# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

import moad_tools.midoss.random_oil_spills as ros

# %matplotlib inline

# %%
importlib.reload(ros)
# Out:
# <module 'moad_tools.midoss.random_oil_spills' from '/Users/sallen/Documents/MIDOSS/moad_tools/moad_tools/midoss/random_oil_spills.py'>

# %%
fraction = np.arange(0, 1+0.02, 0.02)
cumulative = ros.CumulativeSpillFraction(fraction)
print(cumulative)
plt.plot(fraction, cumulative);
# Out:
# [0.         0.24266816 0.35966341 0.42851504 0.47787627 0.51841066
#  0.55415534 0.58670183 0.61673461 0.64459766 0.67050337 0.69460976
#  0.71704939 0.73794026 0.75739031 0.77549928 0.79235978 0.80805793
#  0.82267388 0.83628224 0.84895248 0.86074926 0.87173281 0.88195918
#  0.89148058 0.90034559 0.90859948 0.91628437 0.92343948 0.93010134
#  0.93630395 0.94207896 0.94745587 0.9524621  0.95712322 0.96146302
#  0.96550364 0.96926571 0.97276844 0.97602969 0.97906613 0.98189324
#  0.98452546 0.98697622 0.98925803 0.99138254 0.9933606  0.99520229
#  0.99691702 0.99851354 1.        ]

# %%
random_seed = 101
random_generator = np.random.default_rng(random_seed)

# %%
npoints = 10000
spills = np.zeros(npoints)
for ii in range(npoints):
    spills[ii] = ros.ChoseFractionSpilled(random_generator)
    if ii < 10:
        print(spills[ii])
plt.plot(spills, 'o');
# Out:
# 0.63
# 0.03
# 0.31
# 0.15000000000000002
# 0.03
# 0.55
# 0.43
# 0.05
# 0.77
# 0.01

# %%
plt.hist(spills, bins=50);
