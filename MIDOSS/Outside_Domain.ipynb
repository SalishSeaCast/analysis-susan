# %%
import matplotlib.pyplot as plt
import xarray as xr

# %matplotlib inline

# %%
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_201702.nc')
jjii = xr.open_dataset('/home/sallen/MEOPAR/grid/grid_from_lat_lon_mask999.nc')

# %%
g88r64 = [-122.64, 47.142]
g88r70 = [-122.66, 47.133]
g94p101 = [-126.14, 50.475]
g94p102 = [-126.15, 50.472]
g79r9 = [-124.716, 48.424]
g79r45 = [-124.743, 48.459]
g79r50 = [-124.752, 48.472]
g79r52 = [-124.753, 48.474]
g79r54 = [-124.754, 48.476]
g79r56 = [-124.759, 48.481]
g79r75 = [-124.797, 48.526]
g79r77 = [-124.797, 48.524]
g79r78 = [-124.798, 48.525]
g79r90 = [-124.826, 48.560]

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 9))
ax.pcolormesh(bathy.nav_lon, bathy.nav_lat, bathy.Bathymetry);
for point in [g88r64, g88r70, g94p101, g94p102, g79r9, g79r45, g79r50, g79r52, g79r54, g79r56,
             g79r75, g79r77, g79r78, g79r90]:
    ax.plot(point[0], point[1], 'ro')
# Out:
# <ipython-input-15-7d7a481a9dca>:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(bathy.nav_lon, bathy.nav_lat, bathy.Bathymetry);

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))
for ax in axs:
    ax.pcolormesh(bathy.Bathymetry);
    for point in [g88r64, g88r70, g94p101, g94p102]:
        jj = jjii.jj.sel(lats=point[1], lons=point[0], method='nearest').item()
        ii = jjii.ii.sel(lats=point[1], lons=point[0], method='nearest').item()
        ax.plot(ii + 0.5, jj + 0.5, 'ro')
axs[0].set_ylim(880, 898)
axs[0].set_xlim(40, 60);
axs[1].set_ylim(0, 50)
axs[1].set_xlim(120, 170);

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 9))

ax.pcolormesh(bathy.Bathymetry);
for point in [g79r9, g79r45, g79r50, g79r52, g79r54, g79r56,
             g79r75, g79r77, g79r78, g79r90]:
    jj = jjii.jj.sel(lats=point[1], lons=point[0], method='nearest').item()
    ii = jjii.ii.sel(lats=point[1], lons=point[0], method='nearest').item()
    ax.plot(ii + 0.5, jj + 0.5, 'ro')
ax.set_ylim(395, 415)
ax.set_xlim(0, 20);
