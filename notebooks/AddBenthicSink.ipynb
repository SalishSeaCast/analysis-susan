# %%
import matplotlib.pyplot as plt
import xarray as xr
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
fig, axs = plt.subplots(4, 3, figsize=(14, 16))
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15feb13/SalishSea_1h_20130215_20130215_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[0, 0], vmax=1)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130211_20130215_ptrc_T_20130215-20130215.nc')
benthos.diatoms[23, 0].plot(ax=axs[0, 1], vmax=1)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[0, 2], vmax=0.5)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/20feb13/SalishSea_1h_20130220_20130220_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[1, 0], vmax=2)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130216_20130220_ptrc_T_20130220-20130220.nc')
benthos.diatoms[23, 0].plot(ax=axs[1, 1], vmax=2)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[1, 2], vmax=1)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/25feb13/SalishSea_1h_20130225_20130225_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[2, 0], vmax=2)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130221_20130225_ptrc_T_20130225-20130225.nc')
benthos.diatoms[23, 0].plot(ax=axs[2, 1], vmax=2)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[2, 2], vmax=1)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/28feb13/SalishSea_1h_20130228_20130228_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[3, 0], vmax=2)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130226_20130302_ptrc_T_20130228-20130228.nc')
benthos.diatoms[23, 0].plot(ax=axs[3, 1], vmax=2)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[3, 2], vmax=1)
orig.close()
benthos.close()
fig.tight_layout()

# %%
fig, axs = plt.subplots(4, 3, figsize=(14, 16))
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15feb13/SalishSea_1h_20130215_20130215_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[0, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130211_20130215_ptrc_T_20130215-20130215.nc')
benthos.nitrate[23, 0].plot(ax=axs[0, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[0, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/20feb13/SalishSea_1h_20130220_20130220_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[1, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130216_20130220_ptrc_T_20130220-20130220.nc')
benthos.nitrate[23, 0].plot(ax=axs[1, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[1, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/25feb13/SalishSea_1h_20130225_20130225_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[2, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130221_20130225_ptrc_T_20130225-20130225.nc')
benthos.nitrate[23, 0].plot(ax=axs[2, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[2, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/28feb13/SalishSea_1h_20130228_20130228_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[3, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130226_20130302_ptrc_T_20130228-20130228.nc')
benthos.nitrate[23, 0].plot(ax=axs[3, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[3, 2], vmax=10)
orig.close()
benthos.close()
fig.tight_layout()

# %%
fig, axs = plt.subplots(6, 3, figsize=(14, 24))
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/05mar13/SalishSea_1h_20130305_20130305_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[0, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130303_20130307_ptrc_T_20130305-20130305.nc')
benthos.diatoms[23, 0].plot(ax=axs[0, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[0, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/10mar13/SalishSea_1h_20130310_20130310_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[1, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130308_20130312_ptrc_T_20130310-20130310.nc')
benthos.diatoms[23, 0].plot(ax=axs[1, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[1, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15mar13/SalishSea_1h_20130315_20130315_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[2, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130313_20130317_ptrc_T_20130315-20130315.nc')
benthos.diatoms[23, 0].plot(ax=axs[2, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[2, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/20mar13/SalishSea_1h_20130320_20130320_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[3, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130318_20130322_ptrc_T_20130320-20130320.nc')
benthos.diatoms[23, 0].plot(ax=axs[3, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[3, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/25mar13/SalishSea_1h_20130325_20130325_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[4, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130323_20130327_ptrc_T_20130325-20130325.nc')
benthos.diatoms[23, 0].plot(ax=axs[4, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[4, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/30mar13/SalishSea_1h_20130330_20130330_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[5, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130328_20130401_ptrc_T_20130330-20130330.nc')
benthos.diatoms[23, 0].plot(ax=axs[5, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[5, 2], vmax=2)
orig.close()
benthos.close()
fig.tight_layout()

# %%
fig, axs = plt.subplots(6, 3, figsize=(14, 24))
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/05mar13/SalishSea_1h_20130305_20130305_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[0, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130303_20130307_ptrc_T_20130305-20130305.nc')
benthos.nitrate[23, 0].plot(ax=axs[0, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[0, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/10mar13/SalishSea_1h_20130310_20130310_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[1, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130308_20130312_ptrc_T_20130310-20130310.nc')
benthos.nitrate[23, 0].plot(ax=axs[1, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[1, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15mar13/SalishSea_1h_20130315_20130315_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[2, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130313_20130317_ptrc_T_20130315-20130315.nc')
benthos.nitrate[23, 0].plot(ax=axs[2, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[2, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/20mar13/SalishSea_1h_20130320_20130320_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[3, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130318_20130322_ptrc_T_20130320-20130320.nc')
benthos.nitrate[23, 0].plot(ax=axs[3, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[3, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/25mar13/SalishSea_1h_20130325_20130325_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[4, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130323_20130327_ptrc_T_20130325-20130325.nc')
benthos.nitrate[23, 0].plot(ax=axs[4, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[4, 2], vmax=10)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/30mar13/SalishSea_1h_20130330_20130330_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[5, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130328_20130401_ptrc_T_20130330-20130330.nc')
benthos.nitrate[23, 0].plot(ax=axs[5, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[5, 2], vmax=10)
orig.close()
benthos.close()
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 3, figsize=(14, 12))
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15apr13/SalishSea_1h_20130415_20130415_ptrc_T.nc')
orig.diatoms[23, 0].plot(ax=axs[0, 0], vmax=5)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130412_20130415_ptrc_T_20130415-20130415.nc')
benthos.diatoms[23, 0].plot(ax=axs[0, 1], vmax=5)
(benthos.diatoms[23, 0] - orig.diatoms[23, 0]).plot(ax=axs[0, 2], vmax=2)
orig.close()
benthos.close()
orig = xr.open_dataset('/results/SalishSea/spinup.201905.yr2/15apr13/SalishSea_1h_20130415_20130415_ptrc_T.nc')
orig.nitrate[23, 0].plot(ax=axs[1, 0], vmax=15)
benthos = xr.open_dataset('/data/sallen/results/MEOPAR/test_benthos/SalishSea_1h_20130412_20130415_ptrc_T_20130415-20130415.nc')
benthos.nitrate[23, 0].plot(ax=axs[1, 1], vmax=15)
(benthos.nitrate[23, 0] - orig.nitrate[23, 0]).plot(ax=axs[1, 2], vmax=10)
orig.close()
benthos.close()
fig.tight_layout()
