# %%
import xarray as xr

# %%
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc')
tmask = mesh.tmask

# %%
#data1 = xr.open_dataset('/results2/SalishSea/month-avg.201905/SalishSeaCast_1m_dia1_T_20091201_20091231.nc')
data2 = xr.open_dataset('/data/sallen/results/MEOPAR/v201905r/SalishSea_1m_200912_200912_dia2_T.nc')

# %%
data2.GRMICZDIAT[0].max(axis=0).plot()

# %%
data2.GRMESZMICZ[0].sum(axis=0).plot();

# %%
data3 = xr.open_dataset('/data/sallen/results/MEOPAR/v201905r/SalishSea_1m_200701_200701_dia2_T.nc')

# %%
data3.GRMICZDIAT[0].max(axis=0).plot()

# %%
data3.GRMESZMICZ[0].max(axis=0).plot()

# %%
tmask[0, 0].plot()

# %%
(tmask[0, 0] * data3.GRMESZMICZ[0, :].sum(axis=0)).sum(axis=0).plot()

# %%
(tmask[0, 0] * data3.GRMESZMICZ[0, :].sum(axis=0)).sum(axis=0).sum(axis=0)
# Out:
# <xarray.DataArray ()>
# array(2.2561251e-05, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2007-01-16T12:00:00

# %%
data4 = xr.open_dataset('/results/SalishSea/month-avg.201905/SalishSea_1m_200701_200701_dia2_T.nc')

# %%
(tmask[0, 0] * data4.GRMESZMICZ[0, :].sum(axis=0)).sum(axis=0).sum(axis=0)
# Out:
# <xarray.DataArray ()>
# array(4.4005894e-05, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2007-01-16T12:00:00

# %%
(tmask[0, 0] * data4.GRMICZDIAT[0, :].sum(axis=0)).sum(axis=0).sum(axis=0)
# Out:
# <xarray.DataArray ()>
# array(0., dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2007-01-16T12:00:00

# %%
(tmask[0, 0] * data3.GRMICZDIAT[0, :].sum(axis=0)).sum(axis=0).sum(axis=0)
# Out:
# <xarray.DataArray ()>
# array(0., dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2007-01-16T12:00:00
