# %%
import datetime
import matplotlib.pyplot as plt
import pickle
from salishsea_tools import places
import xarray as xr

# %matplotlib inline
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
places.PLACES['S3']
# Out:
# {'lon lat': (-123.558, 49.125),
#  'NEMO grid ji': (450, 258),
#  'GEM2.5 grid ji': (138, 144)}

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
filein = open('janfebT1.pkl', 'rb')
janfebT1 = pickle.load(filein)
for i in range(len(janfebT1)):
    janfebT1[i].plot(marker='o', color='purple')
filein.close()
filein = open('maraprT1.pkl', 'rb')
maraprT1 = pickle.load(filein)
for i in range(len(maraprT1)):
    maraprT1[i].plot(marker='o', color='purple')
filein.close()
filein = open('janfebbase.pkl', 'rb')
janfebbase = pickle.load(filein)
for i in range(len(janfebbase)):
    janfebbase[i].plot(marker='x', color='blue')
filein.close()
filein = open('maraprbase.pkl', 'rb')
maraprbase = pickle.load(filein)
for i in range(len(maraprbase)):
    maraprbase[i].plot(marker='x', color='blue')
filein.close()
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))

filein = open('maraprT1.pkl', 'rb')
maraprT1 = pickle.load(filein)
for i in range(len(maraprT1)):
    maraprT1[i].plot(marker='o', color='purple')
filein.close()
filein = open('maraprbase.pkl', 'rb')
maraprbase = pickle.load(filein)
for i in range(len(maraprbase)):
    maraprbase[i].plot(marker='x', color='blue')
filein.close()
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))

filein = open('maraprT1NO3.pkl', 'rb')
maraprT1 = pickle.load(filein)
for i in range(len(maraprT1)):
    maraprT1[i].plot(marker='o', color='purple')
filein.close()
filein = open('maraprbaseNO3.pkl', 'rb')
maraprbase = pickle.load(filein)
for i in range(len(maraprbase)):
    maraprbase[i].plot(marker='x', color='blue')
filein.close()
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))

filein = open('novdec2014_base.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='x', color='blue')
filein.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201411-201411.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201412-201412.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))

filein = open('janfeb2015_base.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='x', color='blue')
filein.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201501-201501.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201502-201502.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))

filein = open('janfeb2015_base.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='x', color='blue')
filein.close()
filein = open('marapr2015_base.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='x', color='blue')
filein.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201501-201501.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201502-201502.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201503-201503.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='o', color='purple')
T1.close()
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax2 = ax.twinx()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201503-201503.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(ax=ax, marker='o', color='purple')
T1.nitrate[:, 0, 0, 0].plot(ax=ax2, color='green')
T1.close()
ax.set_xlim(datetime.datetime(2015, 3, 1), datetime.datetime(2015, 3, 10))
ax2.set_ylim(0, 2)
ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax2 = ax.twinx()

filein = open('novdec2014_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201411-201411.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(1, 30+30, 2)):
    base[i].plot(ax=ax2, color='darkslategrey')
    (base[i]-T1chl[j*24:(j+1)*24]).plot(color='goldenrod', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
#for j, i in enumerate(range(28+28, 28+31, 1)):
#    
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201412-201412.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(0, 30+30, 2)):
    (base[i]-T1chl[j*24:(j+1)*24]).plot(marker='+', color='maroon',  ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
(base[60]-T1chl[(30)*24:(31)*24]).plot(marker='^', color='black', ax=ax)
base[60].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()
filein = open('janfeb2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201501-201501.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(1, 28+28, 2)):
    base[i].plot(ax=ax2, color='darkslategrey')
    (base[i]-T1chl[j*24:(j+1)*24]).plot(marker='x', color='blue', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
for j, i in enumerate(range(28+28, 28+31, 1)):
    (base[i]-T1chl[(28+j)*24:(29+j)*24]).plot(marker='^', color='black', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201502-201502.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(0, 28+28, 2)):
    (base[i]-T1chl[j*24:(j+1)*24]).plot(marker='+', color='green',  ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('marapr2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201503-201503.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(1, 30*2, 2)):
    base[i].plot(ax=ax2, color='darkslategrey')
    (base[i]-T1chl[j*24:(j+1)*24]).plot(marker='x', color='purple', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
(base[60]-T1chl[(30)*24:(31)*24]).plot(marker='^', color='black', ax=ax)
base[60].plot(ax=ax2, color='darkslategrey')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov14/S3_201504-201504.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for j, i in enumerate(range(0, 30*2, 2)):
    (base[i]-T1chl[j*24:(j+1)*24]).plot(marker='+', color='cyan', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('may2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01may15/S3_201505-201505.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='<', color='orange', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('jun2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01may15/S3_201506-201506.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='s', color='brown', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('jul2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01jul15/S3_201507-201507.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='o', color='tab:blue', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('aug2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01jul15/S3_201508-201508.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='o', color='darkgreen', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('sep2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01jul15/S3_201509-201509.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='x', color='magenta', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('oct2015_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01jul15/S3_201510-201510.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='tab:cyan', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

#filein = open('janfeb2016_T1.pkl')
#T1 = pickle.load(filein)
#for i in range(len(T1)):
#    base[i].plot(ax=ax2, color='darkslateblue')
#filein.close()

ax.grid();

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax2 = ax.twinx()
filein = open('nov2015_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('dec2015_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('jan2016_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('feb2016_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('mar2016_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('apr2016_snov2015_T1.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(marker='o', color='purple')
filein.close()
filein = open('mar2016_snov2015_T1NO3.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(ax=ax2, color='violet')
filein.close()
filein = open('apr2016_snov2015_T1NO3.pkl', 'rb')
base = pickle.load(filein)
for i in range(len(base)):
    base[i].plot(ax=ax2, color='violet')
filein.close()

T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov15_secondtime/S3_201511-201511.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(ax=ax, marker='+', color='salmon')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov15_secondtime/S3_201512-201512.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='+', color='salmon')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov15_secondtime/S3_201601-201601.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='+', color='salmon')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov15_secondtime/S3_201602-201602.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='+', color='salmon')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01mar16_secondtime/S3_201603-201603.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(marker='+', color='salmon')
T1.nitrate[:, 0, 0, 0].plot(ax=ax2, color='chocolate')
T1.close()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01mar16_secondtime/S3_201604-201604.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(ax=ax, marker='+', color='salmon')
T1.nitrate[:, 0, 0, 0].plot(ax=ax2, color='chocolate')
T1.close()
ax.set_xlim(datetime.datetime(2016, 3, 21), datetime.datetime(2016, 4, 6))

ax.grid()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax2 = ax.twinx()

filein = open('nov2016_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov16/S3_201611-201611.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
base[0].plot(ax=ax2, color='darkslategrey', label='Hindcast')
for i in range(1, len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='goldenrod', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('dec2016_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov16/S3_201612-201612.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='maroon', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('jan2017_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov16/S3_201701-201701.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='tab:blue', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('feb2017_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov16/S3_201702-201702.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='forestgreen', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('mar2017_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/01nov16/S3_201703-201703.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(int(T1chl.shape[0]/24)):
    (base[i]-T1chl[i*24:(i+1)*24]).plot(marker='.', color='purple', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

filein = open('apr2017_base.pkl', 'rb')
base = pickle.load(filein)
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/31mar17/S3_201703-201704.nc')
T1chl = (T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0])
T1chl.plot(ax=ax2, color='grey')
for i in range(len(base)-1):
    (base[i]-T1chl[(i+1)*24:(i+2)*24]).plot(marker='.', color='tab:cyan', ax=ax)
    base[i].plot(ax=ax2, color='darkslategrey')
T1.close()
filein.close()

ax.grid();
ax.set_xlabel('Date')
ax2.legend(loc='lower left')
ax2.set_ylabel('Total Photosynthesizer Biomass (uMol N)');

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax2 = ax.twinx()
T1 = xr.open_dataset('/data/sallen/results/MEOPAR/tuning/31mar17/S3_201703-201704.nc')
(T1.diatoms[:, 0, 0, 0]+T1.flagellates[:, 0, 0, 0]+T1.ciliates[:, 0, 0, 0]).plot(ax=ax, marker='o', color='purple')
T1.nitrate[:, 0, 0, 0].plot(ax=ax2, color='green')
T1.close()
#ax.set_xlim(datetime.datetime(2015, 3, 1), datetime.datetime(2015, 3, 10))
ax2.set_ylim(0, 2)
ax2.grid()
