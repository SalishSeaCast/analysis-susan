# %%
import xarray as xr

# %matplotlib inline

# %%
carp = xr.open_dataset('/data/sallen/results/MEOPAR/202007/SalishSea_1h_20150221_20150225_carp_T_20150221-20150221.nc')
ptrc = xr.open_dataset('/data/sallen/results/MEOPAR/202007/SalishSea_1h_20150221_20150225_ptrc_T_20150221-20150221.nc')

# %%
carp.dissolved_oxygen[0, 0].plot();

# %%
carp.Fraser_tracer[0, 0].plot();

# %%
carp.dissolved_inorganic_carbon[0, 0].plot();

# %%
print(carp.dissolved_oxygen[0].sum())
# Out:
# <xarray.DataArray 'dissolved_oxygen' ()>
# array(4.7547594e+08, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(carp.Fraser_tracer[0].sum())
# Out:
# <xarray.DataArray 'Fraser_tracer' ()>
# array(1083010.5, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(carp.dissolved_inorganic_carbon[0].sum())
# Out:
# <xarray.DataArray 'dissolved_inorganic_carbon' ()>
# array(4.3155553e+09, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(carp.total_alkalinity[0].sum())
# Out:
# <xarray.DataArray 'total_alkalinity' ()>
# array(4.4792883e+09, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.nitrate[0].sum())
# Out:
# <xarray.DataArray 'nitrate' ()>
# array(48670850., dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.biogenic_silicon[0].sum())
# Out:
# <xarray.DataArray 'biogenic_silicon' ()>
# array(10471.012, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.mesozooplankton[0].sum())
# Out:
# <xarray.DataArray 'mesozooplankton' ()>
# array(846397.44, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.particulate_organic_nitrogen[0].sum())
# Out:
# <xarray.DataArray 'particulate_organic_nitrogen' ()>
# array(93736.24, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.dissolved_organic_nitrogen[0].sum())
# Out:
# <xarray.DataArray 'dissolved_organic_nitrogen' ()>
# array(279379.75, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.microzooplankton[0].sum())
# Out:
# <xarray.DataArray 'microzooplankton' ()>
# array(203349.66, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.ciliates[0].sum())
# Out:
# <xarray.DataArray 'ciliates' ()>
# array(232896.2, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.flagellates[0].sum())
# Out:
# <xarray.DataArray 'flagellates' ()>
# array(464428.34, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.diatoms[0].sum())
# Out:
# <xarray.DataArray 'diatoms' ()>
# array(19245.58, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.silicon[0].sum())
# Out:
# <xarray.DataArray 'silicon' ()>
# array(93470570., dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
print(ptrc.ammonium[0].sum())
# Out:
# <xarray.DataArray 'ammonium' ()>
# array(1365314.6, dtype=float32)
# Coordinates:
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-21T00:30:00

# %%
brestart = xr.open_dataset('/data/sallen/results/MEOPAR/202007/SalishSea_03263760_restart_trc.nc')
arestart = xr.open_dataset('/data/sallen/results/MEOPAR/202007/SalishSea_03274560_restart_trc.nc')

# %%
for key in brestart.keys():
    print (key, brestart[key].sum())
    if (brestart[key].sum() != brestart[key].sum()):
        print ('***HERE***')
# Out:
# nav_lon <xarray.DataArray 'nav_lon' ()>
# array(-22577800., dtype=float32)
# nav_lat <xarray.DataArray 'nav_lat' ()>
# array(8939000., dtype=float32)
# nav_lev <xarray.DataArray 'nav_lev' ()>
# array(4214.3496, dtype=float32)
# time_counter <xarray.DataArray 'time_counter' ()>
# array(3263760.)
# kt <xarray.DataArray 'kt' ()>
# array(3263760.)
# ndastp <xarray.DataArray 'ndastp' ()>
# array(20150220.)
# adatrj <xarray.DataArray 'adatrj' ()>
# array(1511.)
# rnf_pis_NO3_b <xarray.DataArray 'rnf_pis_NO3_b' ()>
# array(0.22252972)
# rnf_pis_NH4_b <xarray.DataArray 'rnf_pis_NH4_b' ()>
# array(0.13543033)
# rnf_pis_Si_b <xarray.DataArray 'rnf_pis_Si_b' ()>
# array(1.94184755)
# rnf_pis_DIAT_b <xarray.DataArray 'rnf_pis_DIAT_b' ()>
# array(3.17080688e-05)
# rnf_pis_PHY_b <xarray.DataArray 'rnf_pis_PHY_b' ()>
# array(3.17080688e-05)
# rnf_pis_MYRI_b <xarray.DataArray 'rnf_pis_MYRI_b' ()>
# array(3.17080688e-05)
# rnf_pis_MICZ_b <xarray.DataArray 'rnf_pis_MICZ_b' ()>
# array(3.17080688e-05)
# ...

# %%
for key in arestart.keys():
    print (key, arestart[key].sum())
    if (arestart[key].sum() != arestart[key].sum()):
        print ('***HERE***')
# Out:
# nav_lon <xarray.DataArray 'nav_lon' ()>
# array(-22577800., dtype=float32)
# nav_lat <xarray.DataArray 'nav_lat' ()>
# array(8939000., dtype=float32)
# nav_lev <xarray.DataArray 'nav_lev' ()>
# array(4214.3496, dtype=float32)
# time_counter <xarray.DataArray 'time_counter' ()>
# array(3274560.)
# kt <xarray.DataArray 'kt' ()>
# array(3274560.)
# ndastp <xarray.DataArray 'ndastp' ()>
# array(20150225.)
# adatrj <xarray.DataArray 'adatrj' ()>
# array(1516.)
# rnf_pis_NO3_b <xarray.DataArray 'rnf_pis_NO3_b' ()>
# array(0.20815114)
# rnf_pis_NH4_b <xarray.DataArray 'rnf_pis_NH4_b' ()>
# array(0.12784337)
# rnf_pis_Si_b <xarray.DataArray 'rnf_pis_Si_b' ()>
# array(1.84111363)
# rnf_pis_DIAT_b <xarray.DataArray 'rnf_pis_DIAT_b' ()>
# array(2.99226528e-05)
# rnf_pis_PHY_b <xarray.DataArray 'rnf_pis_PHY_b' ()>
# array(2.99226528e-05)
# rnf_pis_MYRI_b <xarray.DataArray 'rnf_pis_MYRI_b' ()>
# array(2.99226528e-05)
# rnf_pis_MICZ_b <xarray.DataArray 'rnf_pis_MICZ_b' ()>
# array(2.99226528e-05)
# ...

# %% [markdown]
# Its the 20 m depth tracer.  I need to strip this.
