# %% [markdown]
# Notebook to investigate the slab files

# %%
import matplotlib.pyplot as plt
import netCDF4 as nc

# %matplotlib inline

# %%
filename_u = '/results/SalishSea/nowcast-green/03jul17/Slab_U.nc'
u_ds = nc.Dataset(filename_u)
print(u_ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     name: Slab_U
#     description: 20min near surface U velocity
#     title: 20min near surface U velocity
#     Conventions: CF-1.6
#     timeStamp: 2017-Jul-26 23:15:40 GMT
#     uuid: 68c911f9-51fd-47fb-8264-48f9b0d4875c
#     dimensions(sizes): axis_nbounds(2), x(355), y(540), nvertex(4), nearsurface_U(5), time_counter(72)
#     variables(dimensions): float32 nav_lat(y,x), float32 nav_lon(y,x), float32 bounds_lon(y,x,nvertex), float32 bounds_lat(y,x,nvertex), float32 area(y,x), float32 nearsurface_U(nearsurface_U), float32 nearsurface_U_bounds(nearsurface_U,axis_nbounds), float32 vozocrtx(time_counter,nearsurface_U,y,x), float64 time_centered(time_counter), float64 time_centered_bounds(time_counter,axis_nbounds), float64 time_counter(time_counter), float64 time_counter_bounds(time_counter,axis_nbounds)
#     groups:

# %%
depths = u_ds['nearsurface_U'][:]
print(depths)
# Out:
# [ 0.5000003   1.5000031   2.50001144  3.50003052  4.50007057]

# %%
u = u_ds['vozocrtx'][0]
plt.pcolormesh(u[0, 100:200, 200:300], cmap='bwr', vmax=1.4, vmin=-1.4)
plt.colorbar()

# %%
plt.pcolormesh(u[0], cmap='bwr', vmax=1.4, vmin=-1.4)
plt.colorbar()
