# %% [markdown]
# ## Nitrate 20 m and below

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd
import statsmodels.api as sm
import xarray as xr

# %%
foramt = "{:.2}"
myformat = {'bias': foramt, 'rmse': foramt, 'swillmott': foramt, 'slopedev': foramt, 'const': foramt,
                         'systematic': foramt, 'nonsystematic':foramt, 
                    'spread': foramt}
def use_f_2(x):
    return "%.2f" % x

# %%
with xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc') as mesh:
    deptht = mesh.gdept_1d[0].values

# %%
def bias(df, obs, mod):
    diffy = df[mod] - df[obs]
    return diffy.count(), diffy.mean()

# %%
def rmse(df, obs, mod):
    return (np.sqrt(((df[mod] - df[obs])**2).mean()))

# %%
def swillmott(df, obs, mod):
    meanobs = df[obs].mean()
    return (((df[mod] - df[obs])**2).sum()
            /(( (df[mod] - meanobs).abs() + (df[obs] - meanobs).abs() )**2).sum())

# %%
def slope_inter(df, obs, mod):
    X = df[obs]
    y = df[mod]
    X = sm.add_constant(X)

    # Fit and make the predictions by the model
    model = sm.OLS(y, X, missing='drop').fit()
    predictions = model.predict(X)
    
    nonsyst = np.sqrt(((y - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obs])**2).mean())
    return model.params[obs], model.params['const'], systematic, nonsyst

# %%
def spread(df, obs, mod):
    return 1 - ((df[mod] - df[mod].mean())**2).mean() / ((df[obs] - df[obs].mean())**2).mean()

# %%
def read_pieces(pieces):
    temp1 = pd.read_csv(pieces[0])
    for piece in pieces[1:]:
        nextpiece = pd.read_csv(piece)
        temp1 = pd.concat([temp1, nextpiece], ignore_index=True)
    return temp1

# %%
def plot_and_stats(temp1, name, idepth, jdepth, fig, ax):
    vmax = 36
    vmin = 0
#    print (deptht[idepth], deptht[jdepth])
    counts, xedges, yedges, color = ax.hist2d(temp1.NO3[(temp1.k >= idepth) & (temp1.k <= jdepth)], 
                                              temp1.mod_nitrate[(temp1.k >= idepth) & (temp1.k <= jdepth)], 
                                           bins=np.arange(vmin, vmax, 0.5), norm=LogNorm());
    fig.colorbar(color, ax=ax)
    number, tbias = bias(temp1[(temp1.k >= idepth) & (temp1.k <= jdepth)], 'NO3', 'mod_nitrate')
    trmse = rmse(temp1[(temp1.k >= idepth) & (temp1.k <= jdepth)], 'NO3', 'mod_nitrate')
    tswillmott = swillmott(temp1[temp1.k >=idepth], 'NO3', 'mod_nitrate')
    m, c, syst, nonsyst = slope_inter(temp1[(temp1.k >= idepth) & (temp1.k <= jdepth)], 'NO3', 'mod_nitrate')
    tspread = spread(temp1[temp1.k >= idepth], 'NO3', 'mod_nitrate')
    ax.plot([vmin, vmax], [vmin, vmax], 'k-');
    xr = np.arange(vmin, vmax, 0.5)
    ax.plot(xr, c + m * xr, 'r-');
    ax.arrow(5, 30, 0, 2-np.abs(tbias)/2, head_width=0.5, head_length=0.2, length_includes_head=True)
    ax.arrow(5, 34, 0, -2+np.abs(tbias)/2, head_width=0.5, head_length=0.2, length_includes_head=True)
    ax.arrow(7, 30, 0, 2-syst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
    ax.arrow(7, 34, 0, -2+syst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
    ax.arrow(9, 29, 0, 3-nonsyst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
    ax.arrow(9, 35, 0, -3+nonsyst/2, head_width=0.5, head_length=0.2, length_includes_head=True);
    Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
          'swillmott': tswillmott,
          'slopedev': 1-m,
          'const': c,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread}
    ax.text(5-0.6, 26, 'bias', rotation=90)
    ax.text(7-0.6, 22, 'systematic', rotation=90)
    ax.text(9-0.6, 19, 'non-systematic', rotation=90)
    ax.set_title(f'{name}, Nitrate below 20 m');
    dCp2 = pd.DataFrame(data=Cp2, index=[name])
    return dCp2

# %%
def highlight_max_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = abs(s) == abs(s).max()
    is_min = abs(s) == abs(s).min()
    color = []
    for v, v2 in zip(is_max, is_min):
        if v:
            color.append('red')
        elif v2:
            color.append('darkgreen')
        else:
            color.append('black')
    return ['color: %s' % color[i] for i in range(len(is_max))]

# %%
idepth = 19
jdepth = 39

# %%
def plot_one_only(year):
    fig, ax = plt.subplots(1, 1, figsize=(6, 5))
    fig.suptitle(f'Year {year}')
    pieces2 = (
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv'
             )
    temp2 = read_pieces([pieces2])
    temp2['NO3'] = temp2.N
    d202111 = plot_and_stats(temp2, '202111', idepth, jdepth, fig, ax)

    fig.savefig(f'deep_nitrate_202111_for_{year}.png')
    
    f = open(f'./deep_nitrate_202111_for_{year}_table.tex', 'w')
    f.write(d202111.to_latex(column_format='lccccccccc',formatters=[None, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2, use_f_2]))
    f.close()
    
    return d202111

# %%
def plot_compare_year(year):
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(f'Year {year}')
    pieces1 = (
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_bot_{year}0101_{year}1231.csv'
             )
    temp1 = read_pieces([pieces1])
    temp1['NO3'] = temp1.N
    d201905 = plot_and_stats(temp1, '201905R', idepth, jdepth, fig, axs[0])

    pieces2 = (
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv'
             )
    temp2 = read_pieces([pieces2])
    temp2['NO3'] = temp2.N
    d202111 = plot_and_stats(temp2, '202111', idepth, jdepth, fig, axs[1])

    alltogether = pd.concat([d201905, d202111], axis=0)
    fig.savefig(f'deep_nitrate_201905_202111_for_{year}.png')
    
    f = open(f'./deep_nitrate_201905_202111_for_{year}_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='ccccccccc'))
    f.close()
    return alltogether

# %%
def plot_allyears(lastyear):
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    fig.suptitle(f'Year 2007-{lastyear}')
    pieces1 = []
    for year in range(2007, lastyear+1):
        pieces1.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_201905R_bot_{year}0101_{year}1231.csv'
             )
    temp1 = read_pieces(pieces1)
    temp1['NO3'] = temp1.N
    d201905 = plot_and_stats(temp1, '201905R', idepth, jdepth, fig, axs[0])

    pieces2 = []
    for year in range(2007, lastyear+1):
        pieces2.append(
              f'/data/sallen/results/MEOPAR/202111/ObsModel/ObsModel_202111_bot_{year}0101_{year}1231.csv'
             )
    temp2 = read_pieces(pieces2)
    temp2['NO3'] = temp2.N
    d202111 = plot_and_stats(temp2, '202111', idepth, jdepth, fig, axs[1])

    alltogether = pd.concat([d201905, d202111], axis=0)
    fig.savefig(f'deep_nitrate_201905_202111_for_allyears.png')
    
    f = open(f'./deep_nitrate_201905_202111_for_allyears_table.tex', 'w')
    f.write(alltogether.to_latex(column_format='ccccccccc'))
    f.close()
    return alltogether

# %%
results = plot_one_only(2002)
results.style.format(myformat)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_0f601_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f601_level0_row0" class="row_heading level0 row0" >202111</th>
#       <td id="T_0f601_row0_col0" class="data row0 col0" >1112</td>
#       <td id="T_0f601_row0_col1" class="data row0 col1" >-0.87</td>
#       <td id="T_0f601_row0_col2" class="data row0 col2" >3.3</td>
#       <td id="T_0f601_row0_col3" class="data row0 col3" >0.23</td>
#       <td id="T_0f601_row0_col4" class="data row0 col4" >0.42</td>
#       <td id="T_0f601_row0_col5" class="data row0 col5" >1.1e+01</td>
#       <td id="T_0f601_row0_col6" class="data row0 col6" >1.8</td>
#       <td id="T_0f601_row0_col7" class="data row0 col7" >2.7</td>
#       <td id="T_0f601_row0_col8" class="data row0 col8" >0.14</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = plot_one_only(2003)
results.style.format(myformat)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_21091_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21091_level0_row0" class="row_heading level0 row0" >202111</th>
#       <td id="T_21091_row0_col0" class="data row0 col0" >850</td>
#       <td id="T_21091_row0_col1" class="data row0 col1" >-0.77</td>
#       <td id="T_21091_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_21091_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_21091_row0_col4" class="data row0 col4" >0.27</td>
#       <td id="T_21091_row0_col5" class="data row0 col5" >6.8</td>
#       <td id="T_21091_row0_col6" class="data row0 col6" >1.3</td>
#       <td id="T_21091_row0_col7" class="data row0 col7" >2.0</td>
#       <td id="T_21091_row0_col8" class="data row0 col8" >0.18</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = plot_one_only(2004)
results.style.format(myformat)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_5dfac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dfac_level0_row0" class="row_heading level0 row0" >202111</th>
#       <td id="T_5dfac_row0_col0" class="data row0 col0" >640</td>
#       <td id="T_5dfac_row0_col1" class="data row0 col1" >0.39</td>
#       <td id="T_5dfac_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_5dfac_row0_col3" class="data row0 col3" >0.16</td>
#       <td id="T_5dfac_row0_col4" class="data row0 col4" >0.4</td>
#       <td id="T_5dfac_row0_col5" class="data row0 col5" >1.1e+01</td>
#       <td id="T_5dfac_row0_col6" class="data row0 col6" >1.8</td>
#       <td id="T_5dfac_row0_col7" class="data row0 col7" >2.5</td>
#       <td id="T_5dfac_row0_col8" class="data row0 col8" >0.39</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = plot_one_only(2005)
results.style.format(myformat)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_eb86b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb86b_level0_row0" class="row_heading level0 row0" >202111</th>
#       <td id="T_eb86b_row0_col0" class="data row0 col0" >812</td>
#       <td id="T_eb86b_row0_col1" class="data row0 col1" >0.76</td>
#       <td id="T_eb86b_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_eb86b_row0_col3" class="data row0 col3" >0.18</td>
#       <td id="T_eb86b_row0_col4" class="data row0 col4" >0.45</td>
#       <td id="T_eb86b_row0_col5" class="data row0 col5" >1.3e+01</td>
#       <td id="T_eb86b_row0_col6" class="data row0 col6" >2.1</td>
#       <td id="T_eb86b_row0_col7" class="data row0 col7" >2.3</td>
#       <td id="T_eb86b_row0_col8" class="data row0 col8" >0.44</td>
#     </tr>
#   </tbody>
# </table>

# %%
results = plot_one_only(2006)
results.style.format(myformat)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_b2d97_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2d97_level0_row0" class="row_heading level0 row0" >202111</th>
#       <td id="T_b2d97_row0_col0" class="data row0 col0" >723</td>
#       <td id="T_b2d97_row0_col1" class="data row0 col1" >-0.14</td>
#       <td id="T_b2d97_row0_col2" class="data row0 col2" >2.7</td>
#       <td id="T_b2d97_row0_col3" class="data row0 col3" >0.17</td>
#       <td id="T_b2d97_row0_col4" class="data row0 col4" >0.4</td>
#       <td id="T_b2d97_row0_col5" class="data row0 col5" >1.1e+01</td>
#       <td id="T_b2d97_row0_col6" class="data row0 col6" >1.5</td>
#       <td id="T_b2d97_row0_col7" class="data row0 col7" >2.2</td>
#       <td id="T_b2d97_row0_col8" class="data row0 col8" >0.29</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = plot_compare_year(2007)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_6a740_row0_col0, #T_6a740_row0_col1, #T_6a740_row0_col2, #T_6a740_row0_col3, #T_6a740_row0_col4, #T_6a740_row0_col5, #T_6a740_row0_col6, #T_6a740_row0_col8, #T_6a740_row1_col0, #T_6a740_row1_col7 {
#   color: red;
# }
# #T_6a740_row0_col7, #T_6a740_row1_col1, #T_6a740_row1_col2, #T_6a740_row1_col3, #T_6a740_row1_col4, #T_6a740_row1_col5, #T_6a740_row1_col6, #T_6a740_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_6a740_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a740_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_6a740_row0_col0" class="data row0 col0" >827</td>
#       <td id="T_6a740_row0_col1" class="data row0 col1" >-0.77</td>
#       <td id="T_6a740_row0_col2" class="data row0 col2" >2.9</td>
#       <td id="T_6a740_row0_col3" class="data row0 col3" >0.2</td>
#       <td id="T_6a740_row0_col4" class="data row0 col4" >0.41</td>
#       <td id="T_6a740_row0_col5" class="data row0 col5" >1.1e+01</td>
#       <td id="T_6a740_row0_col6" class="data row0 col6" >1.7</td>
#       <td id="T_6a740_row0_col7" class="data row0 col7" >2.4</td>
#       <td id="T_6a740_row0_col8" class="data row0 col8" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_6a740_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_6a740_row1_col0" class="data row1 col0" >827</td>
#       <td id="T_6a740_row1_col1" class="data row1 col1" >-0.66</td>
#       <td id="T_6a740_row1_col2" class="data row1 col2" >2.8</td>
#       <td id="T_6a740_row1_col3" class="data row1 col3" >0.19</td>
#       <td id="T_6a740_row1_col4" class="data row1 col4" >0.39</td>
#       <td id="T_6a740_row1_col5" class="data row1 col5" >1e+01</td>
#       <td id="T_6a740_row1_col6" class="data row1 col6" >1.6</td>
#       <td id="T_6a740_row1_col7" class="data row1 col7" >2.4</td>
#       <td id="T_6a740_row1_col8" class="data row1 col8" >0.22</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = plot_compare_year(2008)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_5c2dd_row0_col0, #T_5c2dd_row0_col1, #T_5c2dd_row0_col2, #T_5c2dd_row0_col3, #T_5c2dd_row0_col4, #T_5c2dd_row0_col5, #T_5c2dd_row0_col6, #T_5c2dd_row0_col7, #T_5c2dd_row1_col0, #T_5c2dd_row1_col8 {
#   color: red;
# }
# #T_5c2dd_row0_col8, #T_5c2dd_row1_col1, #T_5c2dd_row1_col2, #T_5c2dd_row1_col3, #T_5c2dd_row1_col4, #T_5c2dd_row1_col5, #T_5c2dd_row1_col6, #T_5c2dd_row1_col7 {
#   color: darkgreen;
# }
# </style>
# <table id="T_5c2dd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c2dd_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_5c2dd_row0_col0" class="data row0 col0" >788</td>
#       <td id="T_5c2dd_row0_col1" class="data row0 col1" >-0.54</td>
#       <td id="T_5c2dd_row0_col2" class="data row0 col2" >2.7</td>
#       <td id="T_5c2dd_row0_col3" class="data row0 col3" >0.15</td>
#       <td id="T_5c2dd_row0_col4" class="data row0 col4" >0.34</td>
#       <td id="T_5c2dd_row0_col5" class="data row0 col5" >9.1</td>
#       <td id="T_5c2dd_row0_col6" class="data row0 col6" >1.4</td>
#       <td id="T_5c2dd_row0_col7" class="data row0 col7" >2.3</td>
#       <td id="T_5c2dd_row0_col8" class="data row0 col8" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_5c2dd_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_5c2dd_row1_col0" class="data row1 col0" >788</td>
#       <td id="T_5c2dd_row1_col1" class="data row1 col1" >-0.27</td>
#       <td id="T_5c2dd_row1_col2" class="data row1 col2" >2.4</td>
#       <td id="T_5c2dd_row1_col3" class="data row1 col3" >0.13</td>
#       <td id="T_5c2dd_row1_col4" class="data row1 col4" >0.33</td>
#       <td id="T_5c2dd_row1_col5" class="data row1 col5" >9.0</td>
#       <td id="T_5c2dd_row1_col6" class="data row1 col6" >1.3</td>
#       <td id="T_5c2dd_row1_col7" class="data row1 col7" >2.0</td>
#       <td id="T_5c2dd_row1_col8" class="data row1 col8" >0.26</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = plot_compare_year(2009)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_aef0b_row0_col0, #T_aef0b_row0_col2, #T_aef0b_row0_col3, #T_aef0b_row0_col4, #T_aef0b_row0_col5, #T_aef0b_row0_col6, #T_aef0b_row0_col7, #T_aef0b_row0_col8, #T_aef0b_row1_col0, #T_aef0b_row1_col1 {
#   color: red;
# }
# #T_aef0b_row0_col1, #T_aef0b_row1_col2, #T_aef0b_row1_col3, #T_aef0b_row1_col4, #T_aef0b_row1_col5, #T_aef0b_row1_col6, #T_aef0b_row1_col7, #T_aef0b_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_aef0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aef0b_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_aef0b_row0_col0" class="data row0 col0" >818</td>
#       <td id="T_aef0b_row0_col1" class="data row0 col1" >-0.15</td>
#       <td id="T_aef0b_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_aef0b_row0_col3" class="data row0 col3" >0.13</td>
#       <td id="T_aef0b_row0_col4" class="data row0 col4" >0.38</td>
#       <td id="T_aef0b_row0_col5" class="data row0 col5" >1e+01</td>
#       <td id="T_aef0b_row0_col6" class="data row0 col6" >1.4</td>
#       <td id="T_aef0b_row0_col7" class="data row0 col7" >1.8</td>
#       <td id="T_aef0b_row0_col8" class="data row0 col8" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_aef0b_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_aef0b_row1_col0" class="data row1 col0" >818</td>
#       <td id="T_aef0b_row1_col1" class="data row1 col1" >-0.61</td>
#       <td id="T_aef0b_row1_col2" class="data row1 col2" >2.2</td>
#       <td id="T_aef0b_row1_col3" class="data row1 col3" >0.12</td>
#       <td id="T_aef0b_row1_col4" class="data row1 col4" >0.33</td>
#       <td id="T_aef0b_row1_col5" class="data row1 col5" >8.7</td>
#       <td id="T_aef0b_row1_col6" class="data row1 col6" >1.4</td>
#       <td id="T_aef0b_row1_col7" class="data row1 col7" >1.8</td>
#       <td id="T_aef0b_row1_col8" class="data row1 col8" >0.32</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = plot_compare_year(2010)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_1f83a_row0_col0, #T_1f83a_row0_col3, #T_1f83a_row0_col4, #T_1f83a_row0_col5, #T_1f83a_row0_col6, #T_1f83a_row0_col8, #T_1f83a_row1_col0, #T_1f83a_row1_col1, #T_1f83a_row1_col2, #T_1f83a_row1_col7 {
#   color: red;
# }
# #T_1f83a_row0_col1, #T_1f83a_row0_col2, #T_1f83a_row0_col7, #T_1f83a_row1_col3, #T_1f83a_row1_col4, #T_1f83a_row1_col5, #T_1f83a_row1_col6, #T_1f83a_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_1f83a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f83a_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_1f83a_row0_col0" class="data row0 col0" >1071</td>
#       <td id="T_1f83a_row0_col1" class="data row0 col1" >-0.79</td>
#       <td id="T_1f83a_row0_col2" class="data row0 col2" >2.4</td>
#       <td id="T_1f83a_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_1f83a_row0_col4" class="data row0 col4" >0.33</td>
#       <td id="T_1f83a_row0_col5" class="data row0 col5" >8.5</td>
#       <td id="T_1f83a_row0_col6" class="data row0 col6" >1.6</td>
#       <td id="T_1f83a_row0_col7" class="data row0 col7" >1.8</td>
#       <td id="T_1f83a_row0_col8" class="data row0 col8" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_1f83a_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_1f83a_row1_col0" class="data row1 col0" >1071</td>
#       <td id="T_1f83a_row1_col1" class="data row1 col1" >-0.98</td>
#       <td id="T_1f83a_row1_col2" class="data row1 col2" >2.5</td>
#       <td id="T_1f83a_row1_col3" class="data row1 col3" >0.1</td>
#       <td id="T_1f83a_row1_col4" class="data row1 col4" >0.28</td>
#       <td id="T_1f83a_row1_col5" class="data row1 col5" >6.7</td>
#       <td id="T_1f83a_row1_col6" class="data row1 col6" >1.5</td>
#       <td id="T_1f83a_row1_col7" class="data row1 col7" >1.9</td>
#       <td id="T_1f83a_row1_col8" class="data row1 col8" >0.33</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = plot_allyears(2010)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_6b523_row0_col0, #T_6b523_row0_col2, #T_6b523_row0_col3, #T_6b523_row0_col4, #T_6b523_row0_col5, #T_6b523_row0_col6, #T_6b523_row0_col7, #T_6b523_row0_col8, #T_6b523_row1_col0, #T_6b523_row1_col1 {
#   color: red;
# }
# #T_6b523_row0_col1, #T_6b523_row1_col2, #T_6b523_row1_col3, #T_6b523_row1_col4, #T_6b523_row1_col5, #T_6b523_row1_col6, #T_6b523_row1_col7, #T_6b523_row1_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_6b523_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b523_level0_row0" class="row_heading level0 row0" >201905R</th>
#       <td id="T_6b523_row0_col0" class="data row0 col0" >3504</td>
#       <td id="T_6b523_row0_col1" class="data row0 col1" >-0.58</td>
#       <td id="T_6b523_row0_col2" class="data row0 col2" >2.6</td>
#       <td id="T_6b523_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_6b523_row0_col4" class="data row0 col4" >0.36</td>
#       <td id="T_6b523_row0_col5" class="data row0 col5" >9.5</td>
#       <td id="T_6b523_row0_col6" class="data row0 col6" >1.5</td>
#       <td id="T_6b523_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_6b523_row0_col8" class="data row0 col8" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_6b523_level0_row1" class="row_heading level0 row1" >202111</th>
#       <td id="T_6b523_row1_col0" class="data row1 col0" >3504</td>
#       <td id="T_6b523_row1_col1" class="data row1 col1" >-0.66</td>
#       <td id="T_6b523_row1_col2" class="data row1 col2" >2.5</td>
#       <td id="T_6b523_row1_col3" class="data row1 col3" >0.13</td>
#       <td id="T_6b523_row1_col4" class="data row1 col4" >0.32</td>
#       <td id="T_6b523_row1_col5" class="data row1 col5" >8.3</td>
#       <td id="T_6b523_row1_col6" class="data row1 col6" >1.4</td>
#       <td id="T_6b523_row1_col7" class="data row1 col7" >2.1</td>
#       <td id="T_6b523_row1_col8" class="data row1 col8" >0.27</td>
#     </tr>
#   </tbody>
# </table>

# %%
temp1 = read_pieces(pieces)
temp1['NO3'] = temp1.N.fillna(value=temp1.NO23).fillna(value=temp1['Nitrate_plus_Nitrite [umol/L]'])
modH = plot_and_stats(temp1, 'H', idepth, jdepth)
modH.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_d0cd9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0cd9_level0_row0" class="row_heading level0 row0" >H</th>
#       <td id="T_d0cd9_row0_col0" class="data row0 col0" >2938</td>
#       <td id="T_d0cd9_row0_col1" class="data row0 col1" >-1.8</td>
#       <td id="T_d0cd9_row0_col2" class="data row0 col2" >3.4</td>
#       <td id="T_d0cd9_row0_col3" class="data row0 col3" >0.13</td>
#       <td id="T_d0cd9_row0_col4" class="data row0 col4" >0.27</td>
#       <td id="T_d0cd9_row0_col5" class="data row0 col5" >5.0</td>
#       <td id="T_d0cd9_row0_col6" class="data row0 col6" >2.2</td>
#       <td id="T_d0cd9_row0_col7" class="data row0 col7" >2.6</td>
#       <td id="T_d0cd9_row0_col8" class="data row0 col8" >0.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces = ('/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_bot_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_bot_20160101_20161231.csv',
   #       '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_bot_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_psf_20150101_20151231.csv',
# b         '/home/sallen/202007/202007C-p3/ObsModel_202007Cp3_psf_20160101_20161231.csv',
# b         '/home/sallen/202007/202007C-p3/ObsModel_202007Cp3_psf_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pug_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pug_20160101_20161231.csv',
    #      '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pug_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_hplc_20150101_20151231.csv',
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_hplc_20160101_20161231.csv',
    #     '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_hplc_20170101_20171231.csv'
         )

# %%
temp1 = read_pieces(pieces)
temp1['NO3'] = temp1.N.fillna(value=temp1.NO23).fillna(value=temp1['Nitrate_plus_Nitrite [umol/L]'])
modGp1 = plot_and_stats(temp1, 'Gp1', idepth, jdepth)
modGp1.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_d7194_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7194_level0_row0" class="row_heading level0 row0" >Gp1</th>
#       <td id="T_d7194_row0_col0" class="data row0 col0" >1791</td>
#       <td id="T_d7194_row0_col1" class="data row0 col1" >-1.7</td>
#       <td id="T_d7194_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_d7194_row0_col3" class="data row0 col3" >0.13</td>
#       <td id="T_d7194_row0_col4" class="data row0 col4" >0.24</td>
#       <td id="T_d7194_row0_col5" class="data row0 col5" >4.4</td>
#       <td id="T_d7194_row0_col6" class="data row0 col6" >2.0</td>
#       <td id="T_d7194_row0_col7" class="data row0 col7" >2.4</td>
#       <td id="T_d7194_row0_col8" class="data row0 col8" >0.16</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces = ('/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_bot_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_bot_20160101_20161231.csv',
       #   '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_bot_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_psf_20150101_20151231.csv',
#b          '/home/sallen/202007/202007C-p3/ObsModel_202007Cp3_psf_20160101_20161231.csv',
#b          '/home/sallen/202007/202007C-p3/ObsModel_202007Cp3_psf_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_pug_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_pug_20160101_20161231.csv',
  #        '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_pug_20170101_20171231.csv',
         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_hplc_20150101_20151231.csv',
         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_hplc_20160101_20161231.csv',
  #       '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_hplc_20170101_20171231.csv'
         )

# %%
temp1 = read_pieces(pieces)
temp1['NO3'] = temp1.N.fillna(value=temp1.NO23).fillna(value=temp1['Nitrate_plus_Nitrite [umol/L]'])
modGp2 = plot_and_stats(temp1, 'Gp2', idepth, jdepth)
modGp2.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_3b0a3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0a3_level0_row0" class="row_heading level0 row0" >Gp2</th>
#       <td id="T_3b0a3_row0_col0" class="data row0 col0" >1791</td>
#       <td id="T_3b0a3_row0_col1" class="data row0 col1" >-1.7</td>
#       <td id="T_3b0a3_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_3b0a3_row0_col3" class="data row0 col3" >0.13</td>
#       <td id="T_3b0a3_row0_col4" class="data row0 col4" >0.25</td>
#       <td id="T_3b0a3_row0_col5" class="data row0 col5" >4.7</td>
#       <td id="T_3b0a3_row0_col6" class="data row0 col6" >2.0</td>
#       <td id="T_3b0a3_row0_col7" class="data row0 col7" >2.4</td>
#       <td id="T_3b0a3_row0_col8" class="data row0 col8" >0.17</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces = ('/data/sallen/results/MEOPAR/202111/ObsModel_202111_bot_20150101_20151231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_psf_20150101_20151231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_pug_20150101_20151231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_hplc_20150101_20151231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_bot_20160101_20161231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_pug_20160101_20161231.csv',
         '/data/sallen/results/MEOPAR/202111/ObsModel_202111_hplc_20160101_20161231.csv'
         )

# %%
temp1 = read_pieces(pieces)
temp1['NO3'] = temp1.N.fillna(value=temp1.NO23).fillna(value=temp1['Nitrate_plus_Nitrite [umol/L]'])
modv202111 = plot_and_stats(temp1, 'modv202111', idepth, jdepth)
modv202111.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# </style>
# <table id="T_59f95_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59f95_level0_row0" class="row_heading level0 row0" >modv202111</th>
#       <td id="T_59f95_row0_col0" class="data row0 col0" >1791</td>
#       <td id="T_59f95_row0_col1" class="data row0 col1" >-1.6</td>
#       <td id="T_59f95_row0_col2" class="data row0 col2" >3.0</td>
#       <td id="T_59f95_row0_col3" class="data row0 col3" >0.12</td>
#       <td id="T_59f95_row0_col4" class="data row0 col4" >0.27</td>
#       <td id="T_59f95_row0_col5" class="data row0 col5" >5.4</td>
#       <td id="T_59f95_row0_col6" class="data row0 col6" >2.0</td>
#       <td id="T_59f95_row0_col7" class="data row0 col7" >2.3</td>
#       <td id="T_59f95_row0_col8" class="data row0 col8" >0.24</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogether = pd.concat([d201812, d201905, 
                         dCp2, modCp3, #Dagain, DnoC, DlowR, 
                         modF, #modH, 
                         modGp1, modGp2,
                        modv202111], axis=0)
foramt = "{:.2}"
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_d4864_row0_col0, #T_d4864_row0_col7, #T_d4864_row0_col8, #T_d4864_row1_col0, #T_d4864_row2_col0, #T_d4864_row3_col1, #T_d4864_row3_col2, #T_d4864_row3_col3, #T_d4864_row3_col6, #T_d4864_row7_col4, #T_d4864_row7_col5 {
#   color: red;
# }
# #T_d4864_row0_col1, #T_d4864_row0_col2, #T_d4864_row0_col3, #T_d4864_row1_col1, #T_d4864_row1_col2, #T_d4864_row1_col3, #T_d4864_row1_col4, #T_d4864_row1_col5, #T_d4864_row1_col6, #T_d4864_row1_col7, #T_d4864_row1_col8, #T_d4864_row2_col1, #T_d4864_row2_col2, #T_d4864_row2_col3, #T_d4864_row2_col4, #T_d4864_row2_col5, #T_d4864_row2_col6, #T_d4864_row2_col7, #T_d4864_row2_col8, #T_d4864_row3_col4, #T_d4864_row3_col5, #T_d4864_row3_col7, #T_d4864_row4_col0, #T_d4864_row4_col1, #T_d4864_row4_col2, #T_d4864_row4_col3, #T_d4864_row4_col4, #T_d4864_row4_col5, #T_d4864_row4_col6, #T_d4864_row4_col7, #T_d4864_row4_col8, #T_d4864_row5_col0, #T_d4864_row5_col1, #T_d4864_row5_col2, #T_d4864_row5_col3, #T_d4864_row5_col4, #T_d4864_row5_col5, #T_d4864_row5_col6, #T_d4864_row5_col7, #T_d4864_row5_col8, #T_d4864_row6_col0, #T_d4864_row6_col1, #T_d4864_row6_col2, #T_d4864_row6_col3, #T_d4864_row6_col4, #T_d4864_row6_col5, #T_d4864_row6_col6, #T_d4864_row6_col7, #T_d4864_row6_col8, #T_d4864_row7_col0, #T_d4864_row7_col6, #T_d4864_row7_col8 {
#   color: black;
# }
# #T_d4864_row0_col4, #T_d4864_row0_col5, #T_d4864_row0_col6, #T_d4864_row3_col0, #T_d4864_row3_col8, #T_d4864_row7_col1, #T_d4864_row7_col2, #T_d4864_row7_col3, #T_d4864_row7_col7 {
#   color: darkgreen;
# }
# </style>
# <table id="T_d4864_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4864_level0_row0" class="row_heading level0 row0" >H201812</th>
#       <td id="T_d4864_row0_col0" class="data row0 col0" >1793</td>
#       <td id="T_d4864_row0_col1" class="data row0 col1" >-1.9</td>
#       <td id="T_d4864_row0_col2" class="data row0 col2" >3.6</td>
#       <td id="T_d4864_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_d4864_row0_col4" class="data row0 col4" >0.069</td>
#       <td id="T_d4864_row0_col5" class="data row0 col5" >-0.11</td>
#       <td id="T_d4864_row0_col6" class="data row0 col6" >1.9</td>
#       <td id="T_d4864_row0_col7" class="data row0 col7" >3.1</td>
#       <td id="T_d4864_row0_col8" class="data row0 col8" >-0.3</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row1" class="row_heading level0 row1" >H201905</th>
#       <td id="T_d4864_row1_col0" class="data row1 col0" >1793</td>
#       <td id="T_d4864_row1_col1" class="data row1 col1" >-1.9</td>
#       <td id="T_d4864_row1_col2" class="data row1 col2" >3.3</td>
#       <td id="T_d4864_row1_col3" class="data row1 col3" >0.14</td>
#       <td id="T_d4864_row1_col4" class="data row1 col4" >0.27</td>
#       <td id="T_d4864_row1_col5" class="data row1 col5" >5.0</td>
#       <td id="T_d4864_row1_col6" class="data row1 col6" >2.3</td>
#       <td id="T_d4864_row1_col7" class="data row1 col7" >2.3</td>
#       <td id="T_d4864_row1_col8" class="data row1 col8" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row2" class="row_heading level0 row2" >Cp2</th>
#       <td id="T_d4864_row2_col0" class="data row2 col0" >1793</td>
#       <td id="T_d4864_row2_col1" class="data row2 col1" >-2.4</td>
#       <td id="T_d4864_row2_col2" class="data row2 col2" >3.6</td>
#       <td id="T_d4864_row2_col3" class="data row2 col3" >0.15</td>
#       <td id="T_d4864_row2_col4" class="data row2 col4" >0.19</td>
#       <td id="T_d4864_row2_col5" class="data row2 col5" >2.3</td>
#       <td id="T_d4864_row2_col6" class="data row2 col6" >2.6</td>
#       <td id="T_d4864_row2_col7" class="data row2 col7" >2.6</td>
#       <td id="T_d4864_row2_col8" class="data row2 col8" >0.039</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row3" class="row_heading level0 row3" >Cp3</th>
#       <td id="T_d4864_row3_col0" class="data row3 col0" >1789</td>
#       <td id="T_d4864_row3_col1" class="data row3 col1" >-2.6</td>
#       <td id="T_d4864_row3_col2" class="data row3 col2" >3.7</td>
#       <td id="T_d4864_row3_col3" class="data row3 col3" >0.16</td>
#       <td id="T_d4864_row3_col4" class="data row3 col4" >0.16</td>
#       <td id="T_d4864_row3_col5" class="data row3 col5" >1.4</td>
#       <td id="T_d4864_row3_col6" class="data row3 col6" >2.7</td>
#       <td id="T_d4864_row3_col7" class="data row3 col7" >2.6</td>
#       <td id="T_d4864_row3_col8" class="data row3 col8" >-0.015</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row4" class="row_heading level0 row4" >F</th>
#       <td id="T_d4864_row4_col0" class="data row4 col0" >1791</td>
#       <td id="T_d4864_row4_col1" class="data row4 col1" >-2.1</td>
#       <td id="T_d4864_row4_col2" class="data row4 col2" >3.4</td>
#       <td id="T_d4864_row4_col3" class="data row4 col3" >0.15</td>
#       <td id="T_d4864_row4_col4" class="data row4 col4" >0.27</td>
#       <td id="T_d4864_row4_col5" class="data row4 col5" >4.7</td>
#       <td id="T_d4864_row4_col6" class="data row4 col6" >2.5</td>
#       <td id="T_d4864_row4_col7" class="data row4 col7" >2.4</td>
#       <td id="T_d4864_row4_col8" class="data row4 col8" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row5" class="row_heading level0 row5" >Gp1</th>
#       <td id="T_d4864_row5_col0" class="data row5 col0" >1791</td>
#       <td id="T_d4864_row5_col1" class="data row5 col1" >-1.7</td>
#       <td id="T_d4864_row5_col2" class="data row5 col2" >3.1</td>
#       <td id="T_d4864_row5_col3" class="data row5 col3" >0.13</td>
#       <td id="T_d4864_row5_col4" class="data row5 col4" >0.24</td>
#       <td id="T_d4864_row5_col5" class="data row5 col5" >4.4</td>
#       <td id="T_d4864_row5_col6" class="data row5 col6" >2.0</td>
#       <td id="T_d4864_row5_col7" class="data row5 col7" >2.4</td>
#       <td id="T_d4864_row5_col8" class="data row5 col8" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row6" class="row_heading level0 row6" >Gp2</th>
#       <td id="T_d4864_row6_col0" class="data row6 col0" >1791</td>
#       <td id="T_d4864_row6_col1" class="data row6 col1" >-1.7</td>
#       <td id="T_d4864_row6_col2" class="data row6 col2" >3.1</td>
#       <td id="T_d4864_row6_col3" class="data row6 col3" >0.13</td>
#       <td id="T_d4864_row6_col4" class="data row6 col4" >0.25</td>
#       <td id="T_d4864_row6_col5" class="data row6 col5" >4.7</td>
#       <td id="T_d4864_row6_col6" class="data row6 col6" >2.0</td>
#       <td id="T_d4864_row6_col7" class="data row6 col7" >2.4</td>
#       <td id="T_d4864_row6_col8" class="data row6 col8" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_d4864_level0_row7" class="row_heading level0 row7" >modv202111</th>
#       <td id="T_d4864_row7_col0" class="data row7 col0" >1791</td>
#       <td id="T_d4864_row7_col1" class="data row7 col1" >-1.6</td>
#       <td id="T_d4864_row7_col2" class="data row7 col2" >3.0</td>
#       <td id="T_d4864_row7_col3" class="data row7 col3" >0.12</td>
#       <td id="T_d4864_row7_col4" class="data row7 col4" >0.27</td>
#       <td id="T_d4864_row7_col5" class="data row7 col5" >5.4</td>
#       <td id="T_d4864_row7_col6" class="data row7 col6" >2.0</td>
#       <td id="T_d4864_row7_col7" class="data row7 col7" >2.3</td>
#       <td id="T_d4864_row7_col8" class="data row7 col8" >0.24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Conclusion** Gp1 has the best nitrate!  Gp2 very very similar. Fuzz with low model values and obs between 25 and 30 is Puget.

# %% [markdown]
# ## Question 1: Is the inclusion of Puget Sound why the nitrate is so underpredicted?

# %%
pieces = ('/home/sallen/202007/202007F/ObsModel_202007F_bot_20150101_20151231.csv',
          '/home/sallen/202007/202007F/ObsModel_202007F_bot_20160101_20161231.csv',
          '/home/sallen/202007/202007F/ObsModel_202007F_bot_20170101_20171231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_psf_20150101_20151231.csv',
#          '/home/sallen/202007/202007F/ObsModel_202007F_psf_20160101_20161231.csv',
#          '/home/sallen/202007/202007F/ObsModel_202007F_psf_20170101_20171231.csv',
#         '/home/sallen/202007/202007F/ObsModel_202007F_pug_20150101_20151231.csv',
#          '/home/sallen/202007/202007F/ObsModel_202007F_pug_20160101_20161231.csv',
#          '/home/sallen/202007/202007F/ObsModel_202007F_pug_20170101_20171231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_hplc_20150101_20151231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_hplc_20160101_20161231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_hplc_20170101_20171231.csv')

# %%
temp1 = read_pieces(pieces)
temp1['NO3'] = temp1.N.fillna(value=temp1.NO23).fillna(value=temp1['Nitrate_plus_Nitrite [umol/L]'])
modF = plot_and_stats(temp1, 'F', idepth, jdepth)
modF.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# <style  type="text/css" >
# </style><table id="T_ca76b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number</th>        <th class="col_heading level0 col1" >bias</th>        <th class="col_heading level0 col2" >rmse</th>        <th class="col_heading level0 col3" >swillmott</th>        <th class="col_heading level0 col4" >slopedev</th>        <th class="col_heading level0 col5" >const</th>        <th class="col_heading level0 col6" >systematic</th>        <th class="col_heading level0 col7" >nonsystematic</th>        <th class="col_heading level0 col8" >spread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca76b_level0_row0" class="row_heading level0 row0" >F</th>
#                         <td id="T_ca76b_row0_col0" class="data row0 col0" >2429</td>
#                         <td id="T_ca76b_row0_col1" class="data row0 col1" >-1.6</td>
#                         <td id="T_ca76b_row0_col2" class="data row0 col2" >2.6</td>
#                         <td id="T_ca76b_row0_col3" class="data row0 col3" >0.11</td>
#                         <td id="T_ca76b_row0_col4" class="data row0 col4" >0.25</td>
#                         <td id="T_ca76b_row0_col5" class="data row0 col5" >5.0</td>
#                         <td id="T_ca76b_row0_col6" class="data row0 col6" >1.9</td>
#                         <td id="T_ca76b_row0_col7" class="data row0 col7" >1.8</td>
#                         <td id="T_ca76b_row0_col8" class="data row0 col8" >0.26</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# It makes it worse, but the maximum number of points (yellow patch) is not Puget Sound.

# %% [markdown]
# ## Question 2: Is the bias improving or getting worse in time?

# %%
#temp1.set_index('dtUTC', inplace=True)
temp1.index = pd.to_datetime(temp1.index)

# %%
modF15 = plot_and_stats(temp1[temp1.index < dt.datetime(2016, 1, 1)], 'F15', idepth, jdepth)
modF15.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# <style  type="text/css" >
# </style><table id="T_a4e1a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number</th>        <th class="col_heading level0 col1" >bias</th>        <th class="col_heading level0 col2" >rmse</th>        <th class="col_heading level0 col3" >swillmott</th>        <th class="col_heading level0 col4" >slopedev</th>        <th class="col_heading level0 col5" >const</th>        <th class="col_heading level0 col6" >systematic</th>        <th class="col_heading level0 col7" >nonsystematic</th>        <th class="col_heading level0 col8" >spread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4e1a_level0_row0" class="row_heading level0 row0" >F15</th>
#                         <td id="T_a4e1a_row0_col0" class="data row0 col0" >392</td>
#                         <td id="T_a4e1a_row0_col1" class="data row0 col1" >-2.3</td>
#                         <td id="T_a4e1a_row0_col2" class="data row0 col2" >3.0</td>
#                         <td id="T_a4e1a_row0_col3" class="data row0 col3" >0.22</td>
#                         <td id="T_a4e1a_row0_col4" class="data row0 col4" >0.29</td>
#                         <td id="T_a4e1a_row0_col5" class="data row0 col5" >5.4</td>
#                         <td id="T_a4e1a_row0_col6" class="data row0 col6" >2.5</td>
#                         <td id="T_a4e1a_row0_col7" class="data row0 col7" >1.6</td>
#                         <td id="T_a4e1a_row0_col8" class="data row0 col8" >0.23</td>
#             </tr>
#     </tbody></table>

# %%
modF16 = plot_and_stats(temp1[(temp1.index >= dt.datetime(2016, 1, 1)) & (temp1.index < dt.datetime(2017, 1, 1))], 'F16', idepth, jdepth)
modF16.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# <style  type="text/css" >
# </style><table id="T_84b9e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number</th>        <th class="col_heading level0 col1" >bias</th>        <th class="col_heading level0 col2" >rmse</th>        <th class="col_heading level0 col3" >swillmott</th>        <th class="col_heading level0 col4" >slopedev</th>        <th class="col_heading level0 col5" >const</th>        <th class="col_heading level0 col6" >systematic</th>        <th class="col_heading level0 col7" >nonsystematic</th>        <th class="col_heading level0 col8" >spread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84b9e_level0_row0" class="row_heading level0 row0" >F16</th>
#                         <td id="T_84b9e_row0_col0" class="data row0 col0" >1072</td>
#                         <td id="T_84b9e_row0_col1" class="data row0 col1" >-1.7</td>
#                         <td id="T_84b9e_row0_col2" class="data row0 col2" >2.5</td>
#                         <td id="T_84b9e_row0_col3" class="data row0 col3" >0.096</td>
#                         <td id="T_84b9e_row0_col4" class="data row0 col4" >0.16</td>
#                         <td id="T_84b9e_row0_col5" class="data row0 col5" >2.7</td>
#                         <td id="T_84b9e_row0_col6" class="data row0 col6" >1.8</td>
#                         <td id="T_84b9e_row0_col7" class="data row0 col7" >1.7</td>
#                         <td id="T_84b9e_row0_col8" class="data row0 col8" >0.14</td>
#             </tr>
#     </tbody></table>

# %%
modF17 = plot_and_stats(temp1[temp1.index >= dt.datetime(2017, 1, 1)], 'F17', idepth, jdepth)
modF17.style.format(myformat)
# Out:
# 21.38997868353431 441.4661096800038
# <style  type="text/css" >
# </style><table id="T_5de70_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number</th>        <th class="col_heading level0 col1" >bias</th>        <th class="col_heading level0 col2" >rmse</th>        <th class="col_heading level0 col3" >swillmott</th>        <th class="col_heading level0 col4" >slopedev</th>        <th class="col_heading level0 col5" >const</th>        <th class="col_heading level0 col6" >systematic</th>        <th class="col_heading level0 col7" >nonsystematic</th>        <th class="col_heading level0 col8" >spread</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5de70_level0_row0" class="row_heading level0 row0" >F17</th>
#                         <td id="T_5de70_row0_col0" class="data row0 col0" >965</td>
#                         <td id="T_5de70_row0_col1" class="data row0 col1" >-1.2</td>
#                         <td id="T_5de70_row0_col2" class="data row0 col2" >2.7</td>
#                         <td id="T_5de70_row0_col3" class="data row0 col3" >0.1</td>
#                         <td id="T_5de70_row0_col4" class="data row0 col4" >0.31</td>
#                         <td id="T_5de70_row0_col5" class="data row0 col5" >6.7</td>
#                         <td id="T_5de70_row0_col6" class="data row0 col6" >1.9</td>
#                         <td id="T_5de70_row0_col7" class="data row0 col7" >1.9</td>
#                         <td id="T_5de70_row0_col8" class="data row0 col8" >0.36</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Bias is improving in time.
