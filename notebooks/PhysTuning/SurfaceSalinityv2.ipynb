# %% [markdown]
# # Evaluate Surface Salinity

# %% [markdown]
# ## Salinity top 5 m

# %%
import cmocean.cm as cm
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy import stats
import xarray as xr

# %%
foramt = "{:.2}"
myformat = {'bias': foramt, 'rmse': foramt, 'swillmott': foramt, 'slopedev': foramt, 'const': foramt,
                         'systematic': foramt, 'nonsystematic':foramt, 
                    'spread': foramt}

# %%
def bias(df, obs, mod):
    diffy = df[mod] - df[obs]
    return diffy.count(), diffy.mean()

# %%
def rmse(df, obs, mod):
    return (np.sqrt(((df[mod] - df[obs])**2).mean()))

# %%
def swillmott(df, obs, mod):
    meanobs = df[obs].mean()
    return (((df[mod] - df[obs])**2).sum()
            /(( (df[mod] - meanobs).abs() + (df[obs] - meanobs).abs() )**2).sum())

# %%
def slope_inter(df, obs, mod):
    X = df[obs]
    y = df[mod]
    X2 = X**2
    X2 = X**2
    X3 = X**3
    X4 = X**4
    X5 = X**5
    X6 = X**6
#    X = np.column_stack((X, X2, X3, X4, X5, X6))
    X = sm.add_constant(X)

    # Fit and make the predictions by the model
    model = sm.OLS(y, X, missing='drop').fit()
    predictions = model.predict(X)
    
    nonsyst = np.sqrt(((y - predictions)**2).mean())
    systematic = np.sqrt(((predictions - df[obs])**2).mean())
#    print (model.params)
    return predictions, model.params['SA'], model.params['SA'], model.params['const'], systematic, nonsyst

# %%
def spread(df, obs, mod):
    return 1 - ((df[mod] - df[mod].mean())**2).mean() / ((df[obs] - df[obs].mean())**2).mean()

# %%
def read_pieces(pieces):
    temp1 = pd.read_csv(pieces[0])
    if 'ferry' in pieces[0]:
        temp1['k'] = 1.5
    for piece in pieces[1:]:
        nextpiece = pd.read_csv(piece)
        if 'ferry' in piece:
            nextpiece['k'] = 1.5
        temp1 = pd.concat([temp1, nextpiece], ignore_index=True)
    return temp1

# %%
def triple_plots(dowhich, temp1, temp2, temp3):
    No = "No"
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))
    if dowhich[0] != No:
        answer1 = plot_and_stats(fig, axs[0], temp1, dowhich[0])
    else:
        answer1 = No
    if dowhich[1] != No:
        answer2 = plot_and_stats(fig, axs[1], temp2, dowhich[1])
    else:
        answer2 = No
    if dowhich[2] != No:
        answer3 = plot_and_stats(fig, axs[2], temp3, dowhich[2])
    else:
        answer3 = No
    return answer1, answer2, answer3

# %%
def plot_and_stats(fig, ax, temp1, name, withpred=True, witharrows=True):
    vmax = 34
    vmin = 0
    condition = temp1.k < 5
    title = 'Salinity top 5 m'
    counts, xedges, yedges, color = ax.hist2d(temp1.SA[condition], temp1.mod_vosaline[condition], 
                                           bins=np.arange(vmin, vmax, 0.5), norm=LogNorm());
    fig.colorbar(color, ax=ax)
    number, tbias = bias(temp1[condition], 'SA', 'mod_vosaline')
    trmse = rmse(temp1[condition], 'SA', 'mod_vosaline')
    tswillmott = swillmott(temp1[condition], 'SA', 'mod_vosaline')
    predictions, m2, m, c, syst, nonsyst = slope_inter(temp1[condition], 'SA', 'mod_vosaline')
    tspread = spread(temp1[condition], 'SA', 'mod_vosaline')
    ax.plot([vmin, vmax], [vmin, vmax], 'w-');
    xr = np.arange(vmin, vmax, 0.5)
    if withpred:
        ax.plot(temp1.SA[condition], predictions, 'r.')
    if witharrows:
        ax.arrow(3, 27, 0, 1-tbias/2, head_width=0.5, head_length=0.2, length_includes_head=True)
        ax.arrow(3, 29, 0, -1+tbias/2, head_width=0.5, head_length=0.2, length_includes_head=True)
        ax.arrow(4, 27, 0, 1-syst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
        ax.arrow(4, 29, 0, -1+syst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
        ax.arrow(5, 27, 0, 1-nonsyst/2, head_width=0.5, head_length=0.2, length_includes_head=True)
        ax.arrow(5, 29, 0, -1+nonsyst/2, head_width=0.5, head_length=0.2, length_includes_head=True);
    Cp2 = {'number': number,
            'bias': tbias,
          'rmse': trmse,
          'swillmott': tswillmott,
          'slopedev': 1-m,
          'const': c,
          'systematic': syst,
          'nonsystematic': nonsyst,
          'spread': tspread}
    if witharrows:
        ax.text(3-0.2, 22, 'bias', rotation=90)
        ax.text(4-0.2, 21, 'systematic', rotation=90)
        ax.text(5-0.2, 20, 'non-systematic', rotation=90)
        ax.set_title(f'{name}, {title}');
    dCp2 = pd.DataFrame(data=Cp2, index=[name])
    return dCp2

# %%
def cleanup_ferry(temp3):
    return temp3[((temp3.SA > 0.2) | (temp3.mod_vosaline - temp3.SA < 20)) & ((temp3.Lon > -123.8) | (temp3.SA > 14))]

# %%
def highlight_max_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = abs(s) == abs(s).max()
    is_min = abs(s) == abs(s).min()
    color = []
    for v, v2 in zip(is_max, is_min):
        if v:
            color.append('red')
        elif v2:
            color.append('darkgreen')
        else:
            color.append('black')
    return ['color: %s' % color[i] for i in range(len(is_max))]

# %%
pieces1 = ('/home/sallen/202007/H201812/ObsModel_H201812_ctd_20150101_20151231.csv',
         '/home/sallen/202007/H201812/ObsModel_H201812_ctd_20160101_20161231.csv',
    #     '/home/sallen/202007/H201812/ObsModel_H201812_ctd_20170101_20171231.csv',
         '/home/sallen/202007/H201812/ObsModel_H201812_psfts_20150101_20151231.csv',
         '/home/sallen/202007/H201812/ObsModel_H201812_psfts_20160101_20161231.csv',
     #     '/home/sallen/202007/H201812/ObsModel_H201812_psfts_20170101_20171231.csv',
          '/home/sallen/202007/H201812/ObsModel_H201812_pugts_20150101_20151231.csv',
          '/home/sallen/202007/H201812/ObsModel_H201812_pugts_20160101_20161231.csv',
     #     '/home/sallen/202007/H201812/ObsModel_H201812_pugts_20170101_20171231.csv',
          )
pieces2 = (
          '/home/sallen/202007/H201812/ObsModel_H201812_ferry_20150101_20151231.csv',
          '/home/sallen/202007/H201812/ObsModel_H201812_ferry_20160101_20161231.csv',
     #     '/home/sallen/202007/H201812/ObsModel_H201812_ferry_20170101_20171231.csv',
         )

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['H201812o', 'H201812f', 'No'] 

d201812o, d201812f, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)
alltogether = pd.concat([d201812o, d201812f], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_02b74_row0_col0, #T_02b74_row0_col1, #T_02b74_row0_col2, #T_02b74_row0_col3, #T_02b74_row0_col4, #T_02b74_row0_col5, #T_02b74_row0_col6, #T_02b74_row0_col7, #T_02b74_row0_col8 {
#   color: darkgreen;
# }
# #T_02b74_row1_col0, #T_02b74_row1_col1, #T_02b74_row1_col2, #T_02b74_row1_col3, #T_02b74_row1_col4, #T_02b74_row1_col5, #T_02b74_row1_col6, #T_02b74_row1_col7, #T_02b74_row1_col8 {
#   color: red;
# }
# </style>
# <table id="T_02b74_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02b74_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_02b74_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_02b74_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_02b74_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_02b74_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_02b74_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_02b74_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_02b74_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_02b74_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_02b74_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_02b74_level0_row1" class="row_heading level0 row1" >H201812f</th>
#       <td id="T_02b74_row1_col0" class="data row1 col0" >251530</td>
#       <td id="T_02b74_row1_col1" class="data row1 col1" >2.1</td>
#       <td id="T_02b74_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_02b74_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_02b74_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_02b74_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_02b74_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_02b74_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_02b74_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/H201905/ObsModel_H201905_ctd_20150101_20151231.csv',
         '/home/sallen/202007/H201905/ObsModel_H201905_ctd_20160101_20161231.csv',
   #      '/home/sallen/202007/H201905/ObsModel_H201905_ctd_20170101_20171231.csv',
         '/home/sallen/202007/H201905/ObsModel_H201905_psfts_20150101_20151231.csv',
         '/home/sallen/202007/H201905/ObsModel_H201905_psfts_20160101_20161231.csv',
   #       '/home/sallen/202007/H201905/ObsModel_H201905_psfts_20170101_20171231.csv',
          '/home/sallen/202007/H201905/ObsModel_H201905_pugts_20150101_20151231.csv',
          '/home/sallen/202007/H201905/ObsModel_H201905_pugts_20160101_20161231.csv',
   #       '/home/sallen/202007/H201905/ObsModel_H201905_pugts_20170101_20171231.csv',
          )
pieces2 = (
          '/home/sallen/202007/H201905/ObsModel_H201905_ferry_20150101_20151231.csv',
          '/home/sallen/202007/H201905/ObsModel_H201905_ferry_20160101_20161231.csv',
   #       '/home/sallen/202007/H201905/ObsModel_H201905_ferry_20170101_20171231.csv'
         )

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['H201905o', 'H201905f', 'No'] 

d201905o, d201905f, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)
alltogether = pd.concat([d201812o, d201812f, d201905o, d201905f], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_6030c_row0_col0, #T_6030c_row0_col1, #T_6030c_row0_col2, #T_6030c_row0_col6, #T_6030c_row2_col0, #T_6030c_row2_col3, #T_6030c_row2_col4, #T_6030c_row2_col5, #T_6030c_row2_col7, #T_6030c_row2_col8 {
#   color: darkgreen;
# }
# #T_6030c_row0_col3, #T_6030c_row0_col4, #T_6030c_row0_col5, #T_6030c_row0_col7, #T_6030c_row0_col8, #T_6030c_row1_col4, #T_6030c_row1_col7, #T_6030c_row2_col1, #T_6030c_row2_col2, #T_6030c_row2_col6, #T_6030c_row3_col0, #T_6030c_row3_col1, #T_6030c_row3_col2, #T_6030c_row3_col3, #T_6030c_row3_col5, #T_6030c_row3_col6, #T_6030c_row3_col8 {
#   color: black;
# }
# #T_6030c_row1_col0, #T_6030c_row1_col1, #T_6030c_row1_col2, #T_6030c_row1_col3, #T_6030c_row1_col5, #T_6030c_row1_col6, #T_6030c_row1_col8, #T_6030c_row3_col4, #T_6030c_row3_col7 {
#   color: red;
# }
# </style>
# <table id="T_6030c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6030c_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_6030c_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_6030c_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_6030c_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_6030c_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_6030c_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_6030c_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_6030c_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_6030c_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_6030c_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_6030c_level0_row1" class="row_heading level0 row1" >H201812f</th>
#       <td id="T_6030c_row1_col0" class="data row1 col0" >251530</td>
#       <td id="T_6030c_row1_col1" class="data row1 col1" >2.1</td>
#       <td id="T_6030c_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_6030c_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_6030c_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_6030c_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_6030c_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_6030c_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_6030c_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_6030c_level0_row2" class="row_heading level0 row2" >H201905o</th>
#       <td id="T_6030c_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_6030c_row2_col1" class="data row2 col1" >-0.76</td>
#       <td id="T_6030c_row2_col2" class="data row2 col2" >2.3</td>
#       <td id="T_6030c_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_6030c_row2_col4" class="data row2 col4" >0.074</td>
#       <td id="T_6030c_row2_col5" class="data row2 col5" >1.3</td>
#       <td id="T_6030c_row2_col6" class="data row2 col6" >0.86</td>
#       <td id="T_6030c_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_6030c_row2_col8" class="data row2 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_6030c_level0_row3" class="row_heading level0 row3" >H201905f</th>
#       <td id="T_6030c_row3_col0" class="data row3 col0" >251528</td>
#       <td id="T_6030c_row3_col1" class="data row3 col1" >2.0</td>
#       <td id="T_6030c_row3_col2" class="data row3 col2" >5.2</td>
#       <td id="T_6030c_row3_col3" class="data row3 col3" >0.24</td>
#       <td id="T_6030c_row3_col4" class="data row3 col4" >0.53</td>
#       <td id="T_6030c_row3_col5" class="data row3 col5" >1.3e+01</td>
#       <td id="T_6030c_row3_col6" class="data row3 col6" >3.9</td>
#       <td id="T_6030c_row3_col7" class="data row3 col7" >3.5</td>
#       <td id="T_6030c_row3_col8" class="data row3 col8" >0.47</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ctd_20150101_20151231.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TSPUG_20150101-20151231.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ctd_20160101_20161231.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TSPUG_20160101-20161231.csv',
       #  '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TS_20170101-20170331.csv',
       #  '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TS_20170401-20170630.csv',
       #  '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TS_20170701-20170930.csv',
       #  '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TS_20171001-20171231.csv',
       #  '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_TSPUG_20170101-20171231.csv',   
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_psfts_20150101_20151231.csv',
          '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_psfts_20160101_20161231.csv',
       #   '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_psfts_20170101_20171231.csv'
         )
pieces2 = (
      '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20150101_20150331.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20150401_20150630.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20150701_20150930.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20151001_20151231.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20160101_20160331.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20160301_20160630.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20160601_20160930.csv',
         '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20161001_20161231.csv',
     #    '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20170101_20170331.csv',
     #    '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20170401_20170630.csv',
     #    '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20170701_20170930.csv',
     #    '/home/sallen/202007/202007C-p2/ObsModel_202007Cp2_ferry_20171001_20171231.csv',
)

# %%
temp1 = read_pieces(pieces1)
#temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
#temp1['SA'] = temp1['salinity (g/kg)']
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['Cp2o', 'Cp2f', 'No'] 

Cp2o, Cp2f, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)
alltogether = pd.concat([d201812o, d201812f, d201905o, d201905f, Cp2o, Cp2f], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_7ccfe_row0_col0, #T_7ccfe_row0_col1, #T_7ccfe_row0_col6, #T_7ccfe_row2_col0, #T_7ccfe_row2_col8, #T_7ccfe_row4_col0, #T_7ccfe_row4_col2, #T_7ccfe_row4_col3, #T_7ccfe_row4_col4, #T_7ccfe_row4_col5, #T_7ccfe_row4_col7 {
#   color: darkgreen;
# }
# #T_7ccfe_row0_col2, #T_7ccfe_row0_col3, #T_7ccfe_row0_col4, #T_7ccfe_row0_col5, #T_7ccfe_row0_col7, #T_7ccfe_row0_col8, #T_7ccfe_row1_col0, #T_7ccfe_row1_col2, #T_7ccfe_row1_col3, #T_7ccfe_row1_col4, #T_7ccfe_row1_col5, #T_7ccfe_row1_col6, #T_7ccfe_row1_col7, #T_7ccfe_row2_col1, #T_7ccfe_row2_col2, #T_7ccfe_row2_col3, #T_7ccfe_row2_col4, #T_7ccfe_row2_col5, #T_7ccfe_row2_col6, #T_7ccfe_row2_col7, #T_7ccfe_row3_col0, #T_7ccfe_row3_col1, #T_7ccfe_row3_col2, #T_7ccfe_row3_col3, #T_7ccfe_row3_col4, #T_7ccfe_row3_col5, #T_7ccfe_row3_col6, #T_7ccfe_row3_col7, #T_7ccfe_row3_col8, #T_7ccfe_row4_col1, #T_7ccfe_row4_col6, #T_7ccfe_row4_col8, #T_7ccfe_row5_col1, #T_7ccfe_row5_col8 {
#   color: black;
# }
# #T_7ccfe_row1_col1, #T_7ccfe_row1_col8, #T_7ccfe_row5_col0, #T_7ccfe_row5_col2, #T_7ccfe_row5_col3, #T_7ccfe_row5_col4, #T_7ccfe_row5_col5, #T_7ccfe_row5_col6, #T_7ccfe_row5_col7 {
#   color: red;
# }
# </style>
# <table id="T_7ccfe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ccfe_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_7ccfe_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_7ccfe_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_7ccfe_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_7ccfe_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_7ccfe_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_7ccfe_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_7ccfe_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_7ccfe_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_7ccfe_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_7ccfe_level0_row1" class="row_heading level0 row1" >H201812f</th>
#       <td id="T_7ccfe_row1_col0" class="data row1 col0" >251530</td>
#       <td id="T_7ccfe_row1_col1" class="data row1 col1" >2.1</td>
#       <td id="T_7ccfe_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_7ccfe_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_7ccfe_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_7ccfe_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_7ccfe_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_7ccfe_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_7ccfe_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_7ccfe_level0_row2" class="row_heading level0 row2" >H201905o</th>
#       <td id="T_7ccfe_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_7ccfe_row2_col1" class="data row2 col1" >-0.76</td>
#       <td id="T_7ccfe_row2_col2" class="data row2 col2" >2.3</td>
#       <td id="T_7ccfe_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_7ccfe_row2_col4" class="data row2 col4" >0.074</td>
#       <td id="T_7ccfe_row2_col5" class="data row2 col5" >1.3</td>
#       <td id="T_7ccfe_row2_col6" class="data row2 col6" >0.86</td>
#       <td id="T_7ccfe_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_7ccfe_row2_col8" class="data row2 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_7ccfe_level0_row3" class="row_heading level0 row3" >H201905f</th>
#       <td id="T_7ccfe_row3_col0" class="data row3 col0" >251528</td>
#       <td id="T_7ccfe_row3_col1" class="data row3 col1" >2.0</td>
#       <td id="T_7ccfe_row3_col2" class="data row3 col2" >5.2</td>
#       <td id="T_7ccfe_row3_col3" class="data row3 col3" >0.24</td>
#       <td id="T_7ccfe_row3_col4" class="data row3 col4" >0.53</td>
#       <td id="T_7ccfe_row3_col5" class="data row3 col5" >1.3e+01</td>
#       <td id="T_7ccfe_row3_col6" class="data row3 col6" >3.9</td>
#       <td id="T_7ccfe_row3_col7" class="data row3 col7" >3.5</td>
#       <td id="T_7ccfe_row3_col8" class="data row3 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_7ccfe_level0_row4" class="row_heading level0 row4" >Cp2o</th>
#       <td id="T_7ccfe_row4_col0" class="data row4 col0" >27425</td>
#       <td id="T_7ccfe_row4_col1" class="data row4 col1" >-0.74</td>
#       <td id="T_7ccfe_row4_col2" class="data row4 col2" >2.2</td>
#       <td id="T_7ccfe_row4_col3" class="data row4 col3" >0.11</td>
#       <td id="T_7ccfe_row4_col4" class="data row4 col4" >0.071</td>
#       <td id="T_7ccfe_row4_col5" class="data row4 col5" >1.2</td>
#       <td id="T_7ccfe_row4_col6" class="data row4 col6" >0.84</td>
#       <td id="T_7ccfe_row4_col7" class="data row4 col7" >2.1</td>
#       <td id="T_7ccfe_row4_col8" class="data row4 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_7ccfe_level0_row5" class="row_heading level0 row5" >Cp2f</th>
#       <td id="T_7ccfe_row5_col0" class="data row5 col0" >257271</td>
#       <td id="T_7ccfe_row5_col1" class="data row5 col1" >2.1</td>
#       <td id="T_7ccfe_row5_col2" class="data row5 col2" >5.3</td>
#       <td id="T_7ccfe_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_7ccfe_row5_col4" class="data row5 col4" >0.54</td>
#       <td id="T_7ccfe_row5_col5" class="data row5 col5" >1.3e+01</td>
#       <td id="T_7ccfe_row5_col6" class="data row5 col6" >4.0</td>
#       <td id="T_7ccfe_row5_col7" class="data row5 col7" >3.6</td>
#       <td id="T_7ccfe_row5_col8" class="data row5 col8" >0.47</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/202007D-again/ObsModel_202007D-again_TS_20150101-20150331.csv',
         '/home/sallen/202007/202007D-again/ObsModel_202007D-again_TS_20150401-20150630.csv',
         '/home/sallen/202007/202007D-again/ObsModel_202007D-again_TS_20150701-20150930.csv',
         '/home/sallen/202007/202007D-again/ObsModel_202007D-again_TS_20151001-20151231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_psfts_20150101_20151231.csv',
         '/home/sallen/202007/202007D-again/ObsModel_202007D-again_pugts_20150101_20151231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_ctd_20160101_20161231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_psfts_20160101_20161231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_pugts_20160101_20161231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_ctd_20170101_20171231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_psfts_20170101_20171231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_pugts_20170101_20171231.csv',
         )
pieces2 = (
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_ferry_20150101_20151231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_ferry_20160101_20161231.csv',
          '/home/sallen/202007/202007D-again/ObsModel_202007D-again_ferry_20170101_20171231.csv'
        )

# %%
temp1 = read_pieces(pieces1)
#temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
#temp1['SA'] = temp1['salinity (g/kg)']
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['Dagaino', 'Dagainf', 'No'] 

Dagaino, Dagainf, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)
alltogether = pd.concat([d201812o, d201812f, d201905o, d201905f, Cp2o, Cp2f, Dagaino, Dagainf], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_9e34a_row0_col0, #T_9e34a_row0_col1, #T_9e34a_row0_col6, #T_9e34a_row2_col0, #T_9e34a_row2_col8, #T_9e34a_row4_col0, #T_9e34a_row4_col2, #T_9e34a_row4_col7, #T_9e34a_row6_col3, #T_9e34a_row6_col4, #T_9e34a_row6_col5 {
#   color: darkgreen;
# }
# #T_9e34a_row0_col2, #T_9e34a_row0_col3, #T_9e34a_row0_col4, #T_9e34a_row0_col5, #T_9e34a_row0_col7, #T_9e34a_row0_col8, #T_9e34a_row1_col0, #T_9e34a_row1_col2, #T_9e34a_row1_col3, #T_9e34a_row1_col4, #T_9e34a_row1_col5, #T_9e34a_row1_col6, #T_9e34a_row1_col7, #T_9e34a_row2_col1, #T_9e34a_row2_col2, #T_9e34a_row2_col3, #T_9e34a_row2_col4, #T_9e34a_row2_col5, #T_9e34a_row2_col6, #T_9e34a_row2_col7, #T_9e34a_row3_col0, #T_9e34a_row3_col1, #T_9e34a_row3_col2, #T_9e34a_row3_col3, #T_9e34a_row3_col4, #T_9e34a_row3_col5, #T_9e34a_row3_col6, #T_9e34a_row3_col7, #T_9e34a_row3_col8, #T_9e34a_row4_col1, #T_9e34a_row4_col3, #T_9e34a_row4_col4, #T_9e34a_row4_col5, #T_9e34a_row4_col6, #T_9e34a_row4_col8, #T_9e34a_row5_col0, #T_9e34
col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_9e34a_level0_row5" class="row_heading level0 row5" >Cp2f</th>
#       <td id="T_9e34a_row5_col0" class="data row5 col0" >257271</td>
#       <td id="T_9e34a_row5_col1" class="data row5 col1" >2.1</td>
#       <td id="T_9e34a_row5_col2" class="data row5 col2" >5.3</td>
#       <td id="T_9e34a_row5_col3" class="data row5 col3" >0.25</td>
#       <td id="T_9e34a_row5_col4" class="data row5 col4" >0.54</td>
#       <td id="T_9e34a_row5_col5" class="data row5 col5" >1.3e+01</td>
#       <td id="T_9e34a_row5_col6" class="data row5 col6" >4.0</td>
#       <td id="T_9e34a_row5_col7" class="data row5 col7" >3.6</td>
#       <td id="T_9e34a_row5_col8" class="data row5 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_9e34a_level0_row6" class="row_heading level0 row6" >Dagaino</th>
#       <td id="T_9e34a_row6_col0" class="data row6 col0" >39304</td>
#       <td id="T_9e34a_row6_col1" class="data row6 col1" >-0.77</td>
#       <td id="T_9e34a_row6_col2" class="data row6 col2" >2.3</td>
#       <td id="T_9e34a_row6_col3" class="data row6 col3" >0.1</td>
#       <td id="T_9e34a_row6_col4" class="data row6 col4" >0.057</td>
#       <td id="T_9e34a_row6_col5" class="data row6 col5" >0.77</td>
#       <td id="T_9e34a_row6_col6" class="data row6 col6" >0.85</td>
#       <td id="T_9e34a_row6_col7" class="data row6 col7" >2.1</td>
#       <td id="T_9e34a_row6_col8" class="data row6 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_9e34a_level0_row7" class="row_heading level0 row7" >Dagainf</th>
#       <td id="T_9e34a_row7_col0" class="data row7 col0" >414515</td>
#       <td id="T_9e34a_row7_col1" class="data row7 col1" >1.8</td>
#       <td id="T_9e34a_row7_col2" class="data row7 col2" >5.2</td>
#       <td id="T_9e34a_row7_col3" class="data row7 col3" >0.22</td>
#       <td id="T_9e34a_row7_col4" class="data row7 col4" >0.51</td>
#       <td id="T_9e34a_row7_col5" class="data row7 col5" >1.2e+01</td>
#       <td id="T_9e34a_row7_col6" class="data row7 col6" >3.7</td>
#       <td id="T_9e34a_row7_col7" class="data row7 col7" >3.6</td>
#       <td id="T_9e34a_row7_col8" class="data row7 col8" >0.45</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ctd_20150101_20151231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ctd_20160101_20161231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ctd_20170101_20171231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_psfts_20150101_20151231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_psfts_20160101_20161231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_psfts_20170101_20171231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_pugts_20150101_20151231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_pugts_20160101_20161231.csv',
        '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_pugts_20170101_20171231.csv', 
         )
pieces2 = (
         '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ferry_20150101_20151231.csv',     
         '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ferry_20160101_20161231.csv',
         '/home/sallen/202007/202007D-nociliates/ObsModel_202007D-nociliates_ferry_20170101_20171231.csv'
         )

# %%
temp1 = read_pieces(pieces1)
#temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
#temp1['SA'] = temp1['salinity (g/kg)']
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['DnoCilo', 'DnoCilf', 'No'] 

DnoCilo, DnoCilf, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)
alltogether = pd.concat([d201812o, d201812f, d201905o, d201905f, Cp2o, Cp2f, Dagaino, Dagainf,
                        DnoCilo, DnoCilf], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_c78d1_row0_col0, #T_c78d1_row0_col1, #T_c78d1_row0_col6, #T_c78d1_row2_col0, #T_c78d1_row2_col8, #T_c78d1_row4_col0, #T_c78d1_row4_col2, #T_c78d1_row4_col7, #T_c78d1_row8_col3, #T_c78d1_row8_col4, #T_c78d1_row8_col5 {
#   color: darkgreen;
# }
# #T_c78d1_row0_col2, #T_c78d1_row0_col3, #T_c78d1_row0_col4, #T_c78d1_row0_col5, #T_c78d1_row0_col7, #T_c78d1_row0_col8, #T_c78d1_row1_col0, #T_c78d1_row1_col2, #T_c78d1_row1_col3, #T_c78d1_row1_col4, #T_c78d1_row1_col5, #T_c78d1_row1_col6, #T_c78d1_row1_col7, #T_c78d1_row2_col1, #T_c78d1_row2_col2, #T_c78d1_row2_col3, #T_c78d1_row2_col4, #T_c78d1_row2_col5, #T_c78d1_row2_col6, #T_c78d1_row2_col7, #T_c78d1_row3_col0, #T_c78d1_row3_col1, #T_c78d1_row3_col2, #T_c78d1_row3_col3, #T_c78d1_row3_col4, #T_c78d1_row3_col5, #T_c78d1_row3_col6, #T_c78d1_row3_col7, #T_c78d1_row3_col8, #T_c78d1_row4_col1, #T_c78d1_row4_col3, #T_c78d1_row4_col4, #T_c78d1_row4_col5, #T_c78d1_row4_col6, #T_c78d1_row4_col8, #T_c78d1_row5_col0, #T_c78d1_row5_col1, #T_c78d1_row5_col8, #T_c78d1_row6_col0, #T_c78d1_row6_col1, #T_c78d1_row6_col2, #T_c78d1_row6_col3, #T_c78d1_row6_col4, #T_c78d1_row6_col5, #T_c78d1_row6_col6, #T_c78d1_row6_col7, #T_c78d1_row6_col8, #T_c78d1_row7_col1, #T_c78d1_row7_col2, #T_c78d1_row7_col3, #T_c78d1_row7_col4, #T_c78d1_row7_col5, #T_c78d1_row7_col6, #T_c78d1_row7_col7, #T_c78d1_row7_col8, #T_c78d1_row8_col0, #T_c78d1_row8_col1, #T_c78d1_row8_col2, #T_c78d1_row8_col6, #T_c78d1_row8_col7, #T_c78d1_row8_col8, #T_c78d1_row9_col0, #T_c78d1_row9_col1, #T_c78d1_row9_col2, #T_c78d1_row9_col3, #T_c78d1_row9_col4, #T_c78d1_row9_col5, #T_c78d1_row9_col6, #T_c78d1_row9_col7, #T_c78d1_row9_col8 {
#   color: black;
# }
# #T_c78d1_row1_col1, #T_c78d1_row1_col8, #T_c78d1_row5_col2, #T_c78d1_row5_col3, #T_c78d1_row5_col4, #T_c78d1_row5_col5, #T_c78d1_row5_col6, #T_c78d1_row5_col7, #T_c78d1_row7_col0 {
#   color: red;
# }
# </style>
# <table id="T_c78d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c78d1_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_c78d1_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_c78d1_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_c78d1_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_c78d1_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_c78d1_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_c78d1_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_c78d1_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_c78d1_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_c78d1_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_c78d1_level0_row1" class="row_heading level0 row1" >H201812f</th>
#       <td id="T_c78d1_row1_col0" class="data row1 col0" >251530</td>
#       <td id="T_c78d1_row1_col1" class="data row1 col1" >2.1</td>
#       <td id="T_c78d1_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_c78d1_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_c78d1_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_c78d1_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_c78d1_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_c78d1_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_c78d1_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_c78d1_level0_row2" class="row_heading level0 row2" >H201905o</th>
#       <td id="T_c78d1_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_c78d1_row2_col1" class="data row2 col1" >-0.76</td>
#       <td id="T_c78d1_row2_col2" class="data row2 col2" >2.3</td>
#       <td id="T_c78d1_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T
col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_c78d1_level0_row7" class="row_heading level0 row7" >Dagainf</th>
#       <td id="T_c78d1_row7_col0" class="data row7 col0" >414515</td>
#       <td id="T_c78d1_row7_col1" class="data row7 col1" >1.8</td>
#       <td id="T_c78d1_row7_col2" class="data row7 col2" >5.2</td>
#       <td id="T_c78d1_row7_col3" class="data row7 col3" >0.22</td>
#       <td id="T_c78d1_row7_col4" class="data row7 col4" >0.51</td>
#       <td id="T_c78d1_row7_col5" class="data row7 col5" >1.2e+01</td>
#       <td id="T_c78d1_row7_col6" class="data row7 col6" >3.7</td>

# %%
pieces1 = ('/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ctd_20150101_20151231.csv',
          '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_psfts_20150101_20151231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_pugts_20150101_20151231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ctd_20160101_20161231.csv',
          '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_psfts_20160101_20161231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_pugts_20160101_20161231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ctd_20170101_20171231.csv',
          '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_psfts_20170101_20171231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_pugts_20170101_20171231.csv',
         )
pieces2 = (
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ferry_20150101_20151231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ferry_20160101_20161231.csv',
         '/home/sallen/202007/202007D-lowR/ObsModel_202007D-lowR_ferry_20170101_20171231.csv'
         )

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

dowhich = ['DLowRo', 'DLowRf', 'No'] 

DLowRo, DLowRf, stuff = triple_plots(dowhich, temp1, cleanup_ferry(temp2), temp1)

alltogethero = pd.concat([d201812o, d201905o,  Cp2o,  Dagaino, 
                        DnoCilo,  DLowRo,], axis=0)
alltogetherf = pd.concat([d201812f,  d201905f,  Cp2f,  Dagainf,
                         DnoCilf,  DLowRf], axis=0)
alltogethero.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_878f7_row0_col0, #T_878f7_row0_col1, #T_878f7_row0_col6, #T_878f7_row1_col0, #T_878f7_row1_col8, #T_878f7_row2_col0, #T_878f7_row2_col2, #T_878f7_row2_col7, #T_878f7_row4_col3, #T_878f7_row5_col4, #T_878f7_row5_col5 {
#   color: darkgreen;
# }
# #T_878f7_row0_col2, #T_878f7_row0_col7, #T_878f7_row0_col8, #T_878f7_row1_col1, #T_878f7_row1_col2, #T_878f7_row1_col3, #T_878f7_row1_col4, #T_878f7_row1_col5, #T_878f7_row1_col7, #T_878f7_row2_col1, #T_878f7_row2_col3, #T_878f7_row2_col4, #T_878f7_row2_col5, #T_878f7_row2_col6, #T_878f7_row2_col8, #T_878f7_row3_col0, #T_878f7_row3_col1, #T_878f7_row3_col2, #T_878f7_row3_col3, #T_878f7_row3_col4, #T_878f7_row3_col5, #T_878f7_row3_col6, #T_878f7_row3_col7, #T_878f7_row3_col8, #T_878f7_row4_col1, #T_878f7_row4_col2, #T_878f7_row4_col4, #T_878f7_row4_col5, #T_878f7_row4_col6, #T_878f7_row4_col7, #T_878f7_row4_col8, #T_878f7_row5_col3, #T_878f7_row5_col6 {
#   color: black;
# }
# #T_878f7_row0_col3, #T_878f7_row0_col4, #T_878f7_row0_col5, #T_878f7_row1_col6, #T_878f7_row4_col0, #T_878f7_row5_col0, #T_878f7_row5_col1, #T_878f7_row5_col2, #T_878f7_row5_col7, #T_878f7_row5_col8 {
#   color: red;
# }
# </style>
# <table id="T_878f7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_878f7_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_878f7_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_878f7_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_878f7_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_878f7_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_878f7_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_878f7_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_878f7_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_878f7_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_878f7_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_878f7_level0_row1" class="row_heading level0 row1" >H201905o</th>
#       <td id="T_878f7_row1_col0" class="data row1 col0" >27425</td>
#       <td id="T_878f7_row1_col1" class="data row1 col1" >-0.76</td>
#       <td id="T_878f7_row1_col2" class="data row1 col2" >2.3</td>
#       <td id="T_878f7_row1_col3" class="data row1 col3" >0.11</td>
#       <td id="T_878f7_row1_col4" class="data row1 col4" >0.074</td>
#       <td id="T_878f7_row1_col5" class="data row1 col5" >1.3</td>
#       <td id="T_878f7_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_878f7_row1_col7" class="data row1 col7" >2.1</td>
#       <td id="T_878f7_row1_col8" class="data row1 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_878f7_level0_row2" class="row_heading level0 row2" >Cp2o</th>
#       <td id="T_878f7_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_878f7_row2_col1" class="data row2 col1" >-0.74</td>
#       <td id="T_878f7_row2_col2" class="data row2 col2" >2.2</td>
#       <td id="T_878f7_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_878f7_row2_col4" class="data row2 col4" >0.071</td>
#       <td id="T_878f7_row2_col5" class="data row2 col5" >1.2</td>
#       <td id="T_878f7_row2_col6" class="data row2 col6" >0.84</td>
#       <td id="T_878f7_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_878f7_row2_col8" class="data row2 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_878f7_level0_row3" class="row_heading level0 row3" >Dagaino</th>
#       <td id="T_878f7_row3_col0" class="data row3 col0" >39304</td>
#       <td id="T_878f7_row3_col1" class="data row3 col1" >-0.77</td>
#       <td id="T_878f7_row3_col2" class="data row3 col2" >2.3</td>
#       <td id="T_878f7_row3_col3" class="data row3 col3" >0.1</td>
#       <td id="T_878f7_row3_col4" class="data row3 col4" >0.057</td>
#       <td id="T_878f7_row3_col5" class="data row3 col5" >0.77</td>
#       <td id="T_878f7_row3_col6" class="data row3 col6" >0.85</td>
#       <td id="T_878f7_row3_col7" class="data row3 col7" >2.1</td>
#       <td id="T_878f7_row3_col8" class="data row3 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_878f7_level0_row4" class="row_heading level0 row4" >DnoCilo</th>
#       <td id="T_878f7_row4_col0" class="data row4 col0" >39364</td>
#       <td id="T_878f7_row4_col1" class="data row4 col1" >-0.79</td>
#       <td id="T_878f7_row4_col2" class="data row4 col2" >2.3</td>
#       <td id="T_878f7_row4_col3" class="data row4 col3" >0.1</td>
#       <td id="T_878f7_row4_col4" class="data row4 col4" >0.047</td>
#       <td id="T_878f7_row4_col5" class="data row4 col5" >0.46</td>
#       <td id="T_878f7_row4_col6" class="data row4 col6" >0.86</td>
#       <td id="T_878f7_row4_col7" class="data row4 col7" >2.1</td>
#       <td id="T_878f7_row4_col8" class="data row4 col8" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_878f7_level0_row5" class="row_heading level0 row5" >DLowRo</th>
#       <td id="T_878f7_row5_col0" class="data row5 col0" >39364</td>
#       <td id="T_878f7_row5_col1" class="data row5 col1" >-0.79</td>
#       <td id="T_878f7_row5_col2" class="data row5 col2" >2.3</td>
#       <td id="T_878f7_row5_col3" class="data row5 col3" >0.1</td>
#       <td id="T_878f7_row5_col4" class="data row5 col4" >0.046</td>
#       <td id="T_878f7_row5_col5" class="data row5 col5" >0.44</td>
#       <td id="T_878f7_row5_col6" class="data row5 col6" >0.86</td>
#       <td id="T_878f7_row5_col7" class="data row5 col7" >2.2</td>
#       <td id="T_878f7_row5_col8" class="data row5 col8" >-0.38</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogetherf.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_6e474_row0_col0, #T_6e474_row0_col2, #T_6e474_row0_col3, #T_6e474_row0_col4, #T_6e474_row0_col5, #T_6e474_row0_col6, #T_6e474_row1_col1, #T_6e474_row1_col2, #T_6e474_row1_col3, #T_6e474_row1_col4, #T_6e474_row1_col5, #T_6e474_row1_col6, #T_6e474_row1_col7, #T_6e474_row1_col8, #T_6e474_row2_col0, #T_6e474_row2_col1, #T_6e474_row2_col8, #T_6e474_row3_col7, #T_6e474_row4_col0, #T_6e474_row4_col1, #T_6e474_row4_col2, #T_6e474_row4_col3, #T_6e474_row4_col4, #T_6e474_row4_col5, #T_6e474_row4_col6, #T_6e474_row4_col7, #T_6e474_row4_col8, #T_6e474_row5_col0, #T_6e474_row5_col1, #T_6e474_row5_col2, #T_6e474_row5_col3, #T_6e474_row5_col4, #T_6e474_row5_col5, #T_6e474_row5_col6, #T_6e474_row5_col7, #T_6e474_row5_col8 {
#   color: black;
# }
# #T_6e474_row0_col1, #T_6e474_row0_col8, #T_6e474_row2_col2, #T_6e474_row2_col3, #T_6e474_row2_col4, #T_6e474_row2_col5, #T_6e474_row2_col6, #T_6e474_row2_col7, #T_6e474_row3_col0 {
#   color: red;
# }
# #T_6e474_row0_col7, #T_6e474_row1_col0, #T_6e474_row3_col1, #T_6e474_row3_col2, #T_6e474_row3_col3, #T_6e474_row3_col4, #T_6e474_row3_col5, #T_6e474_row3_col6, #T_6e474_row3_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_6e474_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e474_level0_row0" class="row_heading level0 row0" >H201812f</th>
#       <td id="T_6e474_row0_col0" class="data row0 col0" >251530</td>
#       <td id="T_6e474_row0_col1" class="data row0 col1" >2.1</td>
#       <td id="T_6e474_row0_col2" class="data row0 col2" >5.2</td>
#       <td id="T_6e474_row0_col3" class="data row0 col3" >0.24</td>
#       <td id="T_6e474_row0_col4" class="data row0 col4" >0.53</td>
#       <td id="T_6e474_row0_col5" class="data row0 col5" >1.3e+01</td>
#       <td id="T_6e474_row0_col6" class="data row0 col6" >3.9</td>
#       <td id="T_6e474_row0_col7" class="data row0 col7" >3.5</td>
#       <td id="T_6e474_row0_col8" class="data row0 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_6e474_level0_row1" class="row_heading level0 row1" >H201905f</th>
#       <td id="T_6e474_row1_col0" class="data row1 col0" >251528</td>
#       <td id="T_6e474_row1_col1" class="data row1 col1" >2.0</td>
#       <td id="T_6e474_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_6e474_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_6e474_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_6e474_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_6e474_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_6e474_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_6e474_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_6e474_level0_row2" class="row_heading level0 row2" >Cp2f</th>
#       <td id="T_6e474_row2_col0" class="data row2 col0" >257271</td>
#       <td id="T_6e474_row2_col1" class="data row2 col1" >2.1</td>
#       <td id="T_6e474_row2_col2" class="data row2 col2" >5.3</td>
#       <td id="T_6e474_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_6e474_row2_col4" class="data row2 col4" >0.54</td>
#       <td id="T_6e474_row2_col5" class="data row2 col5" >1.3e+01</td>
#       <td id="T_6e474_row2_col6" class="data row2 col6" >4.0</td>
#       <td id="T_6e474_row2_col7" class="data row2 col7" >3.6</td>
#       <td id="T_6e474_row2_col8" class="data row2 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_
# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

temp3 = read_pieces(pieces3)
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

dowhich = ['Cp3o', 'Cp3f', 'Cp3f0'] 

Cp3o, Cp3f, Cp3f0 = triple_plots(dowhich, temp1, cleanup_ferry(temp2), cleanup_ferry(temp3))

alltogethero = pd.concat([d201812o, d201905o,  Cp2o,  #Dagaino, 
                        #DnoCilo,  DLowRo, 
                          Cp3o], axis=0)
alltogetherf = pd.concat([d201812f,  d201905f,  Cp2f,  #Dagainf,
                         #DnoCilf,  DLowRf, 
                          Cp3f, Cp3f0], axis=0)
alltogethero.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_2f720_row0_col0, #T_2f720_row0_col3, #T_2f720_row0_col7, #T_2f720_row1_col0, #T_2f720_row1_col1, #T_2f720_row1_col2, #T_2f720_row1_col6, #T_2f720_row2_col0, #T_2f720_row2_col8, #T_2f720_row3_col0, #T_2f720_row3_col4, #T_2f720_row3_col5 {
#   color: red;
# }
# #T_2f720_row0_col1, #T_2f720_row0_col2, #T_2f720_row0_col4, #T_2f720_row0_col5, #T_2f720_row0_col6, #T_2f720_row0_col8, #T_2f720_row1_col3, #T_2f720_row1_col4, #T_2f720_row1_col5, #T_2f720_row1_col7, #T_2f720_row1_col8, #T_2f720_row2_col1, #T_2f720_row2_col2, #T_2f720_row2_col3, #T_2f720_row2_col6, #T_2f720_row2_col7 {
#   color: black;
# }
# #T_2f720_row2_col4, #T_2f720_row2_col5, #T_2f720_row3_col1, #T_2f720_row3_col2, #T_2f720_row3_col3, #T_2f720_row3_col6, #T_2f720_row3_col7, #T_2f720_row3_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_2f720_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f720_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_2f720_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_2f720_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_2f720_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_2f720_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_2f720_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_2f720_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_2f720_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_2f720_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_2f720_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_2f720_level0_row1" class="row_heading level0 row1" >H201905o</th>
#       <td id="T_2f720_row1_col0" class="data row1 col0" >27425</td>
#       <td id="T_2f720_row1_col1" class="data row1 col1" >-0.76</td>
#       <td id="T_2f720_row1_col2" class="data row1 col2" >2.3</td>
#       <td id="T_2f720_row1_col3" class="data row1 col3" >0.11</td>
#       <td id="T_2f720_row1_col4" class="data row1 col4" >0.074</td>
#       <td id="T_2f720_row1_col5" class="data row1 col5" >1.3</td>
#       <td id="T_2f720_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_2f720_row1_col7" class="data row1 col7" >2.1</td>
#       <td id="T_2f720_row1_col8" class="data row1 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_2f720_level0_row2" class="row_heading level0 row2" >Cp2o</th>
#       <td id="T_2f720_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_2f720_row2_col1" class="data row2 col1" >-0.74</td>
#       <td id="T_2f720_row2_col2" class="data row2 col2" >2.2</td>
#       <td id="T_2f720_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_2f720_row2_col4" class="data row2 col4" >0.071</td>
#       <td id="T_2f720_row2_col5" class="data row2 col5" >1.2</td>
#       <td id="T_2f720_row2_col6" class="data row2 col6" >0.84</td>
#       <td id="T_2f720_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_2f720_row2_col8" class="data row2 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_2f720_level0_row3" class="row_heading level0 row3" >Cp3o</th>
#       <td id="T_2f720_row3_col0" class="data row3 col0" >27425</td>
#       <td id="T_2f720_row3_col1" class="data row3 col1" >-0.46</td>
#       <td id="T_2f720_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_2f720_row3_col3" class="data row3 col3" >0.09</td>
#       <td id="T_2f720_row3_col4" class="data row3 col4" >0.09</td>
#       <td id="T_2f720_row3_col5" class="data row3 col5" >2.0</td>
#       <td id="T_2f720_row3_col6" class="data row3 col6" >0.61</td>
#       <td id="T_2f720_row3_col7" class="data row3 col7" >1.9</td>
#       <td id="T_2f720_row3_col8" class="data row3 col8" >-0.21</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogetherf.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_2f614_row0_col0, #T_2f614_row0_col1, #T_2f614_row0_col2, #T_2f614_row0_col3, #T_2f614_row0_col4, #T_2f614_row0_col5, #T_2f614_row0_col6, #T_2f614_row0_col7, #T_2f614_row0_col8, #T_2f614_row1_col0, #T_2f614_row1_col1, #T_2f614_row1_col3, #T_2f614_row1_col4, #T_2f614_row1_col5, #T_2f614_row1_col6, #T_2f614_row1_col7, #T_2f614_row1_col8, #T_2f614_row2_col1, #T_2f614_row2_col2, #T_2f614_row2_col3, #T_2f614_row2_col4, #T_2f614_row2_col5, #T_2f614_row2_col6, #T_2f614_row2_col7, #T_2f614_row2_col8, #T_2f614_row4_col0, #T_2f614_row4_col2 {
#   color: black;
# }
# #T_2f614_row1_col2, #T_2f614_row3_col0, #T_2f614_row3_col7, #T_2f614_row4_col1, #T_2f614_row4_col3, #T_2f614_row4_col4, #T_2f614_row4_col5, #T_2f614_row4_col6, #T_2f614_row4_col8 {
#   color: darkgreen;
# }
# #T_2f614_row2_col0, #T_2f614_row3_col1, #T_2f614_row3_col2, #T_2f614_row3_col3, #T_2f614_row3_col4, #T_2f614_row3_col5, #T_2f614_row3_col6, #T_2f614_row3_col8, #T_2f614_row4_col7 {
#   color: red;
# }
# </style>
# <table id="T_2f614_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f614_level0_row0" class="row_heading level0 row0" >H201812f</th>
#       <td id="T_2f614_row0_col0" class="data row0 col0" >251530</td>
#       <td id="T_2f614_row0_col1" class="data row0 col1" >2.1</td>
#       <td id="T_2f614_row0_col2" class="data row0 col2" >5.2</td>
#       <td id="T_2f614_row0_col3" class="data row0 col3" >0.24</td>
#       <td id="T_2f614_row0_col4" class="data row0 col4" >0.53</td>
#       <td id="T_2f614_row0_col5" class="data row0 col5" >1.3e+01</td>
#       <td id="T_2f614_row0_col6" class="data row0 col6" >3.9</td>
#       <td id="T_2f614_row0_col7" class="data row0 col7" >3.5</td>
#       <td id="T_2f614_row0_col8" class="data row0 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_2f614_level0_row1" class="row_heading level0 row1" >H201905f</th>
#       <td id="T_2f614_row1_col0" class="data row1 col0" >251528</td>
#       <td id="T_2f614_row1_col1" class="data row1 col1" >2.0</td>
#       <td id="T_2f614_row1_col2" class="data row1 col2" >5.2</td>
#       <td id="T_2f614_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_2f614_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_2f614_row1_col5" class="data row1 col5" >1.3e+01</td>
#       <td id="T_2f614_row1_col6" class="data row1 col6" >3.9</td>
#       <td id="T_2f614_row1_col7" class="data row1 col7" >3.5</td>
#       <td id="T_2f614_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_2f614_level0_row2" class="row_heading level0 row2" >Cp2f</th>
#       <td id="T_2f614_row2_col0" class="data row2 col0" >257271</td>
#       <td id="T_2f614_row2_col1" class="data row2 col1" >2.1</td>
#       <td id="T_2f614_row2_col2" class="data row2 col2" >5.3</td>
#       <td id="T_2f614_row2_col3" class="data row2 col3" >0.25</td>
#       <td id="T_2f614_row2_col4" class="data row2 col4" >0.54</td>
#       <td id="T_2f614_row2_col5" class="data row2 col5" >1.3e+01</td>
#       <td id="T_2f614_row2_col6" class="data row2 col6" >4.0</td>
#       <td id="T_2f614_row2_col7" class="data row2 col7" >3.6</td>
#       <td id="T_2f614_row2_col8" class="data row2 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_2f614_level0_row3" class="row_heading level0 row3" >Cp3f</th>
#       <td id="T_2f614_row3_col0" class="data row3 col0" >249027</td>
#       <td id="T_2f614_row3_col1" class="data row3 col1" >2.5</td>
#       <td id="T_2f614_row3_col2" class="data row3 col2" >5.5</td>
#       <td id="T_2f614_row3_col3" class="data row3 col3" >0.26</td>
#       <td id="T_2f614_row3_col4" class="data row3 col4" >0.56</td>
#       <td id="T_2f614_row3_col5" class="data row3 col5" >1.4e+01</td>
#       <td id="T_2f614_row3_col6" class="data row3 col6" >4.3</td>
#       <td id="T_2f614_row3_col7" class="data row3 col7" >3.4</td>
#       <td id="T_2f614_row3_col8" class="data row3 col8" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_2f614_level0_row4" class="row_heading level0 row4" >Cp3f0</th>
#       <td id="T_2f614_row4_col0" class="data row4 col0" >251533</td>
#       <td id="T_2f614_row4_col1" class="data row4 col1" >1.3</td>
#       <td id="T_2f614_row4_col2" class="data row4 col2" >5.2</td>
#       <td id="T_2f614_row4_col3" class="data row4 col3" >0.21</td>
#       <td id="T_2f614_row4_col4" class="data row4 col4" >0.43</td>
#       <td id="T_2f614_row4_col5" class="data row4 col5" >1e+01</td>
#       <td id="T_2f614_row4_col6" class="data row4 col6" >3.0</td>
#       <td id="T_2f614_row4_col7" class="data row4 col7" >4.3</td>
#       <td id="T_2f614_row4_col8" class="data row4 col8" >0.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/202007F/ObsModel_202007F_ctd_20150101_20151231.csv',
          '/home/sallen/202007/202007F/ObsModel_202007F_psfts_20150101_20151231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_pugts_20150101_20151231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_ctd_20160101_20161231.csv',
          '/home/sallen/202007/202007F/ObsModel_202007F_psfts_20160101_20161231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_pugts_20160101_20161231.csv',
   #      '/home/sallen/202007/202007F/ObsModel_202007F_ctd_20170101_20171231.csv',
   #       '/home/sallen/202007/202007F/ObsModel_202007F_psfts_20170101_20171231.csv',
   #      '/home/sallen/202007/202007F/ObsModel_202007F_pugts_20170101_20171231.csv',
          )
pieces2 = (
         '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20150101_20151231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20160101_20161231.csv',
   #      '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20170101_20171231.csv'
         )
pieces3 = (
       '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20160101_20161231.csv',
   # '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20170101_20171231.csv',
)

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

temp3 = read_pieces(pieces3)
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

dowhich = ['Fo', 'Ff', 'Ff0'] 

Fo, Ff, Ff0 = triple_plots(dowhich, temp1, cleanup_ferry(temp2), cleanup_ferry(temp3))

alltogethero = pd.concat([d201812o, d201905o,  Cp2o,  #Dagaino, 
                       # DnoCilo,  DLowRo, 
                          Cp3o, Fo], axis=0)
alltogetherf = pd.concat([d201812f,  d201905f,  Cp2f,  #Dagainf,
                         #DnoCilf,  DLowRf, 
                          Cp3f, Ff, Cp3f0, Ff0], axis=0)
alltogethero.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_8c7e2_row0_col0, #T_8c7e2_row0_col3, #T_8c7e2_row0_col7, #T_8c7e2_row1_col0, #T_8c7e2_row1_col1, #T_8c7e2_row1_col2, #T_8c7e2_row1_col6, #T_8c7e2_row2_col0, #T_8c7e2_row2_col8, #T_8c7e2_row3_col0, #T_8c7e2_row3_col4, #T_8c7e2_row3_col5, #T_8c7e2_row4_col0 {
#   color: red;
# }
# #T_8c7e2_row0_col1, #T_8c7e2_row0_col2, #T_8c7e2_row0_col4, #T_8c7e2_row0_col5, #T_8c7e2_row0_col6, #T_8c7e2_row0_col8, #T_8c7e2_row1_col3, #T_8c7e2_row1_col4, #T_8c7e2_row1_col5, #T_8c7e2_row1_col7, #T_8c7e2_row1_col8, #T_8c7e2_row2_col1, #T_8c7e2_row2_col2, #T_8c7e2_row2_col3, #T_8c7e2_row2_col6, #T_8c7e2_row2_col7, #T_8c7e2_row3_col2, #T_8c7e2_row3_col3, #T_8c7e2_row3_col7, #T_8c7e2_row4_col1, #T_8c7e2_row4_col4, #T_8c7e2_row4_col5, #T_8c7e2_row4_col6, #T_8c7e2_row4_col8 {
#   color: black;
# }
# #T_8c7e2_row2_col4, #T_8c7e2_row2_col5, #T_8c7e2_row3_col1, #T_8c7e2_row3_col6, #T_8c7e2_row3_col8, #T_8c7e2_row4_col2, #T_8c7e2_row4_col3, #T_8c7e2_row4_col7 {
#   color: darkgreen;
# }
# </style>
# <table id="T_8c7e2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c7e2_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_8c7e2_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_8c7e2_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_8c7e2_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_8c7e2_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_8c7e2_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_8c7e2_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_8c7e2_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_8c7e2_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_8c7e2_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_8c7e2_level0_row1" class="row_heading level0 row1" >H201905o</th>
#       <td id="T_8c7e2_row1_col0" class="data row1 col0" >27425</td>
#       <td id="T_8c7e2_row1_col1" class="data row1 col1" >-0.76</td>
#       <td id="T_8c7e2_row1_col2" class="data row1 col2" >2.3</td>
#       <td id="T_8c7e2_row1_col3" class="data row1 col3" >0.11</td>
#       <td id="T_8c7e2_row1_col4" class="data row1 col4" >0.074</td>
#       <td id="T_8c7e2_row1_col5" class="data row1 col5" >1.3</td>
#       <td id="T_8c7e2_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_8c7e2_row1_col7" class="data row1 col7" >2.1</td>
#       <td id="T_8c7e2_row1_col8" class="data row1 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_8c7e2_level0_row2" class="row_heading level0 row2" >Cp2o</th>
#       <td id="T_8c7e2_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_8c7e2_row2_col1" class="data row2 col1" >-0.74</td>
#       <td id="T_8c7e2_row2_col2" class="data row2 col2" >2.2</td>
#       <td id="T_8c7e2_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_8c7e2_row2_col4" class="data row2 col4" >0.071</td>
#       <td id="T_8c7e2_row2_col5" class="data row2 col5" >1.2</td>
#       <td id="T_8c7e2_row2_col6" class="data row2 col6" >0.84</td>
#       <td id="T_8c7e2_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_8c7e2_row2_col8" class="data row2 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_8c7e2_level0_row3" class="row_heading level0 row3" >Cp3o</th>
#       <td id="T_8c7e2_row3_col0" class="data row3 col0" >27425</td>
#       <td id="T_8c7e2_row3_col1" class="data row3 col1" >-0.46</td>
#       <td id="T_8c7e2_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_8c7e2_row3_col3" class="data row3 col3" >0.09</td>
#       <td id="T_8c7e2_row3_col4" class="data row3 col4" >0.09</td>
#       <td id="T_8c7e2_row3_col5" class="data row3 col5" >2.0</td>
#       <td id="T_8c7e2_row3_col6" class="data row3 col6" >0.61</td>
#       <td id="T_8c7e2_row3_col7" class="data row3 col7" >1.9</td>
#       <td id="T_8c7e2_row3_col8" class="data row3 col8" >-0.21</td>
#     </tr>
#     <tr>
#       <th id="T
>0.2</td>
#     </tr>
#     <tr>
#       <th id="T_41b2d_level0_row6" class="row_heading level0 row6" >Ff0</th>
#       <td id="T_41b2d_row6_col0" class="data row6 col0" >251530</td>
#       <td id="T_41b2d_row6_col1" class="data row6 col1" >1.3</td>
#       <td id="T_41b2d_row6_col2" class="data row6 col2" >5.2</td>
#       <td id="T_41b2d_row6_col3" class="data row6 col3" >0.2</td>
#       <td id="T_41b2d_row6_col4" class="data row6 col4" >0.41</td>
#       <td id="T_41b2d_row6_col5" class="data row6 col5" >9.8</td>
#       <td id="T_41b2d_row6_col6" class="data row6 col6" >2.9</td>
#       <td id="T_41b2d_row6_col7" class="data row6 col7" >4.3</td>
#       <td id="T_41b2d_row6_col8" class="data row6 col8" >0.18</td>
#     </tr>
#   </tbody>
# </table>

# %%
pieces1 = ('/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ctd_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_psfts_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pugts_20150101_20151231.csv',
           '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ctd_20160101_20161231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_psfts_20160101_20161231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pugts_20160101_20161231.csv',
    #       '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ctd_20170101_20171231.csv',
    #      '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_psfts_20170101_20171231.csv',
    #      '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_pugts_20170101_20171231.csv',
          )
pieces2 = ('/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20150101_20150331.csv',
           '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20150401_20150630.csv',
           '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20150701_20150930.csv',
           '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20151001_20151231.csv',
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20160101_20161231.csv',
     #     '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20170101_20171231.csv',
          )
pieces3 = (
          '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20160101_20161231.csv',
   # '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20170101_20171231.csv',
         )

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

temp3 = read_pieces(pieces3)
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

dowhich = ['Gp1o', 'Gp1f', 'Gp1f0'] 

Gp1o, Gp1f, Gp1f0 = triple_plots(dowhich, temp1[temp1.mod_vosaline != 0], cleanup_ferry(temp2), cleanup_ferry(temp3))

alltogethero = pd.concat([d201812o, d201905o,  Cp2o,  #Dagaino, 
                        #DnoCilo,  DLowRo, 
                          Cp3o, Fo, Gp1o], axis=0)
alltogetherf = pd.concat([d201812f,  d201905f,  Cp2f,  #Dagainf,
                        # DnoCilf,  DLowRf, 
                          Cp3f, Ff, Gp1f, Cp3f0, Ff0, Gp1f0], axis=0)
alltogethero.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <style type="text/css">
# #T_392b0_row0_col0, #T_392b0_row0_col3, #T_392b0_row0_col7, #T_392b0_row1_col0, #T_392b0_row1_col1, #T_392b0_row1_col2, #T_392b0_row1_col6, #T_392b0_row2_col0, #T_392b0_row2_col8, #T_392b0_row3_col0, #T_392b0_row3_col4, #T_392b0_row3_col5, #T_392b0_row4_col0 {
#   color: red;
# }
# #T_392b0_row0_col1, #T_392b0_row0_col2, #T_392b0_row0_col4, #T_392b0_row0_col5, #T_392b0_row0_col6, #T_392b0_row0_col8, #T_392b0_row1_col3, #T_392b0_row1_col4, #T_392b0_row1_col5, #T_392b0_row1_col7, #T_392b0_row1_col8, #T_392b0_row2_col1, #T_392b0_row2_col2, #T_392b0_row2_col3, #T_392b0_row2_col4, #T_392b0_row2_col6, #T_392b0_row2_col7, #T_392b0_row3_col1, #T_392b0_row3_col2, #T_392b0_row3_col3, #T_392b0_row3_col6, #T_392b0_row3_col7, #T_392b0_row3_col8, #T_392b0_row4_col1, #T_392b0_row4_col2, #T_392b0_row4_col3, #T_392b0_row4_col4, #T_392b0_row4_col5, #T_392b0_row4_col6, #T_392b0_row4_col7, #T_392b0_row4_col8, #T_392b0_row5_col5 {
#   color: black;
# }
# #T_392b0_row2_col5, #T_392b0_row5_col0, #T_392b0_row5_col1, #T_392b0_row5_col2, #T_392b0_row5_col3, #T_392b0_row5_col4, #T_392b0_row5_col6, #T_392b0_row5_col7, #T_392b0_row5_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_392b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_392b0_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_392b0_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_392b0_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_392b0_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T_392b0_row0_col3" class="data row0 col3" >0.11</td>
#       <td id="T_392b0_row0_col4" class="data row0 col4" >0.076</td>
#       <td id="T_392b0_row0_col5" class="data row0 col5" >1.3</td>
#       <td id="T_392b0_row0_col6" class="data row0 col6" >0.83</td>
#       <td id="T_392b0_row0_col7" class="data row0 col7" >2.1</td>
#       <td id="T_392b0_row0_col8" class="data row0 col8" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_392b0_level0_row1" class="row_heading level0 row1" >H201905o</th>
#       <td id="T_392b0_row1_col0" class="data row1 col0" >27425</td>
#       <td id="T_392b0_row1_col1" class="data row1 col1" >-0.76</td>
#       <td id="T_392b0_row1_col2" class="data row1 col2" >2.3</td>
#       <td id="T_392b0_row1_col3" class="data row1 col3" >0.11</td>
#       <td id="T_392b0_row1_col4" class="data row1 col4" >0.074</td>
#       <td id="T_392b0_row1_col5" class="data row1 col5" >1.3</td>
#       <td id="T_392b0_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_392b0_row1_col7" class="data row1 col7" >2.1</td>
#       <td id="T_392b0_row1_col8" class="data row1 col8" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_392b0_level0_row2" class="row_heading level0 row2" >Cp2o</th>
#       <td id="T_392b0_row2_col0" class="data row2 col0" >27425</td>
#       <td id="T_392b0_row2_col1" class="data row2 col1" >-0.74</td>
#       <td id="T_392b0_row2_col2" class="data row2 col2" >2.2</td>
#       <td id="T_392b0_row2_col3" class="data row2 col3" >0.11</td>
#       <td id="T_392b0_row2_col4" class="data row2 col4" >0.071</td>
#       <td id="T_392b0_row2_col5" class="data row2 col5" >1.2</td>
#       <td id="T_392b0_row2_col6" class="data row2 col6" >0.84</td>
#       <td id="T_392b0_row2_col7" class="data row2 col7" >2.1</td>
#       <td id="T_392b0_row2_col8" class="data row2 col8" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_392b0_level0_row3" class="row_heading level0 row3" >Cp3o</th>
#       <td id="T_392b0_row3_col0" class="data row3 col0" >27425</td>
#       <td id="T_392b0_row3_col1" class="data row3 col1" >-0.46</td>
#       <td id="T_392b0_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_392b0_row3_col3" class="data row3 col3" >0.09</td>
#       <td id="T_392b0_row3_col4" class="data row3 col4" >0.09</td>
#       <td id="T_392b0_row3_col5" class="data row3 col5" >2.0</td>
#       <td id="T_392b0_row3_col6" class="data row3 col6" >0.61</td>
#       <td id="T_392b0_row3_col7" class="data row3 col7" >1.9</td>
#       <td id="T_392b0_row3_col8" class="data row3 col8" >-0.21</td>
#     </tr>
#     <tr>
#       <th id="T_392b0_level0_row4" class="row_heading level0 row4" >Fo</th>
#       <td id="T_392b0_row4_col0" class="data row4 col0" >27425</td>
#       <td id="T_392b0_row4_col1" class="data row4 col1" >-0.48</td>
#       <td id="T_392b0_row4_col2" class="data row4 col2" >1.9</td>
#       <td id="T_392b0_row4_col3" class="data row4 col3" >0.088</td>
#       <td id="T_392b0_row4_col4" class="data row4 col4" >0.085</td>
#       <td id="T_392b0_row4_col5" class="data row4 col5" >1.8</td>
#       <td id="T_392b0_row4_col6" class="data row4 col6" >0.62</td>
#       <td id="T_392b0_row4_col7" class="data row4 col7" >1.9</td>
#       <td id="T_392b0_row4_col8" class="data row4 col8" >-0.21</td>
#     </tr>
#     <tr>
#       <th id="T
>0.51</td>
#     </tr>
#     <tr>
#       <th id="T_55b66_level0_row6" class="row_heading level0 row6" >Cp3f0</th>
#       <td id="T_55b66_row6_col0" class="data row6 col0" >251533</td>
#       <td id="T_55b66_row6_col1" class="data row6 col1" >1.3</td>
#       <td id="T_55b66_row6_col2" class="data row6 col2" >5.2</td>
#       <td id="T_55b66_row6_col3" class="data row6 col3" >0.21</td>
#       <td id="T_55b66_row6_col4" class="data row6 col4" >0.43</td>
#       <td id="T_55b66_row6_col5" class="data row6 col5" >1e+01</td>
#       <td id="T_55b66_row6_col6" class="data row6 col6" >3.0</td>
#       <td id="T_55b66_row6_col7" class="data row6 col7" >4.3</td>
#       <td id="T_55b66_row6_col8" class="data row6 col8" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_55b66_level0_row7" class="row_heading level0 row7" >Ff0</th>
#       <td id="T_55b66_row7_col0" class="data row7 col0" >251530</td>
#       <td id="T_55b66_row7_col1" class="data row7 col1" >1.3</td>
#       <td id="T_55b66_row7_col2" class="data row7 col2" >5.2</td>
#       <td id="T_55b66_row7_col3" class="data row7 col3" >0.2</td>
#       <td id="T_55b66_row7_col4" class="data row7 col4" >0.41</td>
#       <td id="T_55b66_row7_col5" class="data row7 col5" >9.8</td>
#       <td id="T_55b66_row7_col6" class="data row7 col6" >2.9</td>
#       <td id="T_55b66_row7_col7" class="data row7 col7" >4.3</td>
#       <td id="T_55b66_row7_col8" class="data row7 col8" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_55b66_level0_row8" class="row_headin

# %%
pieces1 = ('/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_ctd_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_psfts_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_pugts_20150101_20151231.csv',
        '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ctd_20160101_20161231.csv',
           '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_psfts_20160101_20161231.csv',
           '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_pugts_20160101_20161231.csv',
  #         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ctd_20170101_20171231.csv',
  #         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_psfts_20170101_20171231.csv',
  #         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_pugts_20170101_20171231.csv'
         )
pieces2 = (
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_ferry_20150101_20151231.csv',
   
         )
pieces3 = (
    '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20160101_20161231.csv',
  #  '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20170101_20171231.csv',
)

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp2 = read_pieces(pieces2)
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

temp3 = read_pieces(pieces3)
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

dowhich = ['Gp2o', 'Gp2f', 'Gp2f0'] 

Gp2o, Gp2f, Gp2f0 = triple_plots(dowhich, temp1[temp1.mod_vosaline != 0], cleanup_ferry(temp2), cleanup_ferry(temp3))
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
pieces1 = ('/data/sallen/results/MEOPAR/202111/ObsModel_202111_ctd_20150101_20151231.csv',
           '/data/sallen/results/MEOPAR/202111/ObsModel_202111_psfts_20150101_20151231.csv',
           '/data/sallen/results/MEOPAR/202111/ObsModel_202111_pugts_20150101_20151231.csv',
           '/data/sallen/results/MEOPAR/202111/ObsModel_202111_ctd_20160101_20161231.csv',
           '/data/sallen/results/MEOPAR/202111/ObsModel_202111_psfts_20160101_20161231.csv',
           '/data/sallen/results/MEOPAR/202111/ObsModel_202111_pugts_20160101_20161231.csv',
          )

pieces3 = ('/data/sallen/results/MEOPAR/202111/ObsModel_202111_ferry_20150101_20151231.csv',
          '/data/sallen/results/MEOPAR/202111/ObsModel_202111_ferry_20160101_20161231.csv'
          )

# %%
temp1 = read_pieces(pieces1)
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

temp3 = read_pieces(pieces3)
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

dowhich = ['v202111o', 'No', 'v202111f0'] 

v202111o, stuff, v202111f0 = triple_plots(dowhich, temp1[temp1.mod_vosaline != 0], cleanup_ferry(temp1), cleanup_ferry(temp3))
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
alltogethero = pd.concat([d201812o, d201905o,  Cp2o,  #Dagaino, 
                 #       DnoCilo,  DLowRo, 
                          Cp3o, Fo, Gp1o, 
                          Gp2o, 
                          v202111o], axis=0)
alltogetherf = pd.concat([d201812f,  d201905f, Cp2f,  #Dagainf,
                  #       DnoCilf,  DLowRf, 
                          Cp3f, Ff, Gp1f, 
                          Cp3f0, #Ff0, 
                          Gp1f0, Gp2f, Gp2f0, 
                          v202111f0], axis=0)
alltogethero.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_06665_row0_col0, #T_06665_row0_col3, #T_06665_row0_col7, #T_06665_row1_col0, #T_06665_row1_col1, #T_06665_row1_col2, #T_06665_row1_col6, #T_06665_row2_col0, #T_06665_row2_col8, #T_06665_row3_col0, #T_06665_row4_col0, #T_06665_row7_col4, #T_06665_row7_col5 {
#   color: red;
# }
# #T_06665_row0_col1, #T_06665_row0_col2, #T_06665_row0_col4, #T_06665_row0_col5, #T_06665_row0_col6, #T_06665_row0_col8, #T_06665_row1_col3, #T_06665_row1_col4, #T_06665_row1_col5, #T_06665_row1_col7, #T_06665_row1_col8, #T_06665_row2_col1, #T_06665_row2_col2, #T_06665_row2_col3, #T_06665_row2_col4, #T_06665_row2_col6, #T_06665_row2_col7, #T_06665_row3_col1, #T_06665_row3_col2, #T_06665_row3_col3, #T_06665_row3_col4, #T_06665_row3_col5, #T_06665_row3_col6, #T_06665_row3_col7, #T_06665_row3_col8, #T_06665_row4_col1, #T_06665_row4_col2, #T_06665_row4_col3, #T_06665_row4_col4, #T_06665_row4_col5, #T_06665_row4_col6, #T_06665_row4_col7, #T_06665_row4_col8, #T_06665_row5_col1, #T_06665_row5_col2, #T_06665_row5_col5, #T_06665_row5_col6, #T_06665_row5_col7, #T_06665_row5_col8, #T_06665_row6_col2, #T_06665_row6_col3, #T_06665_row6_col4, #T_06665_row6_col5, #T_06665_row6_col7, #T_06665_row6_col8, #T_06665_row7_col1, #T_06665_row7_col3, #T_06665_row7_col6 {
#   color: black;
# }
# #T_06665_row2_col5, #T_06665_row5_col0, #T_06665_row5_col3, #T_06665_row5_col4, #T_06665_row6_col0, #T_06665_row6_col1, #T_06665_row6_col6, #T_06665_row7_col0, #T_06665_row7_col2, #T_06665_row7_col7, #T_06665_row7_col8 {
#   color: darkgreen;
# }
# </style>
# <table id="T_06665_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >number</th>
#       <th class="col_heading level0 col1" >bias</th>
#       <th class="col_heading level0 col2" >rmse</th>
#       <th class="col_heading level0 col3" >swillmott</th>
#       <th class="col_heading level0 col4" >slopedev</th>
#       <th class="col_heading level0 col5" >const</th>
#       <th class="col_heading level0 col6" >systematic</th>
#       <th class="col_heading level0 col7" >nonsystematic</th>
#       <th class="col_heading level0 col8" >spread</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06665_level0_row0" class="row_heading level0 row0" >H201812o</th>
#       <td id="T_06665_row0_col0" class="data row0 col0" >27425</td>
#       <td id="T_06665_row0_col1" class="data row0 col1" >-0.72</td>
#       <td id="T_06665_row0_col2" class="data row0 col2" >2.3</td>
#       <td id="T
>-0.19</td>
#     </tr>
#     <tr>
#       <th id="T_06665_level0_row6" class="row_heading level0 row6" >Gp2o</th>
#       <td id="T_06665_row6_col0" class="data row6 col0" >27398</td>
#       <td id="T_06665_row6_col1" class="data row6 col1" >-0.33</td>
#       <td id="T_06665_row6_col2" class="data row6 col2" >1.9</td>
#       <td id="T_06665_row6_col3" class="data row6 col3" >0.083</td>
#       <td id="T_06665_row6_col4" class="data row6 col4" >0.075</td>
#       <td id="T_06665_row6_col5" class="data row6 col5" >1.7</td>
#       <td id="T_06665_row6_col6" class="data row6 col6" >0.46</td>
#       <td id="T_06665_row6_col7" class="data row6 col7" >1.8</td>
#       <td id="T_06665_row6_col8" class="data row6 col8" >-0.2</td>
#     </tr>
#     <tr>
#       <th id="T_06665_level0_row7" class="row_heading level0 row7" >v202111o</th>
#       <td id="T_06665_row7_col0" class="data row7 col0" >27398</td>
#       <td id="T_06665_row7_col1" class="data row7 col1" >-0.35</td>
#       <td id="T_06665_row7_col2" class="data row7 col2" >1.8</td>
#       <td id="T_06665_row7_col3" class="data row7 col3" >0.081</td>
#       <td id="T_06665_row7_col4" class="data row7 col4" >0.098</td>
#       <td id="T_06665_row7_col5" class="data row7 col5" >2.3</td>
#       <td id="T_06665_row7_col6" class="data row7 col6" >0.54</td>
#       <td id="T_06665_row7_col7" class="data row7 col7" >1.8</td>
#       <td id="T_06665_row7_col8" class="data row7 col8" >-0.14</td>
#     </tr>
#   </tbody>
# </table>

# %%
alltogetherf.style.format(myformat).apply(highlight_max_min)
# Out:
# <style type="text/css">
# #T_63db3_row0_col0, #T_63db3_row0_col1, #T_63db3_row0_col2, #T_63db3_row0_col3, #T_63db3_row0_col4, #T_63db3_row0_col5, #T_63db3_row0_col6, #T_63db3_row0_col7, #T_63db3_row0_col8, #T_63db3_row1_col0, #T_63db3_row1_col1, #T_63db3_row1_col2, #T_63db3_row1_col3, #T_63db3_row1_col4, #T_63db3_row1_col5, #T_63db3_row1_col6, #T_63db3_row1_col7, #T_63db3_row1_col8, #T_63db3_row2_col1, #T_63db3_row2_col2, #T_63db3_row2_col3, #T_63db3_row2_col4, #T_63db3_row2_col5, #T_63db3_row2_col6, #T_63db3_row2_col7, #T_63db3_row2_col8, #T_63db3_row3_col0, #T_63db3_row3_col1, #T_63db3_row3_col7, #T_63db3_row4_col0, #T_63db3_row4_col1, #T_63db3_row4_col2, #T_63db3_row4_col3, #T_63db3_row4_col4, #T_63db3_row4_col5, #T_63db3_row4_col6, #T_63db3_row4_col7, #T_63db3_row4_col8, #T_63db3_row5_col0, #T_63db3_row5_col2, #T_63db3_row5_col3, #T_63db3_row5_col4, #T_63db3_row5_col5, #T_63db3_row5_col6, #T_63db3_row5_col8, #T_63db3_row6_col0, #T_63db3_row6_col1, #T_63db3_row6_col2, #T_63db3_row6_col3, #T_63db3_row6_col4, #T_63db3_row6_col5, #T_63db3_row6_col6, #T_63db3_row6_col8, #T_63db3_row7_col0, #T
col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_63db3_level0_row3" class="row_heading level0 row3" >Cp3f</th>
#       <td id="T_63db3_row3_col0" class="data row3 col0" >249027</td>
#       <td id="T_63db3_row3_col1" class="data row3 col1" >2.5</td>
#       <td id="T_63db3_row3_col2" class="data row3 col2" >5.5</td>
#       <td id="T_63db3_row3_col3" class="data row3 col3" >0.26</td>
#       <td id="T_63db3_row3_col4" class="data row3 col4" >0.56</td>
#       <td id="T_63db3_row3_col5" class="data row3 col5" >1.4e+01</td>
#       <td id="T_63db3_row3_col6" class="data row3 col6" >4.3</td>
#       <td id="T_63db3_row3_col7" class="data row3 col7" >3.4</td>
#       <td id="T_63db3_row3_col8" class="data row3 col8" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_63db3_level0_row4" class="row_heading level0 row4" >Ff</th>
#       <td id="T_63db3_row4_col0" class="data row4 col0" >251528</td>
#       <td id="T_63db3_row4_col1" class="data row4 col1" >2.4</td>
#       <td id="T_63db3_row4_col2" class="data row4 col2" >5.4</td>
#       <td id="T_63db3_row4_col3" class="data row4 col3" >0.25</td>
#       <td id="T_63db3_row4_col4" class="data row4 col4" >0.55</td>
#       <td id="T_63db3_row4_col5" class="data row4 col5" >1.4e+01</td>
#       <td id="T_63db3_row4_col6" class="data row4 col6" >4.2</td>
#       <td id="T_63db3_row4_col7" class="data row4 col7" >3.4</td>
#       <td id="T_63db3_row4_col8" class="data row4 col8" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_63db3_level0_row5" class="row_heading level0 row5" >Gp1f</th>
#       <td id="T_63db3_row5_col0" class="data row5 col0" >250589</td>
#       <td id="T_63db3_row5_col1" class="data row5 col1" >2.6</td>
#       <td id="T_63db3_row5_col2" class="data row5 col2" >5.1</td>
#       <td id="T_63db3_row5_col3" class="data row5 col3" >0.23</td>
#       <td id="T_63db3_row5_col4" class="data row5 col4" >0.5</td>
#       <td id="T_63db3_row5_col5" class="data row5 col5" >1.3e+01</td>
#       <td id="T_63db3_row5_col6" class="data row5 col6" >4.1</td>
#       <td id="T_63db3_row5_col7" class="data row5 col7" >3.1</td>
#       <td id="T_63db3_row5_col8" class="data row5 col8" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_63db3_level0_row6" class="row_heading level0 row6" >Cp3f0</th>
#       <td id="T_63db3_row6_col0" class="data row6 col0" >251533</td>
#       <td id="T_63db3_row6_col1" class="data row6 col1" >1.3</td>
#       <td id="T_63db3_row6_col2" class="data row6 col2" >5.2</td>
#       <td id="T_63db3_row6_col3" class="data row6 col3" >0.21</td>
#       <td id="T_63db3_row6_col4" class="data row6 col4" >0.43</td>
#       <td id="T_63db3_row6_col5" class="data row6 col5" >1e+01</td>
#       <td id="T_63db3_row6_col6" class="data row6 col6" >3.0</td>
#       <td id="T_63db3_row6_col7" class="data row6 col7" >4.3</td>
#       <td id="T_63db3_row6_col8" class="data row6 col8" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_63db3_level0_row7" class="row_heading level0 row7" >Gp1f0</th>
#       <td id="T_63db3_row7_col0" class="data row7 col0" >251535</td>
#       <td id="T_63db3_row7_col1" class="data row7 col1" >1.4</td>
#       <td id="T_63db3_row7_col2" class="data row7 col2" >4.4</td>
#       <td id="T_63db3_row7_col3" class="data row7 col3" >0.14</td>
#       <td id="T_63db3_row7_col4

# %%
temp4 = read_pieces(pieces1+pieces3)
temp4['SA'] = temp4.SA.fillna(value=temp4['salinity (g/kg)'])
#temp4['SA'] = temp4['salinity (g/kg)']
temp4.drop(columns='Unnamed: 0', inplace=True)
temp4.drop_duplicates(inplace=True)

# %%
temp1 = read_pieces(pieces1+pieces3)
temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
#temp4['SA'] = temp4['salinity (g/kg)']
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 12))
Gp1, counts1 = plot_and_stats(fig, axs[0, 0], cleanup_ferry(temp1[temp1.mod_vosaline != 0]), 'Gp1',withpred=False, witharrows=False)
Gp2, counts2 = plot_and_stats(fig, axs[0, 1], cleanup_ferry(temp4[temp4.mod_vosaline != 0]), 'Gp2',withpred=False, witharrows=False)
sals = np.arange(0.25, 33.75, 0.5)
colours = axs[1, 0].pcolormesh(sals, sals, (counts2 - counts1).transpose(), cmap='bwr', vmax=400, vmin=-400)
axs[1, 0].plot([0, 34], [0, 34], 'k')
fig.colorbar(colours, ax= axs[1, 0])
for ii in range(67):
    if counts1[ii, :].sum() > 0:
        axs[1, 1].plot(sals[ii], np.average(sals, weights=counts1[ii, :]), 'co')
        axs[1, 1].plot(sals[ii], np.average(sals, weights=counts1[ii, :]) - sals[ii], 'cx')
    if counts2[ii, :].sum() > 0:
        axs[1, 1].plot(sals[ii], np.average(sals, weights=counts2[ii, :]), 'mo')
        axs[1, 1].plot(sals[ii], np.average(sals, weights=counts2[ii, :]) - sals[ii], 'mx')
axs[1, 1].plot(sals, sals, 'k-')
axs[1, 1].text(2, 30, 'Gp1', color='c')
axs[1, 1].text(2, 28, 'Gp2', color='m')
alltogether = pd.concat([Gp1, Gp2], axis=0)
alltogether.style.format(myformat).apply(highlight_max_min)
# Out:
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-aad5356746b5> in <module>
#       1 fig, axs = plt.subplots(2, 2, figsize=(14, 12))
# ----> 2 Gp1, counts1 = plot_and_stats(fig, axs[0, 0], cleanup_ferry(temp1[temp1.mod_vosaline != 0]), 'Gp1',withpred=False, witharrows=False)
#       3 Gp2, counts2 = plot_and_stats(fig, axs[0, 1], cleanup_ferry(temp4[temp4.mod_vosaline != 0]), 'Gp2',withpred=False, witharrows=False)
#       4 sals = np.arange(0.25, 33.75, 0.5)
#       5 colours = axs[1, 0].pcolormesh(sals, sals, (counts2 - counts1).transpose(), cmap='bwr', vmax=400, vmin=-400)
#
# ValueError: too many values to unpack (expected 2)

# %%
maxi = 29.6
plt.plot(temp4.SA[(temp4.mod_vosaline > maxi) & (temp4.SA < 25)], 
         temp4.mod_vosaline[(temp4.mod_vosaline > maxi) & (temp4.SA < 25)], 'o')

# %%
plt.plot(temp4.Lon, temp4.Lat, 'o')
plt.plot(temp4.Lon[(temp4.mod_vosaline > maxi) & (temp4.SA < 25)], 
         temp4.Lat[(temp4.mod_vosaline > maxi) & (temp4.SA < 25)], 'o')
pd.set_option('display.max_columns', None)
whatIwant = temp4[(temp4.mod_vosaline > maxi) & (temp4.SA < 25)][-400:]
plt.xlim(-124, -123)
plt.ylim(48.9, 49.3)
# Out:
# (48.9, 49.3)

# %%
whatIwant['dtUTC'] = pd.to_datetime(whatIwant['dtUTC'])

# %%
last_incident = -159
plt.plot(whatIwant[last_incident:].dtUTC, whatIwant.SA[last_incident:], 'o')
plt.plot(whatIwant[last_incident:].dtUTC, whatIwant.mod_vosaline[last_incident:], 'o')

# %%
flow = pd.read_csv('/home/sallen/MEOPAR/tools/I_ForcingFiles/Rivers/river_flows/Nicomekl_203_flow', header=None, sep=' ', dtype={0: 'int64',
                                                                                                                         1: 'int64',
                                                                                                                         2: 'int64'},
            
           )
#
#df = pd.read_csv(file, header=None, index_col='datetime', 
#                 parse_dates={'datetime': [1,2,3,4]}, 
#                 date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
flow.rename(columns={0: "Year", 1: "Month", 2: "Day", 3: 'Flow'}, inplace=True)
#pd.to_datetime(df[['year', 'month', 'day']])
flow['datetime'] = pd.to_datetime(flow[['Year', 'Month', 'Day']])
flow.set_index('datetime', inplace=True)
flow
# Out:
#             Year  Month  Day       Flow
# datetime
# 1985-01-29  1985      1   29   0.806000
# 1985-01-30  1985      1   30   0.705000
# 1985-01-31  1985      1   31   0.648000
# 1985-02-01  1985      2    1   0.684000
# 1985-02-02  1985      2    2   0.662000
# ...          ...    ...  ...        ...
# 2020-12-30  2020     12   30  12.370490
# 2020-12-31  2020     12   31  18.568590
# 2021-01-01  2021      1    1   9.472535
# 2021-01-02  2021      1    2   8.384792
# 2021-01-03  2021      1    3   9.653576
#
# [13124 rows x 4 columns]

# %%
roberts = pd.read_csv('/home/sallen/MEOPAR/tools/I_ForcingFiles/Rivers/river_flows/Roberts_Roberts_flow', header=None, sep=' ', dtype={0: 'int64',
                                                                                                                         1: 'int64',
                                                                                                                         2: 'int64'},
            
           )
#
#df = pd.read_csv(file, header=None, index_col='datetime', 
#                 parse_dates={'datetime': [1,2,3,4]}, 
#                 date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
roberts.rename(columns={0: "Year", 1: "Month", 2: "Day", 3: 'Flow'}, inplace=True)
#pd.to_datetime(df[['year', 'month', 'day']])
roberts['datetime'] = pd.to_datetime(roberts[['Year', 'Month', 'Day']])
roberts.set_index('datetime', inplace=True)
roberts
# Out:
#             Year  Month  Day   Flow
# datetime
# 1959-04-28  1959      4   28  1.250
# 1959-04-29  1959      4   29  5.660
# 1959-04-30  1959      4   30  3.680
# 1959-05-01  1959      5    1  5.890
# 1959-05-02  1959      5    2  1.250
# ...          ...    ...  ...    ...
# 2019-12-27  2019     12   27  0.625
# 2019-12-28  2019     12   28  0.571
# 2019-12-29  2019     12   29  0.843
# 2019-12-30  2019     12   30  1.060
# 2019-12-31  2019     12   31  5.000
#
# [21961 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
flow.Flow.plot()
roberts.Flow.plot()
plt.xlim(dt.datetime(2017, 9, 1), dt.datetime(2017, 12, 31))
# Out:
# (17410.0, 17531.0)

# %%
# Huge Oct 12, 2017 storm (https://dailyhive.com/vancouver/vancouver-flooding-rainfall-october-12-2017) not picked up in river flows!

# %%
atmos1 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d11.nc')
atmos2 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d12.nc')
atmos3 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d13.nc')
atmos4 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d14.nc')

# %%
fig, axs = plt.subplots(1, 2, figsize=(11, 4))
atmos.tair.sum(axis=0).plot(ax=axs[0])
((atmos1.precip.mean(axis=0)+
  atmos2.precip.mean(axis=0)+
  atmos3.precip.mean(axis=0)+
  atmos4.precip.mean(axis=0))/4.*(4*86400)).plot(ax=axs[1], cmap='gist_ncar')
for ax in axs:
    ax.set_xlim(200000, 500000)
    ax.set_ylim(200000, 500000)
    ax.plot(390000, 345000, 'ro')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-19cc735bbe98> in <module>
#       1 fig, axs = plt.subplots(1, 2, figsize=(11, 4))
# ----> 2 atmos.tair.sum(axis=0).plot(ax=axs[0])
#       3 ((atmos1.precip.mean(axis=0)+
#       4   atmos2.precip.mean(axis=0)+
#       5   atmos3.precip.mean(axis=0)+
#
# NameError: name 'atmos' is not defined

# %%
atmos1 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d18.nc')
atmos2 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d19.nc')
atmos3 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d20.nc')
atmos4 = xr.open_dataset('/results/forcing/atmospheric/GEM2.5/operational/ops_y2017m10d21.nc')

# %%
fig, axs = plt.subplots(1, 2, figsize=(11, 4))
atmos.tair.sum(axis=0).plot(ax=axs[0])
((atmos1.precip.mean(axis=0)+
  atmos2.precip.mean(axis=0)+
  atmos3.precip.mean(axis=0)+
  atmos4.precip.mean(axis=0))/4*4*86400).plot(ax=axs[1], cmap='gist_ncar')
for ax in axs:
    ax.set_xlim(200000, 500000)
    ax.set_ylim(200000, 500000)
    ax.plot(390000, 345000, 'ro')

# %%
# First storm is a miss.  Second storm is good with 50 mm of rain at YVR
                                                         this column
09 	15.2 	5.5 	10.4 	7.6 	0.0 	0.0 	0.0 	0.0 	  	  	<31
10 	12.3 	6.5 	9.4 	8.6 	0.0 	3.1 	0.0 	3.1 	  	28 	39
11 	13.4 	6.6 	10.0 	8.0 	0.0 	2.2 	0.0 	2.2 	  	  	<31
12 	9.6 	6.1 	7.9 	10.1 	0.0 	31.4 	0.0 	31.4 	  	6 	35
13 	11.4 	4.6 	8.0 	10.0 	0.0 	1.0 	0.0 	1.0 	  	29 	41
14 	10.4 	5.2 	7.8 	10.2 	0.0 	0.2 	0.0 	0.2 	  	4 	37
15 	13.6 	8.7 	11.2 	6.8 	0.0 	0.0 	0.0 	0.0 	  	  	<31
16 	11.9 	10.2 	11.1 	6.9 	0.0 	8.2 	0.0 	8.2 	  	10 	33
17 	14.1 	8.4 	11.3 	6.7 	0.0 	2.2 	0.0 	2.2 	  	27 	65
18 	12.5 	7.7 	10.1 	7.9 	0.0 	33.4 	0.0 	33.4 	  	17 	50
19 	12.2 	9.1 	10.7 	7.3 	0.0 	10.0 	0.0 	10.0 	  	14 	39
20 	12.6 	6.2 	9.4 	8.6 	0.0 	9.4 	0.0 	9.4 	  	19 	39
21 	9.6 	7.0 	8.3 	9.7 	0.0 	8.2 	0.0 	8.2 	  	6 	44

# %%
## Now look at Distribution

# %%
pieces = (#'/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_ctd_20150101_20151231.csv',
          #'/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_psfts_20150101_20151231.csv',
          #'/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_pugts_20150101_20151231.csv',
          '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_ferry_20150101_20151231.csv',
           '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2_ferry_20150101_20151231.csv'
         )

# %%
temp1 = read_pieces(pieces)
#temp1['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
temp1['SA'] = temp1['salinity (g/kg)']
temp1.drop(columns='Unnamed: 0', inplace=True)
temp1.drop_duplicates(inplace=True)

# %%
pieces = (#'/home/sallen/202007/202007F/ObsModel_202007F_ctd_20150101_20151231.csv',
          #'/home/sallen/202007/202007F/ObsModel_202007F_psfts_20150101_20151231.csv',
         #'/home/sallen/202007/202007F/ObsModel_202007F_pugts_20150101_20151231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_ctd_20160101_20161231.csv',
        #  '/home/sallen/202007/202007F/ObsModel_202007F_psfts_20160101_20161231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_pugts_20160101_20161231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_ctd_20170101_20171231.csv',
        #  '/home/sallen/202007/202007F/ObsModel_202007F_psfts_20170101_20171231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_pugts_20170101_20171231.csv',
         '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20160101_20161231.csv',
    '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20170101_20171231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20160101_20161231.csv',
        # '/home/sallen/202007/202007F/ObsModel_202007F_ferry_20170101_20171231.csv'
         )

# %%
temp2 = read_pieces(pieces)
#temp2['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
temp2['SA'] = temp2['salinity (g/kg)']
temp2.drop(columns='Unnamed: 0', inplace=True)
temp2.drop_duplicates(inplace=True)

# %%
pieces = (
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20160101_20161231.csv',
    '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1_ferry_20170101_20171231.csv',
         )

# %%
temp3 = read_pieces(pieces)
#temp2['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
temp3['SA'] = temp3['salinity (g/kg)']
temp3.drop(columns='Unnamed: 0', inplace=True)
temp3.drop_duplicates(inplace=True)

# %%
pieces = (
         '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20160101_20161231.csv',
    '/home/sallen/202007/202007F/ObsModel_202007F0f_ferry_20170101_20171231.csv',
         )

# %%
temp4 = read_pieces(pieces)
#temp2['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
temp4['SA'] = temp4['salinity (g/kg)']
temp4.drop(columns='Unnamed: 0', inplace=True)
temp4.drop_duplicates(inplace=True)

# %%
pieces = (
         '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20160101_20161231.csv',
     '/home/sallen/202007/202007G-p1/ObsModel_202007Gp1f0_ferry_20170101_20171231.csv',
         )

# %%
tempGp1f = read_pieces(pieces)
#temp2['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
tempGp1f['SA'] = tempGp1f['salinity (g/kg)']
tempGp1f.drop(columns='Unnamed: 0', inplace=True)
tempGp1f.drop_duplicates(inplace=True)

# %%
pieces = (
         '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20150101_20151231.csv',
    '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20160101_20161231.csv',
    '/home/sallen/202007/202007G-p2/ObsModel_202007Gp2f0_ferry_20170101_20171231.csv',
         )

# %%
tempGp2f = read_pieces(pieces)
#temp2['SA'] = temp1.SA.fillna(value=temp1['salinity (g/kg)'])
tempGp2f['SA'] = tempGp2f['salinity (g/kg)']
tempGp2f.drop(columns='Unnamed: 0', inplace=True)
tempGp2f.drop_duplicates(inplace=True)

# %%
## Some Quick Looks at Distribution

# %%
plt.plot(temp3.Lon, temp3.mod_vosaline - temp3.SA, 'o')

# %%
## Remove some bad data
#cleaned = temp3[(temp3.Lon > -123.8) | (temp3.SA > 14)]
more_clean = temp3[((temp3.SA > 0.2) | (temp3.mod_vosaline - temp3.SA < 20)) & ((temp3.Lon > -123.8) | (temp3.SA > 14))]

# %%
def cleanup_ferry(temp3):
    return temp3[((temp3.SA > 0.2) | (temp3.mod_vosaline - temp3.SA < 20)) & ((temp3.Lon > -123.8) | (temp3.SA > 14))]

# %%
fig, axs = plt.subplots(1, 2, figsize= (12, 5))
axs[0].plot(temp3.Lon, temp3.SA, 'o');
axs[0].plot(cleaned.Lon, cleaned.SA, 'rx');
axs[0].plot(more_clean.Lon, more_clean.SA, 'gx')
axs[1].plot(temp3.Lon, temp3.mod_vosaline, 'o');
axs[0].set_ylim(0, 1);
axs[0].grid();

# %%
plt.hist2d(temp1.Lon[temp3.mod_vosaline-temp3.SA > 5], temp1.Lat[temp3.mod_vosaline-temp3.SA > 5]);

# %%
plt.hist2d(temp1.Lon[temp3.mod_vosaline-temp3.SA < -5], temp1.Lat[temp3.mod_vosaline-temp3.SA < -5]);

# %%
plt.hist(temp4.mod_vosaline - temp4.SA, bins=[-20, -15, -10, -5, 0, 5, 10, 15, 20])
print ((temp4.mod_vosaline - temp4.SA).mean())
print ((temp4.mod_vosaline - temp4.SA).std()/np.sqrt((temp4.mod_vosaline - temp4.SA).count()))
print ((temp4.mod_vosaline - temp4.SA).count())

# %%
## And now bin across the Strait

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 7))
bin_means, bin_edges, binnumber = stats.binned_statistic(temp4.Lon, temp4.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='g', lw=5,
               label='Obs');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp1.Lon, temp1.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='k', lw=5,
               label='Gp2');
bin_means, bin_edges, binnumber = stats.binned_statistic(tempGp2f.Lon, tempGp2f.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='gray', lw=5,
               label='Gp2-f0');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp2.Lon, temp2.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='b', lw=5,
               label='F');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp3.Lon, temp3.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='r', lw=5,
               label='Gp1');
bin_means, bin_edges, binnumber = stats.binned_statistic(tempGp1f.Lon, tempGp1f.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='orange', lw=5,
               label='Gp1-f0');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp4.Lon, temp4.mod_vosaline, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='c', lw=5,
               label='F at surface');
plt.grid();
plt.legend(loc='lower left');

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 7))
bin_means, bin_edges, binnumber = stats.binned_statistic(temp1.Lon, temp1.mod_vosaline - temp1.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='k', lw=5,
               label='Gp2');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp2.Lon, temp2.mod_vosaline - temp2.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='b', lw=5,
               label='F');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp3.Lon, temp3.mod_vosaline - temp3.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='r', lw=5,
               label='Gp1');
bin_means, bin_edges, binnumber = stats.binned_statistic(temp4.Lon, temp4.mod_vosaline - temp4.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='c', lw=5,
               label='F at surface');
bin_means, bin_edges, binnumber = stats.binned_statistic(tempGp2f.Lon, tempGp2f.mod_vosaline - tempGp2f.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='gray', lw=5,
               label='Gp2-f0');
bin_means, bin_edges, binnumber = stats.binned_statistic(tempGp1f.Lon, tempGp1f.mod_vosaline - tempGp1f.SA, 'mean', bins=100)
plt.hlines(bin_means, bin_edges[:-1], bin_edges[1:], colors='orange', lw=5,
               label='Gp1-f0');
plt.legend(loc='upper left');
plt.grid();
