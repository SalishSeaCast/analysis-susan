# %%
import cmocean.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline

# %%
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_201702.nc')
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc')

# %%
puck = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1h_20150201_20150205_carp_T_20150201-20150201.nc')
puck2 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1h_20150201_20150205_carp_T_20150202-20150202.nc')
puck3 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1h_20150201_20150205_carp_T_20150203-20150203.nc')
puck4 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1h_20150201_20150205_carp_T_20150204-20150204.nc')
puck5 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1h_20150201_20150205_carp_T_20150205-20150205.nc')

# %%
marco = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1h_20150201_20150205_carp_T_20150201-20150201.nc')
marco2 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1h_20150201_20150205_carp_T_20150202-20150202.nc')
marco3 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1h_20150201_20150205_carp_T_20150203-20150203.nc')
marco4 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1h_20150201_20150205_carp_T_20150204-20150204.nc')
marco5 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1h_20150201_20150205_carp_T_20150205-20150205.nc')

# %%
tvdnew = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1h_20150201_20150205_carp_T_20150201-20150201.nc')
tvdnew2 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1h_20150201_20150205_carp_T_20150202-20150202.nc')
tvdnew3 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1h_20150201_20150205_carp_T_20150203-20150203.nc')
tvdnew4 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1h_20150201_20150205_carp_T_20150204-20150204.nc')
tvdnew5 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1h_20150201_20150205_carp_T_20150205-20150205.nc')

# %%
tvdold = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1h_20150201_20150205_carp_T_20150201-20150201.nc')
tvdold2 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1h_20150201_20150205_carp_T_20150202-20150202.nc')
tvdold3 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1h_20150201_20150205_carp_T_20150203-20150203.nc')
tvdold4 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1h_20150201_20150205_carp_T_20150204-20150204.nc')
tvdold5 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1h_20150201_20150205_carp_T_20150205-20150205.nc')

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
puck.Fraser_tracer[23, 15].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
puck2.Fraser_tracer[23, 15].plot(ax=axs[1]);
puck3.Fraser_tracer[23, 15].plot(ax=axs[2]);
puck4.Fraser_tracer[23, 15].plot(ax=axs[3]);
puck5.Fraser_tracer[23, 15].plot(ax=axs[4]);
#bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[1]);

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
marco.Fraser_tracer[23, 15].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
marco2.Fraser_tracer[23, 15].plot(ax=axs[1]);
marco3.Fraser_tracer[23, 15].plot(ax=axs[2]);
marco4.Fraser_tracer[23, 15].plot(ax=axs[3]);
marco5.Fraser_tracer[23, 15].plot(ax=axs[4]);
#bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[1]);

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
tvdnew.Fraser_tracer[23, 15].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
tvdnew2.Fraser_tracer[23, 15].plot(ax=axs[1]);
tvdnew3.Fraser_tracer[23, 15].plot(ax=axs[2]);
tvdnew4.Fraser_tracer[23, 15].plot(ax=axs[3]);
tvdnew5.Fraser_tracer[23, 15].plot(ax=axs[4]);

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
tvdold.Fraser_tracer[23, 15].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
tvdold2.Fraser_tracer[23, 15].plot(ax=axs[1]);
tvdold3.Fraser_tracer[23, 15].plot(ax=axs[2]);
tvdold4.Fraser_tracer[23, 15].plot(ax=axs[3]);
tvdold5.Fraser_tracer[23, 15].plot(ax=axs[4]);

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
puck.Fraser_tracer[23, 0].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
puck2.Fraser_tracer[23, 0].plot(ax=axs[1]);
puck3.Fraser_tracer[23, 0].plot(ax=axs[2]);
puck4.Fraser_tracer[23, 0].plot(ax=axs[3]);
puck5.Fraser_tracer[23, 0].plot(ax=axs[4]);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
marco.Fraser_tracer[23, 0].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
marco2.Fraser_tracer[23, 0].plot(ax=axs[1]);
marco3.Fraser_tracer[23, 0].plot(ax=axs[2]);
marco4.Fraser_tracer[23, 0].plot(ax=axs[3]);
marco5.Fraser_tracer[23, 0].plot(ax=axs[4]);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
tvdnew.Fraser_tracer[23, 0].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
tvdnew2.Fraser_tracer[23, 0].plot(ax=axs[1]);
tvdnew3.Fraser_tracer[23, 0].plot(ax=axs[2]);
tvdnew4.Fraser_tracer[23, 0].plot(ax=axs[3]);
tvdnew5.Fraser_tracer[23, 0].plot(ax=axs[4]);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
tvdold.Fraser_tracer[23, 0].plot(ax=axs[0]);
bathy.Bathymetry.plot(cmap='winter_r', alpha=0.02, ax=axs[0]);
tvdold2.Fraser_tracer[23, 0].plot(ax=axs[1]);
tvdold3.Fraser_tracer[23, 0].plot(ax=axs[2]);
tvdold4.Fraser_tracer[23, 0].plot(ax=axs[3]);
tvdold5.Fraser_tracer[23, 0].plot(ax=axs[4]);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
horzsum = puck.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
marcosum = marco.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
elisesum = tvdnew.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
oldsum = tvdold.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
horzsum2 = puck2.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
marcosum2 = marco2.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
elisesum2 = tvdnew2.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
oldsum2 = tvdold2.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
horzsum3 = puck3.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
marcosum3 = marco3.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
oldsum3 = tvdold3.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
elisesum3 = tvdnew3.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
horzsum4 = puck4.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
oldsum4 = tvdold4.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
marcosum4 = marco4.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
elisesum4 = tvdnew4.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
horzsum5 = puck5.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
marcosum5 = marco5.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
elisesum5 = tvdnew5.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
oldsum5 = tvdold5.Fraser_tracer[:].sum(axis=2).sum(axis=2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.pcolormesh(horzsum.time_centered, horzsum.deptht, horzsum.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(horzsum2.time_centered, horzsum2.deptht, horzsum2.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(horzsum3.time_centered, horzsum3.deptht, horzsum3.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(horzsum4.time_centered, horzsum4.deptht, horzsum4.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(horzsum5.time_centered, horzsum5.deptht, horzsum5.transpose(), vmax=2e4, cmap=cm.matter)
ax.set_ylim(50, 0);

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.pcolormesh(marcosum.time_centered, marcosum.deptht, marcosum.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(marcosum2.time_centered, marcosum2.deptht, marcosum2.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(marcosum3.time_centered, marcosum3.deptht, marcosum3.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(marcosum4.time_centered, marcosum4.deptht, marcosum4.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(marcosum5.time_centered, marcosum5.deptht, marcosum5.transpose(), vmax=2e4, cmap=cm.matter)
ax.set_ylim(50, 0);

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.pcolormesh(elisesum.time_centered, elisesum.deptht, elisesum.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(elisesum2.time_centered, elisesum2.deptht, elisesum2.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(elisesum3.time_centered, elisesum3.deptht, elisesum3.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(elisesum4.time_centered, elisesum4.deptht, elisesum4.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(elisesum5.time_centered, elisesum5.deptht, elisesum5.transpose(), vmax=2e4, cmap=cm.matter)
ax.set_ylim(50, 0);

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
ax.pcolormesh(oldsum.time_centered, oldsum.deptht, oldsum.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(oldsum2.time_centered, oldsum2.deptht, oldsum2.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(oldsum3.time_centered, oldsum3.deptht, oldsum3.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(oldsum4.time_centered, oldsum4.deptht, oldsum4.transpose(), vmax=2e4, cmap=cm.matter)
ax.pcolormesh(oldsum5.time_centered, oldsum5.deptht, oldsum5.transpose(), vmax=2e4, cmap=cm.matter)
ax.set_ylim(50, 0);

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
horzsum[0, 0:20].plot(ax=axs[0], y='deptht', label='0')
horzsum[3, 0:20].plot(ax=axs[0], y='deptht', label='3')
horzsum[6, 0:20].plot(ax=axs[0], y='deptht', label='6')
horzsum[9, 0:20].plot(ax=axs[0], y='deptht', label='9')
horzsum[12, 0:20].plot(ax=axs[0], y='deptht', label='12')
horzsum[15, 0:20].plot(ax=axs[0], y='deptht', label='15')
horzsum[18, 0:20].plot(ax=axs[0], y='deptht', label='18')
horzsum[21, 0:20].plot(ax=axs[0], y='deptht', label='21')
horzsum2[0, 0:20].plot(ax=axs[1], y='deptht')
horzsum2[3, 0:20].plot(ax=axs[1], y='deptht', label='3')
horzsum2[6, 0:20].plot(ax=axs[1], y='deptht')
horzsum2[9, 0:20].plot(ax=axs[1], y='deptht', label='9')
horzsum2[12, 0:20].plot(ax=axs[1], y='deptht')
horzsum2[15, 0:20].plot(ax=axs[1], y='deptht', label='15')
horzsum2[18, 0:20].plot(ax=axs[1], y='deptht')
horzsum2[21, 0:20].plot(ax=axs[1], y='deptht', label='21')
horzsum3[0, 0:20].plot(ax=axs[2], y='deptht')
horzsum3[3, 0:20].plot(ax=axs[2], y='deptht', label='3')
horzsum3[6, 0:20].plot(ax=axs[2], y='deptht')
horzsum3[9, 0:20].plot(ax=axs[2], y='deptht', label='9')
horzsum3[12, 0:20].plot(ax=axs[2], y='deptht')
horzsum3[15, 0:20].plot(ax=axs[2], y='deptht', label='15')
horzsum3[18, 0:20].plot(ax=axs[2], y='deptht')
horzsum3[21, 0:20].plot(ax=axs[2], y='deptht', label='21')
horzsum4[0, 0:22].plot(ax=axs[3], y='deptht')
horzsum4[3, 0:22].plot(ax=axs[3], y='deptht', label='3')
horzsum4[6, 0:22].plot(ax=axs[3], y='deptht')
horzsum4[9, 0:22].plot(ax=axs[3], y='deptht', label='9')
horzsum4[12, 0:22].plot(ax=axs[3], y='deptht')
horzsum4[15, 0:22].plot(ax=axs[3], y='deptht', label='15')
horzsum4[18, 0:22].plot(ax=axs[3], y='deptht')
horzsum4[21, 0:22].plot(ax=axs[3], y='deptht', label='21')
horzsum5[0, 0:25].plot(ax=axs[4], y='deptht')
horzsum5[3, 0:25].plot(ax=axs[4], y='deptht', label='3')
horzsum5[6, 0:25].plot(ax=axs[4], y='deptht')
horzsum5[9, 0:25].plot(ax=axs[4], y='deptht', label='9')
horzsum5[12, 0:25].plot(ax=axs[4], y='deptht')
horzsum5[15, 0:25].plot(ax=axs[4], y='deptht', label='15')
horzsum5[18, 0:25].plot(ax=axs[4], y='deptht')
horzsum5[21, 0:25].plot(ax=axs[4], y='deptht', label='21')
for ax in axs:
    ax.invert_yaxis()
    ax.legend(loc='lower center')

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
marcosum[0, 0:20].plot(ax=axs[0], y='deptht', label='0')
marcosum[3, 0:20].plot(ax=axs[0], y='deptht', label='3')
marcosum[6, 0:20].plot(ax=axs[0], y='deptht', label='6')
marcosum[9, 0:20].plot(ax=axs[0], y='deptht', label='9')
marcosum[12, 0:20].plot(ax=axs[0], y='deptht', label='12')
marcosum[15, 0:20].plot(ax=axs[0], y='deptht', label='15')
marcosum[18, 0:20].plot(ax=axs[0], y='deptht', label='18')
marcosum[21, 0:20].plot(ax=axs[0], y='deptht', label='21')
marcosum2[0, 0:20].plot(ax=axs[1], y='deptht')
marcosum2[3, 0:20].plot(ax=axs[1], y='deptht', label='3')
marcosum2[6, 0:20].plot(ax=axs[1], y='deptht')
marcosum2[9, 0:20].plot(ax=axs[1], y='deptht', label='9')
marcosum2[12, 0:20].plot(ax=axs[1], y='deptht')
marcosum2[15, 0:20].plot(ax=axs[1], y='deptht', label='15')
marcosum2[18, 0:20].plot(ax=axs[1], y='deptht')
marcosum2[21, 0:20].plot(ax=axs[1], y='deptht', label='21')
marcosum3[0, 0:20].plot(ax=axs[2], y='deptht')
marcosum3[3, 0:20].plot(ax=axs[2], y='deptht', label='3')
marcosum3[6, 0:20].plot(ax=axs[2], y='deptht')
marcosum3[9, 0:20].plot(ax=axs[2], y='deptht', label='9')
marcosum3[12, 0:20].plot(ax=axs[2], y='deptht')
marcosum3[15, 0:20].plot(ax=axs[2], y='deptht', label='15')
marcosum3[18, 0:20].plot(ax=axs[2], y='deptht')
marcosum3[21, 0:20].plot(ax=axs[2], y='deptht', label='21')
marcosum4[0, 0:22].plot(ax=axs[3], y='deptht')
marcosum4[3, 0:22].plot(ax=axs[3], y='deptht', label='3')
marcosum4[6, 0:22].plot(ax=axs[3], y='deptht')
marcosum4[9, 0:22].plot(ax=axs[3], y='deptht', label='9')
marcosum4[12, 0:22].plot(ax=axs[3], y='deptht')
marcosum4[15, 0:22].plot(ax=axs[3], y='deptht', label='15')
marcosum4[18, 0:22].plot(ax=axs[3], y='deptht')
marcosum4[21, 0:22].plot(ax=axs[3], y='deptht', label='21')
marcosum5[0, 0:25].plot(ax=axs[4], y='deptht')
marcosum5[3, 0:25].plot(ax=axs[4], y='deptht', label='3')
marcosum5[6, 0:25].plot(ax=axs[4], y='deptht')
marcosum5[9, 0:25].plot(ax=axs[4], y='deptht', label='9')
marcosum5[12, 0:25].plot(ax=axs[4], y='deptht')
marcosum5[15, 0:25].plot(ax=axs[4], y='deptht', label='15')
marcosum5[18, 0:25].plot(ax=axs[4], y='deptht')
marcosum5[21, 0:25].plot(ax=axs[4], y='deptht', label='21')
for ax in axs:
    ax.invert_yaxis()
    ax.legend(loc='lower center')

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
elisesum[0, 0:20].plot(ax=axs[0], y='deptht', label='0')
elisesum[3, 0:20].plot(ax=axs[0], y='deptht', label='3')
elisesum[6, 0:20].plot(ax=axs[0], y='deptht', label='6')
elisesum[9, 0:20].plot(ax=axs[0], y='deptht', label='9')
elisesum[12, 0:20].plot(ax=axs[0], y='deptht', label='12')
elisesum[15, 0:20].plot(ax=axs[0], y='deptht', label='15')
elisesum[18, 0:20].plot(ax=axs[0], y='deptht', label='18')
elisesum[21, 0:20].plot(ax=axs[0], y='deptht', label='21')
elisesum2[0, 0:20].plot(ax=axs[1], y='deptht')
elisesum2[3, 0:20].plot(ax=axs[1], y='deptht', label='3')
elisesum2[6, 0:20].plot(ax=axs[1], y='deptht')
elisesum2[9, 0:20].plot(ax=axs[1], y='deptht', label='9')
elisesum2[12, 0:20].plot(ax=axs[1], y='deptht')
elisesum2[15, 0:20].plot(ax=axs[1], y='deptht', label='15')
elisesum2[18, 0:20].plot(ax=axs[1], y='deptht')
elisesum2[21, 0:20].plot(ax=axs[1], y='deptht', label='21')
elisesum3[0, 0:20].plot(ax=axs[2], y='deptht')
elisesum3[3, 0:20].plot(ax=axs[2], y='deptht', label='3')
elisesum3[6, 0:20].plot(ax=axs[2], y='deptht')
elisesum3[9, 0:20].plot(ax=axs[2], y='deptht', label='9')
elisesum3[12, 0:20].plot(ax=axs[2], y='deptht')
elisesum3[15, 0:20].plot(ax=axs[2], y='deptht', label='15')
elisesum3[18, 0:20].plot(ax=axs[2], y='deptht')
elisesum3[21, 0:20].plot(ax=axs[2], y='deptht', label='21')
elisesum4[0, 0:22].plot(ax=axs[3], y='deptht')
elisesum4[3, 0:22].plot(ax=axs[3], y='deptht', label='3')
elisesum4[6, 0:22].plot(ax=axs[3], y='deptht')
elisesum4[9, 0:22].plot(ax=axs[3], y='deptht', label='9')
elisesum4[12, 0:22].plot(ax=axs[3], y='deptht')
elisesum4[15, 0:22].plot(ax=axs[3], y='deptht', label='15')
elisesum4[18, 0:22].plot(ax=axs[3], y='deptht')
elisesum4[21, 0:22].plot(ax=axs[3], y='deptht', label='21')
elisesum5[0, 0:25].plot(ax=axs[4], y='deptht')
elisesum5[3, 0:25].plot(ax=axs[4], y='deptht', label='3')
elisesum5[6, 0:25].plot(ax=axs[4], y='deptht')
elisesum5[9, 0:25].plot(ax=axs[4], y='deptht', label='9')
elisesum5[12, 0:25].plot(ax=axs[4], y='deptht')
elisesum5[15, 0:25].plot(ax=axs[4], y='deptht', label='15')
elisesum5[18, 0:25].plot(ax=axs[4], y='deptht')
elisesum5[21, 0:25].plot(ax=axs[4], y='deptht', label='21')
for ax in axs:
    ax.invert_yaxis()
    ax.legend(loc='lower center')

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
oldsum[0, 0:20].plot(ax=axs[0], y='deptht', label='0')
oldsum[3, 0:20].plot(ax=axs[0], y='deptht', label='3')
oldsum[6, 0:20].plot(ax=axs[0], y='deptht', label='6')
oldsum[9, 0:20].plot(ax=axs[0], y='deptht', label='9')
oldsum[12, 0:20].plot(ax=axs[0], y='deptht', label='12')
oldsum[15, 0:20].plot(ax=axs[0], y='deptht', label='15')
oldsum[18, 0:20].plot(ax=axs[0], y='deptht', label='18')
oldsum[21, 0:20].plot(ax=axs[0], y='deptht', label='21')
oldsum2[0, 0:20].plot(ax=axs[1], y='deptht')
oldsum2[3, 0:20].plot(ax=axs[1], y='deptht', label='3')
oldsum2[6, 0:20].plot(ax=axs[1], y='deptht')
oldsum2[9, 0:20].plot(ax=axs[1], y='deptht', label='9')
oldsum2[12, 0:20].plot(ax=axs[1], y='deptht')
oldsum2[15, 0:20].plot(ax=axs[1], y='deptht', label='15')
oldsum2[18, 0:20].plot(ax=axs[1], y='deptht')
oldsum2[21, 0:20].plot(ax=axs[1], y='deptht', label='21')
oldsum3[0, 0:20].plot(ax=axs[2], y='deptht')
oldsum3[3, 0:20].plot(ax=axs[2], y='deptht', label='3')
oldsum3[6, 0:20].plot(ax=axs[2], y='deptht')
oldsum3[9, 0:20].plot(ax=axs[2], y='deptht', label='9')
oldsum3[12, 0:20].plot(ax=axs[2], y='deptht')
oldsum3[15, 0:20].plot(ax=axs[2], y='deptht', label='15')
oldsum3[18, 0:20].plot(ax=axs[2], y='deptht')
oldsum3[21, 0:20].plot(ax=axs[2], y='deptht', label='21')
oldsum4[0, 0:22].plot(ax=axs[3], y='deptht')
oldsum4[3, 0:22].plot(ax=axs[3], y='deptht', label='3')
oldsum4[6, 0:22].plot(ax=axs[3], y='deptht')
oldsum4[9, 0:22].plot(ax=axs[3], y='deptht', label='9')
oldsum4[12, 0:22].plot(ax=axs[3], y='deptht')
oldsum4[15, 0:22].plot(ax=axs[3], y='deptht', label='15')
oldsum4[18, 0:22].plot(ax=axs[3], y='deptht')
oldsum4[21, 0:22].plot(ax=axs[3], y='deptht', label='21')
oldsum5[0, 0:25].plot(ax=axs[4], y='deptht')
oldsum5[3, 0:25].plot(ax=axs[4], y='deptht', label='3')
oldsum5[6, 0:25].plot(ax=axs[4], y='deptht')
oldsum5[9, 0:25].plot(ax=axs[4], y='deptht', label='9')
oldsum5[12, 0:25].plot(ax=axs[4], y='deptht')
oldsum5[15, 0:25].plot(ax=axs[4], y='deptht', label='15')
oldsum5[18, 0:25].plot(ax=axs[4], y='deptht')
oldsum5[21, 0:25].plot(ax=axs[4], y='deptht', label='21')
for ax in axs:
    ax.invert_yaxis()
    ax.legend(loc='lower center')

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 7))
horzsum[:, 1].plot(ax=axs[0], color='b');
marcosum[:, 1].plot(ax=axs[0], color='lightblue');
horzsum2[:, 1].plot(ax=axs[0], color='b');
marcosum2[:, 1].plot(ax=axs[0], color='lightblue');
horzsum3[:, 1].plot(ax=axs[0], color='b');
marcosum3[:, 1].plot(ax=axs[0], color='lightblue');
horzsum[:, 5].plot(ax=axs[0], color='orange');
marcosum[:, 5].plot(ax=axs[0], color='y');
horzsum2[:, 5].plot(ax=axs[0], color='orange');
marcosum2[:, 5].plot(ax=axs[0], color='y');
horzsum3[:, 5].plot(ax=axs[0], color='orange');
marcosum3[:, 5].plot(ax=axs[0], color='y');
horzsum[:, 9].plot(ax=axs[0], color='green');
marcosum[:, 9].plot(ax=axs[0], color='limegreen');
horzsum2[:, 9].plot(ax=axs[0], color='green');
marcosum2[:, 9].plot(ax=axs[0], color='limegreen');
horzsum3[:, 9].plot(ax=axs[0], color='green');
marcosum3[:, 9].plot(ax=axs[0], color='limegreen');
horzsum4[:, 13].plot(ax=axs[1], color='b');
marcosum4[:, 13].plot(ax=axs[1], color='lightblue');
horzsum2[:, 13].plot(ax=axs[1], color='b');
marcosum2[:, 13].plot(ax=axs[1], color='lightblue');
horzsum3[:, 13].plot(ax=axs[1], color='b');
marcosum3[:, 13].plot(ax=axs[1], color='lightblue');
horzsum4[:, 17].plot(ax=axs[1], color='orange');
marcosum4[:, 17].plot(ax=axs[1], color='y');
horzsum2[:, 17].plot(ax=axs[1], color='orange');
marcosum2[:, 17].plot(ax=axs[1], color='y');
horzsum3[:, 17].plot(ax=axs[1], color='orange');
marcosum3[:, 17].plot(ax=axs[1], color='y');
horzsum4[:, 21].plot(ax=axs[1], color='green');
marcosum4[:, 21].plot(ax=axs[1], color='limegreen');
horzsum2[:, 21].plot(ax=axs[1], color='green');
marcosum2[:, 21].plot(ax=axs[1], color='limegreen');
horzsum3[:, 21].plot(ax=axs[1], color='green');
marcosum3[:, 21].plot(ax=axs[1], color='limegreen');

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 7))
(horzsum[:, 1]-marcosum[:, 1]).plot(ax=axs[0], color='b');
(horzsum2[:, 1]-marcosum2[:, 1]).plot(ax=axs[0], color='b');
(horzsum3[:, 1]-marcosum3[:, 1]).plot(ax=axs[0], color='b');
(horzsum[:, 5]-marcosum[:, 5]).plot(ax=axs[0], color='orange');
(horzsum2[:, 5]-marcosum2[:, 5]).plot(ax=axs[0], color='orange');
(horzsum3[:, 5]-marcosum3[:, 5]).plot(ax=axs[0], color='orange');
(horzsum[:, 9]-marcosum[:, 9]).plot(ax=axs[0], color='green');
(horzsum2[:, 9]-marcosum2[:, 9]).plot(ax=axs[0], color='green');
(horzsum3[:, 9]-marcosum3[:, 9]).plot(ax=axs[0], color='green');
horzsum4[:, 13].plot(ax=axs[1], color='b');
marcosum4[:, 13].plot(ax=axs[1], color='lightblue');
horzsum2[:, 13].plot(ax=axs[1], color='b');
marcosum2[:, 13].plot(ax=axs[1], color='lightblue');
horzsum3[:, 13].plot(ax=axs[1], color='b');
marcosum3[:, 13].plot(ax=axs[1], color='lightblue');
horzsum4[:, 17].plot(ax=axs[1], color='orange');
marcosum4[:, 17].plot(ax=axs[1], color='y');
horzsum2[:, 17].plot(ax=axs[1], color='orange');
marcosum2[:, 17].plot(ax=axs[1], color='y');
horzsum3[:, 17].plot(ax=axs[1], color='orange');
marcosum3[:, 17].plot(ax=axs[1], color='y');
horzsum4[:, 21].plot(ax=axs[1], color='green');
marcosum4[:, 21].plot(ax=axs[1], color='limegreen');
horzsum2[:, 21].plot(ax=axs[1], color='green');
marcosum2[:, 21].plot(ax=axs[1], color='limegreen');
horzsum3[:, 21].plot(ax=axs[1], color='green');
marcosum3[:, 21].plot(ax=axs[1], color='limegreen');
axs[0].grid()

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
horzsum[23, 0:25].plot(color='b', y='deptht', ax=axs[0])
marcosum[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[0])
elisesum[23, 0:25].plot(color='orange', y='deptht', ax=axs[0])
oldsum[23, 0:25].plot(color='darkorange', y='deptht', ax=axs[0])
horzsum2[23, 0:25].plot(color='b', y='deptht', ax=axs[1])
marcosum2[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[1])
elisesum2[23, 0:25].plot(color='orange', y='deptht', ax=axs[1])
oldsum2[23, 0:25].plot(color='darkorange', y='deptht', ax=axs[1])
horzsum3[23, 0:25].plot(color='b', y='deptht', ax=axs[2])
marcosum3[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[2])
elisesum3[23, 0:25].plot(color='orange', y='deptht', ax=axs[2])
oldsum3[23, 0:25].plot(color='darkorange', y='deptht', ax=axs[2])
horzsum4[23, 0:25].plot(color='b', y='deptht', ax=axs[3])
marcosum4[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[3])
elisesum4[23, 0:25].plot(color='orange', y='deptht', ax=axs[3])
oldsum4[23, 0:25].plot(color='darkorange', y='deptht', ax=axs[3])
horzsum5[23, 0:25].plot(color='b', y='deptht', ax=axs[4])
marcosum5[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[4])
elisesum5[23, 0:25].plot(color='orange', y='deptht', ax=axs[4])
oldsum5[23, 0:25].plot(color='darkorange', y='deptht', ax=axs[4])
for ax in axs:
    ax.invert_yaxis()
    ax.grid()

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
(horzsum[23, 0:25]-elisesum[23, 0:25]).plot(color='b', y='deptht', ax=axs[0])
(marcosum[23, 0:25]-elisesum[23, 0:25]).plot(color='lightblue', y='deptht', ax=axs[0])
(elisesum[23, 0:25]-elisesum[23, 0:25]).plot(color='orange', y='deptht', ax=axs[0])
(oldsum[23, 0:25]-elisesum[23, 0:25]).plot(color='darkorange', y='deptht', ax=axs[0])
(horzsum2[23, 0:25]-elisesum2[23, 0:25]).plot(color='b', y='deptht', ax=axs[1])
(marcosum2[23, 0:25]-elisesum2[23, 0:25]).plot(color='lightblue', y='deptht', ax=axs[1])
(elisesum2[23, 0:25]-elisesum2[23, 0:25]).plot(color='orange', y='deptht', ax=axs[1])
(oldsum2[23, 0:25]-elisesum2[23, 0:25]).plot(color='darkorange', y='deptht', ax=axs[1])
(horzsum3[23, 0:25]-elisesum3[23, 0:25]).plot(color='b', y='deptht', ax=axs[2])
(marcosum3[23, 0:25]-elisesum3[23, 0:25]).plot(color='lightblue', y='deptht', ax=axs[2])
(elisesum3[23, 0:25]-elisesum3[23, 0:25]).plot(color='orange', y='deptht', ax=axs[2])
(oldsum3[23, 0:25]-elisesum3[23, 0:25]).plot(color='darkorange', y='deptht', ax=axs[2])
(horzsum4[23, 0:25]-elisesum4[23, 0:25]).plot(color='b', y='deptht', ax=axs[3])
(marcosum4[23, 0:25]-elisesum4[23, 0:25]).plot(color='lightblue', y='deptht', ax=axs[3])
(elisesum4[23, 0:25]-elisesum4[23, 0:25]).plot(color='orange', y='deptht', ax=axs[3])
(oldsum4[23, 0:25]-elisesum4[23, 0:25]).plot(color='darkorange', y='deptht', ax=axs[3])
(horzsum5[23, 0:25]-elisesum5[23, 0:25]).plot(color='b', y='deptht', ax=axs[4])
(marcosum5[23, 0:25]-elisesum5[23, 0:25]).plot(color='lightblue', y='deptht', ax=axs[4])
(elisesum5[23, 0:25]-elisesum5[23, 0:25]).plot(color='orange', y='deptht', ax=axs[4])
(oldsum5[23, 0:25]-elisesum5[23, 0:25]).plot(color='darkorange', y='deptht', ax=axs[4])
for ax in axs:
    ax.invert_yaxis()
    ax.grid()

# %%
puck_boxcontent = np.empty((5*24, 40, 898, 398))

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(puck5.Fraser_tracer[i]) * np.array(puck5.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598018571.62912
# 39366699408.82813
# 48055173305.83672
# 46431910010.92886

# %%
# fifth day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 55656461526.376175
# 50709940931.15971
# 58053957883.077614
# 57544280607.320946

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(marco5.Fraser_tracer[i]) * np.array(marco5.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598020864.12397
# 39366803891.81364
# 48055570456.13128
# 46433373165.84578

# %%
# fifth day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 55669146735.978485
# 50733353260.97644
# 58077436673.3712
# 57564471645.1315

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(tvdnew.Fraser_tracer[i]) * np.array(tvdnew.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598015225.29197
# 39367076136.029785
# 48055921160.59993
# 46433083337.75201

# %%
# fifth day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 55673606383.234406
# 50730520961.924835
# 58073583543.016815
# 57560383052.111755

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(tvdold.Fraser_tracer[i]) * np.array(tvdold.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598015225.298416
# 39367081803.622
# 48055939115.71923
# 46433133335.76923

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i, :, :700, 100:]))
# Out:
# 34373899538.57357
# 34373846439.18375
# 34373790326.66838
# 34373851329.906685

# %%
mesh.e2t.shape
# Out:
# (1, 898, 398)
