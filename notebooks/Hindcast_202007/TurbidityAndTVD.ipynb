# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline

# %%
olddir = 'averages/hindcast.201905/'
newdir = '202007/202007A/'
year = '2015'
month = '12'
file = 'carp'
dm = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{olddir}/SalishSea_1m_{year}{month}_{year}{month}_{file}_T.nc')
ds = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{newdir}/SalishSea_1m_{year}{month}_{year}{month}_{file}_T.nc')

# %%
dm.Fraser_tracer[0, 0:15, 420, 360].plot(y='deptht', yincrease=False, label='Hindcast: not TVD');
ds.Fraser_tracer[0, 0:15, 420, 360].plot(y='deptht', yincrease=False, label='TVD');
plt.legend();

# %%
olddir = '202007/checkit/'
dir3 = '202007/zeroreflect'
dirbbc = '202007/fbbc'
dirbbcr = '202007/fbbc_reflect'
dircake = '202007/cake'
dirzero = '202007/zerobot2'
dirmarco = '202007/Marco1'
year = '2015'
month = '02'
file = 'carp'
dm = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{olddir}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
dz = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dir3}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
dbbc = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dirbbc}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
dbbc2 = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dirbbc}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
dbbcr = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirbbcr}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
dcake = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dircake}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
dzero = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirzero}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
dMarco1 = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirmarco}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')

# %%
dm.Fraser_tracer[0, 0:15, 420, 360].plot(linestyle='-', marker='x', y='deptht', yincrease=False, label='Original TVD')
dz.Fraser_tracer[0, 0:15, 420, 360].plot(y='deptht', yincrease=False, label='No Reflection');
dbbc.Fraser_tracer[0, 0:15, 420, 360].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbc2.Fraser_tracer[0, 0:15, 420, 360].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:15, 420, 360].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:15, 420, 360].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:15, 420, 360].plot(marker='x', y='deptht', yincrease=False, label='ZeroBot');
dMarco1.Fraser_tracer[0, 0:15, 420, 360].plot(marker='x', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
(dbbcr.Fraser_tracer[23, 0:10, 420, 360]-dbbc2.Fraser_tracer[23, 0:15, 420, 360]).plot(y='deptht', yincrease=False);
(dcake.Fraser_tracer[23, 0:10, 420, 360]-dbbcr.Fraser_tracer[23, 0:15, 420, 360]).plot(y='deptht', yincrease=False);
(dcake.Fraser_tracer[23, 0:10, 420, 360]-dbbc2.Fraser_tracer[23, 0:15, 420, 360]).plot(y='deptht', yincrease=False);
(dzero.Fraser_tracer[23, 0:10, 420, 360]-dbbc2.Fraser_tracer[23, 0:15, 420, 360]).plot(y='deptht', yincrease=False);
(dMarco1.Fraser_tracer[23, 0:10, 420, 360]-dbbc2.Fraser_tracer[23, 0:15, 420, 360]).plot(y='deptht', yincrease=False);

# %%
dz.Fraser_tracer[:, 0:15, 420, 360].plot(y='deptht', yincrease=False, label='No Reflection');

# %%
dz.Fraser_tracer[:, 10, 420, 360].plot()
dz.Fraser_tracer[:, 9, 420, 360].plot()

# %%
dbbc2.Fraser_tracer[:, 0:15, 420, 360].plot(y='deptht', yincrease=False, label='Bottom Boundary Condition');

# %%
dbbcr.Fraser_tracer[:, 0:15, 420, 360].plot(y='deptht', yincrease=False);

# %%
dcake.Fraser_tracer[:, 0:15, 420, 360].plot(y='deptht', yincrease=False);

# %%
dzero.Fraser_tracer[:, 0:15, 420, 360].plot(y='deptht', yincrease=False);

# %%
dbbc.Fraser_tracer[:, 10, 420, 360].plot()
dbbc.Fraser_tracer[:, 9, 420, 360].plot()

# %%
file = 'ptrc'
pm = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{olddir}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
pz = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dir3}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
pbbc = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dirbbc}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}05-{year}{month}05.nc')
pbbc2 = xr.open_dataset(
        f'/data/sallen/results/MEOPAR/{dirbbc}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
pbbcr = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirbbcr}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
pcake = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dircake}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
pzero = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirzero}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')
pMarco1 = xr.open_dataset(
f'/data/sallen/results/MEOPAR/{dirmarco}/SalishSea_1h_{year}{month}01_{year}{month}05_{file}_T_{year}{month}02-{year}{month}02.nc')

# %%
(pbbc2.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(pbbcr.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection');
(pcake.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Cake');
(pzero.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');
(pMarco1.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Marco');

# %%
(dbbc2.Fraser_tracer[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(dbbcr.Fraser_tracer[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection', marker='+');
(dcake.Fraser_tracer[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Cake');
(dzero.Fraser_tracer[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');
(dMarco1.Fraser_tracer[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Marco', marker='o');

# %%
(pbbc2.particulate_organic_nitrogen[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(pbbcr.particulate_organic_nitrogen[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection', marker='+');
(pcake.particulate_organic_nitrogen[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Cake');
(pzero.particulate_organic_nitrogen[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');
(pMarco1.particulate_organic_nitrogen[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');

# %%
(pbbc2.diatoms[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(pbbcr.diatoms[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection');
(pMarco1.diatoms[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Marco');

# %%
(pMarco1.diatoms[23, 0:32, 420, 280]-pbbcr.diatoms[23, 0:32, 420, 280]).plot(y='deptht', yincrease=False);
plt.ylim(50, 0);
# Out:
# (50.0, 0.0)

# %%
(pbbc2.nitrate[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(pbbcr.nitrate[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection');
(pcake.nitrate[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Cake');
(pzero.nitrate[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');
(pMarco1.nitrate[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');

# %%
(pbbc2.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='BBC fixed')
(pbbcr.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='With reflection');
(pcake.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Cake');
(pzero.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Zero Bot');
(pMarco1.biogenic_silicon[0, 0:32, 420, 280]).plot(y='deptht', yincrease=False, label='Marco');
plt.ylim(30, 0);

# %%
pbbcr.biogenic_silicon[0, 12, 420, 280]
# Out:
# <xarray.DataArray 'biogenic_silicon' ()>
# array(45.07859)
# Coordinates:
#     nav_lat        float32 ...
#     nav_lon        float32 ...
#     deptht         float32 12.518167
#     time_centered  datetime64[ns] ...
#     time_counter   datetime64[ns] 2015-02-02T00:30:00
# Attributes:
#     standard_name:       mole_concentration_of_organic_detritus_expressed_as_...
#     long_name:           Biogenic Silicon Concentration
#     units:               mmol m-3
#     online_operation:    average
#     interval_operation:  40 s
#     interval_write:      1 h
#     cell_methods:        time: mean (interval: 40 s)
#     cell_measures:       area: area

# %%
pbbcr.biogenic_silicon[0, 12, 400:440, 260:300].plot();
#plt.ylim(400, 440)
#plt.xlim(260, 300);

# %%
pbbcr.biogenic_silicon[0, 0:12, 420, 260:320].plot(yincrease=False);

# %%
dbbc2.Fraser_tracer[0, 0:33, 420, 250:320].plot(yincrease=False, vmax=1/200.);

# %%
dbbcr.Fraser_tracer[0, 0:33, 420, 250:320].plot(yincrease=False, vmax=1/200.);

# %%
dcake.Fraser_tracer[0, 0:33, 420, 250:320].plot(yincrease=False, vmax=1/200.);

# %%
dzero.Fraser_tracer[0, 0:33, 420, 250:320].plot(yincrease=False, vmax=1/200.);

# %%
dMarco1.Fraser_tracer[0, 0:33, 420, 250:320].plot(yincrease=False, vmax=1/200.);

# %%
dbbc2.Fraser_tracer[0, 0:10, 420, 290:360].plot(yincrease=False, vmax=12.1, vmin=12.05);

# %%
dbbcr.Fraser_tracer[0, 0:10, 420, 290:360].plot(yincrease=False, vmax=12.1, vmin=12.05);

# %%
dcake.Fraser_tracer[0, 0:10, 420, 290:360].plot(yincrease=False, vmax=12.1, vmin=12.);

# %%
dzero.Fraser_tracer[0, 0:10, 420, 290:360].plot(yincrease=False, vmax=12.1, vmin=12.05);

# %%
dMarco1.Fraser_tracer[0, 0:10, 420, 290:360].plot(yincrease=False, vmax=12.1, vmin=12.05);

# %%
dbbc2.Fraser_tracer[0, 0:11, 420, 360].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:11, 420, 360].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:11, 420, 360].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:11, 420, 360].plot(marker='o', y='deptht', yincrease=False, label='Zero Bot');
dMarco1.Fraser_tracer[0, 0:11, 420, 360].plot(marker='o', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:6, 420, 359].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:6, 420, 359].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:6, 420, 359].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:6, 420, 359].plot(marker='o', y='deptht', yincrease=False, label='Zero');
dMarco1.Fraser_tracer[0, 0:6, 420, 359].plot(marker='o', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:5, 420, 358].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:5, 420, 358].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:5, 420, 358].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:5, 420, 358].plot(marker='o', y='deptht', yincrease=False, label='Zero');
dMarco1.Fraser_tracer[0, 0:5, 420, 358].plot(marker='o', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:4, 420, 357].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:4, 420, 357].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:4, 420, 357].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:4, 420, 357].plot(marker='o', y='deptht', yincrease=False, label='Zero');
dMarco1.Fraser_tracer[0, 0:4, 420, 357].plot(marker='o', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:4, 419, 356].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:4, 419, 356].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:4, 419, 356].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:4, 419, 356].plot(marker='o', y='deptht', yincrease=False, label='Zero');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:4, 419, 355].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:4, 419, 355].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:4, 419, 355].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:4, 419, 355].plot(marker='o', y='deptht', yincrease=False, label='Zero');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:4, 418, 354].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:4, 418, 354].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:4, 418, 354].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:4, 418, 354].plot(marker='o', y='deptht', yincrease=False, label='Zero');
plt.legend();

# %%
dbbc2.Fraser_tracer[0, 0:5, 418, 352].plot(marker='+', y='deptht', yincrease=False, label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[0, 0:5, 418, 352].plot(marker='+', y='deptht', yincrease=False, label='With Reflection');
dcake.Fraser_tracer[0, 0:5, 418, 352].plot(marker='o', y='deptht', yincrease=False, label='Cake');
dzero.Fraser_tracer[0, 0:5, 418, 352].plot(marker='o', y='deptht', yincrease=False, label='Zero');
dMarco1.Fraser_tracer[0, 0:5, 418, 352].plot(marker='o', y='deptht', yincrease=False, label='Marco');
plt.legend();

# %%
(dbbc2.Fraser_tracer[0, 3, 400:445, 300:361]-dbbc2.Fraser_tracer[0, 2, 400:445, 300:361]).plot(vmax=2);

# %%
(dbbcr.Fraser_tracer[0, 3, 400:445, 300:361]-dbbcr.Fraser_tracer[0, 2, 400:445, 300:361]).plot(vmax=2);

# %%
(dcake.Fraser_tracer[0, 3, 400:445, 300:361]-dcake.Fraser_tracer[0, 2, 400:445, 300:361]).plot(vmax=2);

# %%
(dzero.Fraser_tracer[0, 3, 400:445, 300:361]-dzero.Fraser_tracer[0, 2, 400:445, 300:361]).plot(vmax=2);

# %%
(dMarco1.Fraser_tracer[0, 3, 400:445, 300:361]-dMarco1.Fraser_tracer[0, 2, 400:445, 300:361]).plot(vmax=2);

# %%
dbbc2.Fraser_tracer[:, 3, 418, 354].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 418, 354].plot(marker='+', label='With Reflection');
dcake.Fraser_tracer[:, 3, 418, 354].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 3, 420, 357].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 420, 357].plot(marker='+', label='With Reflection');
dcake.Fraser_tracer[:, 3, 420, 357].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 3, 420, 358].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 420, 358].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 3, 420, 358].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 10, 420, 360].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 10, 420, 360].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 10, 420, 360].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 3, 418, 352].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 418, 352].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 3, 418, 352].plot(marker='o', label='Cake');

# %%
pbbc2.diatoms[:, 3, 418, 352].plot(marker='+', label='Add Bottom Boundary Condition');
pbbcr.diatoms[:, 3, 418, 352].plot(marker='x', label='With Reflection');
pcake.diatoms[:, 3, 418, 352].plot(marker='o', label='Cake');

# %%
pbbc2.particulate_organic_nitrogen[:, 3, 418, 352].plot(marker='+', label='Add Bottom Boundary Condition');
pbbcr.particulate_organic_nitrogen[:, 3, 418, 352].plot(marker='x', label='With Reflection');
pcake.particulate_organic_nitrogen[:, 3, 418, 352].plot(marker='o', label='Cake');
pzero.particulate_organic_nitrogen[:, 3, 418, 352].plot(marker='o', label='Zero');
pMarco1.particulate_organic_nitrogen[:, 3, 418, 352].plot(marker='o', label='Marco');

# %%
iz = 3
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for ix in range(4):
    for iy in range(4):
        dbbc2.Fraser_tracer[ix+iy*4, iz, 410:425, 345:360].plot(ax=axs[iy, ix]);
        axs[iy, ix].plot(418-410, 352-345,'ro');

# %%
iz = 3
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for ix in range(4):
    for iy in range(2):
        dbbcr.Fraser_tracer[ix+iy*4, iz, 410:425, 345:360].plot(ax=axs[iy, ix], vmin=13.75, vmax=13.8);
        axs[iy, ix].plot(418-410, 352-345,'ro');
    for iy in range(2,4):
        dbbcr.Fraser_tracer[ix+iy*4, iz, 410:425, 345:360].plot(ax=axs[iy, ix], vmin=14.73, vmax=14.78);
        axs[iy, ix].plot(418-410, 352-345,'ro');

# %%
iz = 3
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for ix in range(4):
    for iy in range(2):
        dzero.Fraser_tracer[ix+iy*4, iz, 410:425, 345:360].plot(ax=axs[iy, ix], vmin=13.75, vmax=13.8);
        axs[iy, ix].plot(418-410, 352-345,'ro');
    for iy in range(2,4):
        dzero.Fraser_tracer[ix+iy*4, iz, 410:425, 345:360].plot(ax=axs[iy, ix], vmin=14.73, vmax=14.78);
        axs[iy, ix].plot(418-410, 352-345,'ro');

# %%
dbbc2.Fraser_tracer[:, 5, 416, 350].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 5, 416, 350].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 5, 416, 350].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 3, 416, 345].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 416, 345].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 3, 416, 345].plot(marker='o', label='Cake');

# %%
dbbc2.Fraser_tracer[:, 7, 415, 340].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 7, 415, 340].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 7, 415, 340].plot(marker='o', label='Cake');
dMarco1.Fraser_tracer[:, 7, 415, 340].plot(marker='o', label='Marco');

# %%
dbbc2.Fraser_tracer[:, 5, 416, 335].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 5, 416, 335].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 5, 416, 335].plot(marker='o', label='Cake');
dzero.Fraser_tracer[:, 5, 416, 335].plot(marker='o', label='ZeroBot');
dMarco1.Fraser_tracer[:, 5, 416, 335].plot(marker='o', label='Marco');

# %%
dbbc2.Fraser_tracer[:, 5, 415, 330].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 5, 415, 330].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 5, 415, 330].plot(marker='o', label='Cake');
dMarco1.Fraser_tracer[:, 5, 415, 330].plot(marker='o', label='Marco');

# %%
dbbc2.Fraser_tracer[:, 3, 416, 325].plot(marker='+', label='Add Bottom Boundary Condition');
dbbcr.Fraser_tracer[:, 3, 416, 325].plot(marker='x', label='With Reflection');
dcake.Fraser_tracer[:, 3, 416, 325].plot(marker='o', label='Cake');
dzero.Fraser_tracer[:, 3, 416, 325].plot(marker='+', label='Zerobot');
dMarco1.Fraser_tracer[:, 3, 416, 325].plot(marker='o', label='Marco');

# %%
dbbc2.Fraser_tracer[2, :12, 416, 325].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dbbcr.Fraser_tracer[2, :12, 416, 325].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dcake.Fraser_tracer[2, :12, 416, 325].plot(marker='x', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dzero.Fraser_tracer[2, :12, 416, 325].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dMarco1.Fraser_tracer[2, :12, 416, 325].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);

# %%
dbbcr.Fraser_tracer[2, 3, 400:450, 310:360].plot(vmin=5);
plt.plot(335-310, 416-400, 'ro');

# %%
dzero.Fraser_tracer[2, 3, 400:450, 310:360].plot(vmin=5);
plt.plot(335-310, 416-400, 'ro');

# %%
dMarco1.Fraser_tracer[2, 3, 400:450, 310:360].plot(vmin=5);
plt.plot(335-310, 416-400, 'ro');

# %%
(dbbcr.Fraser_tracer[2, 3, 400:450, 310:360]-dzero.Fraser_tracer[2, 3, 400:450, 310:360]).plot(vmax=5e-5);
plt.plot(335-310, 416-400, 'ro');

# %%
(dMarco1.Fraser_tracer[2, 3, 400:450, 310:360]-dzero.Fraser_tracer[2, 3, 400:450, 310:360]).plot(vmax=5e-3);
plt.plot(335-310, 416-400, 'ro');

# %%
dzero.Fraser_tracer[2, :12, 430, 310].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dMarco1.Fraser_tracer[2, :12, 430, 310].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);

# %%
dzero.Fraser_tracer[2, :12, 412, 323].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);
dMarco1.Fraser_tracer[2, :12, 412, 323].plot(marker='+', label='Add Bottom Boundary Condition', y='deptht', yincrease=False);

# %%
iz = 3
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for ix in range(4):
    for iy in range(2):
        dzero.Fraser_tracer[ix+iy*4, iz, 410:425, 330:345].plot(ax=axs[iy, ix], vmin=13.73, vmax=13.78);
        axs[iy, ix].plot(338-330, 415-410,'ro');
    for iy in range(2,4):
        dzero.Fraser_tracer[ix+iy*4, iz, 410:425, 330:345].plot(ax=axs[iy, ix], vmin=14.78, vmax=14.83);
        axs[iy, ix].plot(338-330, 415-410,'ro');

# %%
iz = 3
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
for ix in range(4):
    for iy in range(2):
        dMarco1.Fraser_tracer[ix+iy*4, iz, 410:425, 330:345].plot(ax=axs[iy, ix], vmin=13.73, vmax=13.78);
        axs[iy, ix].plot(338-330, 415-410,'ro');
    for iy in range(2,4):
        dMarco1.Fraser_tracer[ix+iy*4, iz, 410:425, 330:345].plot(ax=axs[iy, ix], vmin=14.7, vmax=14.73);
        axs[iy, ix].plot(338-330, 415-410,'ro');
