# %%
import cmocean.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %matplotlib inline

# %%
bathy = xr.open_dataset('/home/sallen/MEOPAR/grid/bathymetry_201702.nc')
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc')

# %%
puck = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150201-20150201.nc')
puck2 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150202-20150202.nc')
puck3 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150203-20150203.nc')
puck4 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150204-20150204.nc')
puck5 = xr.open_dataset('/home/sallen/202007/Upwind_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150205-20150205.nc')

# %%
upwind = xr.concat([puck, puck2, puck3, puck4, puck5], 'time_counter')

# %%
marco = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150201-20150201.nc')
marco2 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150202-20150202.nc')
marco3 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150203-20150203.nc')
marco4 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150204-20150204.nc')
marco5 = xr.open_dataset('/home/sallen/202007/MUSCL_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150205-20150205.nc')

# %%
MUSCL = xr.concat([marco, marco2, marco3, marco4, marco5], 'time_counter')

# %%
old = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150201-20150201.nc')
old2 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150202-20150202.nc')
old3 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150203-20150203.nc')
old4 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150204-20150204.nc')
old5 = xr.open_dataset('/home/sallen/202007/TVD_OLD_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150205-20150205.nc')

# %%
oldTVD = xr.concat([old, old2, old3, old4, old5], 'time_counter')

# %%
new = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150201-20150201.nc')
new2 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150202-20150202.nc')
new3 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150203-20150203.nc')
new4 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150204-20150204.nc')
new5 = xr.open_dataset('/home/sallen/202007/TVD_NEW_puck/SalishSea_1d_20150201_20150205_ptrc_T_20150205-20150205.nc')

# %%
newTVD = xr.concat([new, new2, new3, new4, new5], 'time_counter')

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
upwind.diatoms[0, 5].plot(ax=axs[0], vmax=1);
upwind.diatoms[1, 5].plot(ax=axs[1], vmax=1);
upwind.diatoms[2, 5].plot(ax=axs[2], vmax=1);
upwind.diatoms[3, 5].plot(ax=axs[3], vmax=1);
upwind.diatoms[4, 5].plot(ax=axs[4], vmax=1);

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
MUSCL.diatoms[0, 5].plot(ax=axs[0], vmax=1);
MUSCL.diatoms[1, 5].plot(ax=axs[1], vmax=1);
MUSCL.diatoms[2, 5].plot(ax=axs[2], vmax=1);
MUSCL.diatoms[3, 5].plot(ax=axs[3], vmax=1);
MUSCL.diatoms[4, 5].plot(ax=axs[4], vmax=1);

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
upwind.diatoms[0, 0].plot(ax=axs[0], vmax=1.5);
upwind.diatoms[1, 0].plot(ax=axs[1], vmax=1.5);
upwind.diatoms[2, 0].plot(ax=axs[2], vmax=1.5);
upwind.diatoms[3, 0].plot(ax=axs[3], vmax=1.5);
upwind.diatoms[4, 0].plot(ax=axs[4], vmax=1.5);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
MUSCL.diatoms[0, 0].plot(ax=axs[0], vmax=1.5);
MUSCL.diatoms[1, 0].plot(ax=axs[1], vmax=1.5);
MUSCL.diatoms[2, 0].plot(ax=axs[2], vmax=1.5);
MUSCL.diatoms[3, 0].plot(ax=axs[3], vmax=1.5);
MUSCL.diatoms[4, 0].plot(ax=axs[4], vmax=1.5);
for ax in axs:
    ax.set_xlim(180,398)
    ax.set_ylim(400,550)

# %%
izi, ize = 0, 5
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
(upwind.diatoms[0, izi:ize]-newTVD.diatoms[0, izi:ize]).sum(axis=0).plot(ax=axs[0]);
(upwind.diatoms[1, izi:ize]-newTVD.diatoms[1, izi:ize]).sum(axis=0).plot(ax=axs[1]);
(upwind.diatoms[2, izi:ize]-newTVD.diatoms[2, izi:ize]).sum(axis=0).plot(ax=axs[2]);
(upwind.diatoms[3, izi:ize]-newTVD.diatoms[3, izi:ize]).sum(axis=0).plot(ax=axs[3]);
(upwind.diatoms[4, izi:ize]-newTVD.diatoms[4, izi:ize]).sum(axis=0).plot(ax=axs[4], vmax=0.2);

# %%
izi, ize = 0, 10
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
(MUSCL.diatoms[0, izi:ize]-newTVD.diatoms[0, izi:ize]).sum(axis=0).plot(ax=axs[0]);
(MUSCL.diatoms[1, izi:ize]-newTVD.diatoms[1, izi:ize]).sum(axis=0).plot(ax=axs[1]);
(MUSCL.diatoms[2, izi:ize]-newTVD.diatoms[2, izi:ize]).sum(axis=0).plot(ax=axs[2]);
(MUSCL.diatoms[3, izi:ize]-newTVD.diatoms[3, izi:ize]).sum(axis=0).plot(ax=axs[3]);
(MUSCL.diatoms[4, izi:ize]-newTVD.diatoms[4, izi:ize]).sum(axis=0).plot(ax=axs[4]);

# %%
izi, ize = 0, 10
fig, axs = plt.subplots(1, 5, figsize=(21, 7))
(oldTVD.diatoms[0, izi:ize]-newTVD.diatoms[0, izi:ize]).sum(axis=0).plot(ax=axs[0], vmax=2);
(oldTVD.diatoms[1, izi:ize]-newTVD.diatoms[1, izi:ize]).sum(axis=0).plot(ax=axs[1], vmax=2);
(oldTVD.diatoms[2, izi:ize]-newTVD.diatoms[2, izi:ize]).sum(axis=0).plot(ax=axs[2], vmax=2);
(oldTVD.diatoms[3, izi:ize]-newTVD.diatoms[3, izi:ize]).sum(axis=0).plot(ax=axs[3], vmax=2);
(oldTVD.diatoms[4, izi:ize]-newTVD.diatoms[4, izi:ize]).sum(axis=0).plot(ax=axs[4], vmax=2);

# %%
horzsum = upwind.diatoms[:].sum(axis=2).sum(axis=2)

# %%
marcosum = MUSCL.diatoms[:].sum(axis=2).sum(axis=2)

# %%
oldsum = oldTVD.diatoms[:].sum(axis=2).sum(axis=2)

# %%
newsum = newTVD.diatoms[:].sum(axis=2).sum(axis=2)

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
for i in range(5):
    horzsum[i, 0:20].plot(ax=axs[i], y='deptht', color='blue')
    marcosum[i, 0:20].plot(ax=axs[i], y='deptht', color='lightblue')
    newsum[i, 0:20].plot(ax=axs[i], y='deptht', color='orange')
    oldsum[i, 0:20].plot(ax=axs[i], y='deptht', color='darkorange')
for ax in axs:
    ax.invert_yaxis()

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 7))
for i in range(5):
    (horzsum[i, 0:20]-newsum[i, 0:20]).plot(ax=axs[i], y='deptht', color='blue')
    (marcosum[i, 0:20]-newsum[i, 0:20]).plot(ax=axs[i], y='deptht', color='lightblue')
    (oldsum[i, 0:20]-newsum[i, 0:20]).plot(ax=axs[i], y='deptht', color='darkorange')
for ax in axs:
    ax.invert_yaxis()
    ax.grid()

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 7))
horzsum[:, 1].plot(ax=axs[0], color='b');
marcosum[:, 1].plot(ax=axs[0], color='lightblue');
horzsum2[:, 1].plot(ax=axs[0], color='b');
marcosum2[:, 1].plot(ax=axs[0], color='lightblue');
horzsum3[:, 1].plot(ax=axs[0], color='b');
marcosum3[:, 1].plot(ax=axs[0], color='lightblue');
horzsum[:, 5].plot(ax=axs[0], color='orange');
marcosum[:, 5].plot(ax=axs[0], color='y');
horzsum2[:, 5].plot(ax=axs[0], color='orange');
marcosum2[:, 5].plot(ax=axs[0], color='y');
horzsum3[:, 5].plot(ax=axs[0], color='orange');
marcosum3[:, 5].plot(ax=axs[0], color='y');
horzsum[:, 9].plot(ax=axs[0], color='green');
marcosum[:, 9].plot(ax=axs[0], color='limegreen');
horzsum2[:, 9].plot(ax=axs[0], color='green');
marcosum2[:, 9].plot(ax=axs[0], color='limegreen');
horzsum3[:, 9].plot(ax=axs[0], color='green');
marcosum3[:, 9].plot(ax=axs[0], color='limegreen');
horzsum4[:, 13].plot(ax=axs[1], color='b');
marcosum4[:, 13].plot(ax=axs[1], color='lightblue');
horzsum2[:, 13].plot(ax=axs[1], color='b');
marcosum2[:, 13].plot(ax=axs[1], color='lightblue');
horzsum3[:, 13].plot(ax=axs[1], color='b');
marcosum3[:, 13].plot(ax=axs[1], color='lightblue');
horzsum4[:, 17].plot(ax=axs[1], color='orange');
marcosum4[:, 17].plot(ax=axs[1], color='y');
horzsum2[:, 17].plot(ax=axs[1], color='orange');
marcosum2[:, 17].plot(ax=axs[1], color='y');
horzsum3[:, 17].plot(ax=axs[1], color='orange');
marcosum3[:, 17].plot(ax=axs[1], color='y');
horzsum4[:, 21].plot(ax=axs[1], color='green');
marcosum4[:, 21].plot(ax=axs[1], color='limegreen');
horzsum2[:, 21].plot(ax=axs[1], color='green');
marcosum2[:, 21].plot(ax=axs[1], color='limegreen');
horzsum3[:, 21].plot(ax=axs[1], color='green');
marcosum3[:, 21].plot(ax=axs[1], color='limegreen');

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 7))
(horzsum[:, 1]-marcosum[:, 1]).plot(ax=axs[0], color='b');
(horzsum2[:, 1]-marcosum2[:, 1]).plot(ax=axs[0], color='b');
(horzsum3[:, 1]-marcosum3[:, 1]).plot(ax=axs[0], color='b');
(horzsum[:, 5]-marcosum[:, 5]).plot(ax=axs[0], color='orange');
(horzsum2[:, 5]-marcosum2[:, 5]).plot(ax=axs[0], color='orange');
(horzsum3[:, 5]-marcosum3[:, 5]).plot(ax=axs[0], color='orange');
(horzsum[:, 9]-marcosum[:, 9]).plot(ax=axs[0], color='green');
(horzsum2[:, 9]-marcosum2[:, 9]).plot(ax=axs[0], color='green');
(horzsum3[:, 9]-marcosum3[:, 9]).plot(ax=axs[0], color='green');
horzsum4[:, 13].plot(ax=axs[1], color='b');
marcosum4[:, 13].plot(ax=axs[1], color='lightblue');
horzsum2[:, 13].plot(ax=axs[1], color='b');
marcosum2[:, 13].plot(ax=axs[1], color='lightblue');
horzsum3[:, 13].plot(ax=axs[1], color='b');
marcosum3[:, 13].plot(ax=axs[1], color='lightblue');
horzsum4[:, 17].plot(ax=axs[1], color='orange');
marcosum4[:, 17].plot(ax=axs[1], color='y');
horzsum2[:, 17].plot(ax=axs[1], color='orange');
marcosum2[:, 17].plot(ax=axs[1], color='y');
horzsum3[:, 17].plot(ax=axs[1], color='orange');
marcosum3[:, 17].plot(ax=axs[1], color='y');
horzsum4[:, 21].plot(ax=axs[1], color='green');
marcosum4[:, 21].plot(ax=axs[1], color='limegreen');
horzsum2[:, 21].plot(ax=axs[1], color='green');
marcosum2[:, 21].plot(ax=axs[1], color='limegreen');
horzsum3[:, 21].plot(ax=axs[1], color='green');
marcosum3[:, 21].plot(ax=axs[1], color='limegreen');
axs[0].grid()

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 7))
horzsum[23, 0:25].plot(color='b', y='deptht', ax=axs[0])
marcosum[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[0])
horzsum2[23, 0:25].plot(color='b', y='deptht', ax=axs[1])
marcosum2[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[1])
horzsum3[23, 0:25].plot(color='b', y='deptht', ax=axs[2])
marcosum3[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[2])
horzsum4[23, 0:25].plot(color='b', y='deptht', ax=axs[3])
marcosum4[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[3])
horzsum5[23, 0:25].plot(color='b', y='deptht', ax=axs[4])
marcosum5[23, 0:25].plot(color='lightblue', y='deptht', ax=axs[4])
for ax in axs:
    ax.invert_yaxis()
    ax.grid()

# %%
puck_boxcontent = np.empty((5*24, 40, 898, 398))

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(puck5.Fraser_tracer[i]) * np.array(puck5.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598018571.62912
# 39366699408.82813
# 48055173305.83672
# 46431910010.92886

# %%
# fifth day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 55656461526.376175
# 50709940931.15971
# 58053957883.077614
# 57544280607.320946

# %%
for i in [0, 6, 12, 18]:
    puck_boxcontent[i] = (np.array(marco5.Fraser_tracer[i]) * np.array(marco5.e3t[i])
                          * np.array(mesh.tmask[0]) * np.array(mesh.e2t[0])
                          * np.array(mesh.e1t[0]))

# %%
# first day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 36598020864.12397
# 39366803891.81364
# 48055570456.13128
# 46433373165.84578

# %%
# fifth day
for i in [0, 6, 12, 18]:
    print(np.nansum(puck_boxcontent[i]))
# Out:
# 55669146735.978485
# 50733353260.97644
# 58077436673.3712
# 57564471645.1315
