# %% [markdown]
# Detailed panel by panel comparison of bathymetry 201702 to 201803d and the river file for 201803 (which was done earlier than d)

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

from salishsea_tools import river_202101 as r202101
from salishsea_tools import river_201803 as r201803

# %matplotlib inline

# %%
b201702 = xr.open_dataset('../../../../grid/bathymetry_201702.nc')
b201803d = xr. open_dataset('../../../../sea_initial_hg/bathymetry_201803d.nc')

# %%
r202102 = xr.open_dataset('../../../../rivers-climatology/rivers_daily_202102.nc').rorunoff[5]
r201803 = xr.open_dataset('../../../../sea_initial_hg/rivers_month_201803.nc').rorunoff[5]
d202102 = xr.open_dataset('../../../../rivers-climatology/rivers_daily_202102.nc').rodepth[5]
d201803 = xr.open_dataset('../../../../sea_initial_hg/rivers_month_201803.nc').rodepth[:]

# %%
def make_the_plots(istart, iend, jstart,jend):
    fig, axs = plt.subplots(2, 3, figsize=(15, 10))
    colours = axs[0, 0].pcolormesh(np.arange(jstart, jend+1), np.arange(istart, iend+1), b201702.Bathymetry[istart:iend, jstart:jend],
            cmap='nipy_spectral', vmax=15);
    axs[0, 1].pcolormesh(np.arange(jstart, jend+1), np.arange(istart, iend+1), b201803d.Bathymetry[istart:iend, jstart:jend],
            cmap='nipy_spectral', vmax=15);
    colours = axs[0, 2].pcolormesh(np.arange(jstart, jend+1), np.arange(istart, iend+1), 
             (b201803d.Bathymetry[istart:iend, jstart:jend].fillna(0) 
            - b201702.Bathymetry[istart:iend, jstart:jend].fillna(0)), cmap='Blues_r');
    highest = np.max(b201803d.Bathymetry[istart:iend, jstart:jend].fillna(0) 
            - b201702.Bathymetry[istart:iend, jstart:jend].fillna(0)).item()
    lowest = np.min(b201803d.Bathymetry[istart:iend, jstart:jend].fillna(0) 
            - b201702.Bathymetry[istart:iend, jstart:jend].fillna(0)).item()
    axs[0, 2].text(jstart+10, iend-10, f'{lowest}-{highest}')
    for i in range(istart, iend):
        for j in range(jstart, jend):
            if r202102[i, j] > 0:
                axs[0, 0].plot(j, i, 'ro')
                axs[1, 0].scatter(j, i, c=d202102[i, j]/3., s=100)
                axs[1, 2].scatter(j, i, c='r',s=100)
    for i in range(istart, iend):
        for j in range(jstart, jend):
            if r201803[i, j] > 0:
                axs[0, 1].plot(j, i, 'ro')
                axs[1, 1].scatter(j, i, c=d201803[i, j]/3., s=100)
                axs[1, 2].scatter(j, i, c='b')
    for ax in axs[1]:
        ax.set_xlim(jstart, jend);
        ax.set_ylim(istart, iend);
    return fig, axs

# %% [markdown]
# ## Tile Ninety-seven, Ninety-Eight
#  * empty
#
# ## Tile Ninety-Nine
#
#  * small changes in Island shapes

# %%
istart, iend = 600, 650
jstart, jend = 100, 150
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ks', markersize=4)

# %% [markdown]
# ## Tile One Hundred
#
# * slight changes

# %%
istart, iend = 600, 650
jstart, jend = 150, 200
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred-one
#
# * ok

# %%
istart, iend = 600, 650
jstart, jend = 200, 250
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred-two
#
# * no change

# %%
istart, iend = 600, 650
jstart, jend = 250, 300
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred-three
#
# * no change

# %%
istart, iend = 600, 650
jstart, jend = 280, 350
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred-four, 105, 106
#
# * empty
#
# ## Tile One Hundred-seven

# %%
istart, iend = 650, 700
jstart, jend = 100, 150
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Eight
#
# * looks fine, made Savary more substantial

# %%
istart, iend = 650, 700
jstart, jend = 150, 200
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Nine
#
# * No difference

# %%
istart, iend = 650, 700
jstart, jend = 200, 250
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred Ten
#
# * empty
#
# ## 111, 112
#
# * hard to plot

# %%
istart, iend = 650, 700
jstart, jend = 200, 398
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = 340, 350
ii, ie = 670, 690
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=15)

# %% [markdown]
# ## Tile One Hundred Thirteen, 114
#
# * empty
#
# ## Tile One Hundred Fifteen
#
# * coastline edits

# %%
istart, iend = 700, 750
jstart, jend = 100, 150
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## One Hundred Sixteen
#
# * coastline edits

# %%
istart, iend = 700, 750
jstart, jend = 150, 200
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Seventeen
#
# * coastline edits

# %%
istart, iend = 700, 750
jstart, jend = 180, 250
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred Eighteen, 119, 120, 121, 122
#
# * empty
#
# ## Tile One Hundred Twenty-three
#
# * coastline edits

# %%
istart, iend = 750, 800
jstart, jend = 100, 150
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Twenty-Four
#
# * don't close north of Read Island which is easily navigable at low tide by small motor boats

# %%
istart, iend = 750, 800
jstart, jend = 150, 200
fig, axs = make_the_plots(istart, iend, jstart,jend)
for ii in range(istart, iend):
    for jj in range(jstart, jend):
        if (b201803d.Bathymetry[ii, jj] != b201803d.Bathymetry[ii, jj]) & (b201702.Bathymetry[ii, jj] == b201702.Bathymetry[ii, jj]):
            if (ii > 770) & (ii < 785):
                if (jj > 165):
                    print (ii, jj, b201702.Bathymetry[ii, jj].values)
                    axs[0, 1].plot(jj, ii, 'rx')
# Out:
# 777 170 7.6875
# 777 171 4.0
# 778 170 8.4375
# 778 171 4.0
# 778 172 4.0
# 778 173 4.0
# 779 172 4.0
# 779 173 4.0
# 779 174 4.0
# 779 175 7.8125
# 780 174 5.875

# %%
js, je = jstart, jend-15
ii, ie = istart+25, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Twenty-Five
#
# * small coastline change

# %%
istart, iend = 750, 800
jstart, jend = 180, 250
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred twenty-six, 127, 128
# * no change, small coastline, empty, respectively

# %%
istart, iend = 750, 800
jstart, jend = 250, 398
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = 300, 320
ii, ie = 770, 780
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Twenty-nine
#
# * empty
#
# ## Tile One Hundred Thirty
#
# * no change
#
# ## Tile One Hundred Thirty-one
#
# * fine

# %%
istart, iend = 800, 850
jstart, jend = 100, 150
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = 130, 150
ii, ie = 830, 850
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=10)

# %% [markdown]
# ## Tile One Hundred Thirty-two
#
# * Stuart Island should be disconnected

# %%
istart, iend = 800, 850
jstart, jend = 150, 200
fig, axs = make_the_plots(istart, iend, jstart,jend)
for ii in range(istart, iend):
    for jj in range(jstart, jend):
        if (b201803d.Bathymetry[ii, jj] != b201803d.Bathymetry[ii, jj]) & (b201702.Bathymetry[ii, jj] == b201702.Bathymetry[ii, jj]):
#            if (ii > 770) & (ii < 785):
#                if (jj > 165):
                    print (ii, jj, b201702.Bathymetry[ii, jj].values)
                    axs[0, 1].plot(jj+0.5, ii+0.5, 'rx')
# Out:
# 800 160 12.125
# 800 161 5.4375
# 802 161 4.0
# 807 180 20.0625
# 808 180 14.9375
# 809 180 10.5
# 809 181 11.1875
# 810 180 19.5
# 810 181 22.125
# 810 182 22.9375
# 814 187 28.4375

# %%
js, je = 170, 190
ii, ie = 800, 820
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=10)
            print (i, j, b201702.Bathymetry[i, j].values)
# Out:
# 807 180 20.0625
# 808 180 14.9375
# 809 180 10.5
# 809 181 11.1875
# 810 180 19.5
# 810 181 22.125
# 810 182 22.9375
# 814 187 28.4375

# %% [markdown]
# ## Tile One Hundred Thirty-three, 134
#
# * no change
#
# ## Tile One Hundred Thirty-five, 136
#
# * empty

# %%
istart, iend = 800, 850
jstart, jend = 180, 398
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart+20, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=10)

# %% [markdown]
# ## Tile One hundred thirty-seven
#
# * no change
#
# ## Tile One hundred thirty-eight
#
# * good

# %%
istart, iend = 850, 898
jstart, jend = 50, 100
make_the_plots(istart, iend, jstart,jend)

# %%
js, je = jstart, jend
ii, ie = istart, iend
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
colours = axs[0].pcolormesh(b201702.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[0])
colours = axs[1].pcolormesh(b201803d.Bathymetry[ii:ie, js:je], cmap='nipy_spectral', vmin=4, vmax=20);
fig.colorbar(colours, ax=axs[1])
colours = axs[2].pcolormesh(b201803d.Bathymetry[ii:ie, js:je] - b201702.Bathymetry[ii:ie, js:je], cmap='bwr', vmin=-7.5, vmax=7.5);
fig.colorbar(colours, ax=axs[2]);
for i in range(ii, ie):
    for j in range(js, je):
        if b201702.Bathymetry[i, j] == b201702.Bathymetry[i, j] and b201803d.Bathymetry[i, j] != b201803d.Bathymetry[i, j]:
            axs[2].plot(j -js + 0.5, i-ii + 0.5, 'ko', markersize=4)

# %% [markdown]
# ## Tile One Hundred Thiry-Nine
#
# * no changes

# %%
istart, iend = 850, 898
jstart, jend = 90, 150
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred  Forty
#
# * good

# %%
istart, iend = 850, 898
jstart, jend = 150, 200
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# # Tile One Hundred Forty-One
#
# * empty
#
# # Tile One Hundred Forty-Two
#
# * as expected

# %%
istart, iend = 850, 898
jstart, jend = 250, 300
make_the_plots(istart, iend, jstart,jend)

# %% [markdown]
# ## Tile One Hundred-Forty-Three, 144
#
# * empty

# %%
istart, iend = 850, 898
jstart, jend = 350, 398
make_the_plots(istart, iend, jstart,jend)
# Out:
# <__array_function__ internals>:5: UserWarning: Warning: converting a masked element to nan.
# /ocean/sallen/miniconda3/envs/py39/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
