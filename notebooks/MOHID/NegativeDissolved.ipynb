# %% [markdown]
# # Investigate Negative Dissolved Concentrations #

# %%
import pandas as pd

# %%
! ls /data/sallen/results/MIDOSS/Mass*
# Out:
# /data/sallen/results/MIDOSS/MassBalance_1-200_near-BP_spill-hr-172.sro

# %%
! head '/data/sallen/results/MIDOSS/MassBalance_1-200_near-BP_spill-hr-172.sro'
# Out:
# Time Serie Results File
# NAME                    : OilOutput
#  SERIE_INITIAL_DATA      : 2017.  4. 28. 15. 30.  0.0
# TIME_UNITS              : SECONDS
# ...

# %%
pd.read_csv('/data/sallen/results/MIDOSS/MassBalance_1-200_near-BP_spill-hr-172.sro')
# Out:
#                                Time Serie Results File
# 0                  NAME                    : OilOutput
# 1     SERIE_INITIAL_DATA      : 2017.  4. 28. 15. 3...
# 2                    TIME_UNITS              : SECONDS
# 3          Seconds   YY  MM  DD  hh  mm       ss   ...
# 4                                     <BeginTimeSerie>
# ..                                                 ...
# 107       367200.00 2017   5   2  21  30   0.0000  ...
# 108                                     <EndTimeSerie>
# 109                                    <BeginResidual>
# 110      367200.00 2017   5   2  21  30   0.0000   ...
# 111                                      <EndResidual>
#
# [112 rows x 1 columns]

# %%
pd.read_csv('/data/sallen/results/MIDOSS/MassBalance_1-200_near-BP_spill-hr-172.sro', skiprows=5, sep=' ')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
