# %%
import matplotlib.pyplot as plt
import xarray as xr

# %matplotlib inline
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
dec15 = xr.open_dataset('/home/sallen/public_html/SoG_ww3_fields_20181215_20181215.nc')

# %%
jj, ii = 254, 398

# %%
time = (12+8)*2

# %%
dec15.hs[:, jj, ii].plot();

# %%
aspanda = (dec15.hs[:, jj, ii]).to_pandas()

aspanda.to_csv('Krista_dec15.csv')
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dec15.hs[time, 200:300, 350:450].plot();

# %%
360-123.20396
# Out:
# 236.79604

# %%
dec15.close()

# %%
dec20 = xr.open_dataset('/home/sallen/public_html/SoG_ww3_fields_20181220_20181220.nc')

# %%
dec20.hs[:, jj, ii].plot();

# %%
aspanda = (dec20.hs[:, jj, ii]).to_pandas()

aspanda.to_csv('Krista_dec20.csv')
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dec20.close()

# %%
dec21 = xr.open_dataset('/home/sallen/public_html/SoG_ww3_fields_20181221_20181221.nc')
dec21.hs[:, jj, ii].plot();
aspanda = (dec21.hs[:, jj, ii]).to_pandas()

aspanda.to_csv('Krista_dec21.csv')
dec21.close()
# Out:
# /home/sallen/anaconda/envs/py38/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
