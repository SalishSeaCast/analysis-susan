# %% [markdown]
# Copied from Vicky's analysis space (and edited)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import datetime as dt
import cmocean
import xarray as xr

from salishsea_tools import nc_tools, viz_tools

# %matplotlib inline

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.titlesize'] = 18

# %%
mymesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask201702.nc')
e3t = mymesh['e3t_1d'][0]

# %%
mean_2007_2020_jun = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_jun_climate_2007_2020_prod_T.nc')
mean_2007_2020_jul = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_jul_climate_2007_2020_prod_T.nc')
mean_2007_2020_aug = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_aug_climate_2007_2020_prod_T.nc')

# %%
mean_totalphyto = (mean_2007_2020_jun['PPDIAT'][0] + mean_2007_2020_jun['PPPHY'][0] 
                    + mean_2007_2020_jun['PPMRUB'][0] +
                  mean_2007_2020_jul['PPDIAT'][0] + mean_2007_2020_jul['PPPHY'][0] 
                    + mean_2007_2020_jul['PPMRUB'][0] +
                  mean_2007_2020_aug['PPDIAT'][0] + mean_2007_2020_aug['PPPHY'][0] 
                    + mean_2007_2020_aug['PPMRUB'][0])/3.

# %%
mean_flag = (mean_2007_2020_jun['PPPHY'][0] + mean_2007_2020_jul['PPPHY'][0] 
                    + mean_2007_2020_aug['PPPHY'][0])/3.

# %%
mean_dia2_2007_2020_jun = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_jun_climate_2007_2020_dia2_T.nc')
mean_dia2_2007_2020_jul = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_jul_climate_2007_2020_dia2_T.nc')
mean_dia2_2007_2020_aug = xr.open_dataset('/data/sallen/results/MEOPAR/averages/SalishSea_aug_climate_2007_2020_dia2_T.nc')

# %%
mean_totalgraz = (mean_dia2_2007_2020_jun['GRMESZDIAT'][0] + mean_dia2_2007_2020_jun['GRMESZPHY'][0] 
                    + mean_dia2_2007_2020_jun['GRMESZMRUB'][0] +
                  mean_dia2_2007_2020_jun['GRMESZPON'][0] + mean_dia2_2007_2020_jun['GRMESZMICZ'][0] 
                  + mean_dia2_2007_2020_jul['GRMESZDIAT'][0] + mean_dia2_2007_2020_jul['GRMESZPHY'][0] 
                    + mean_dia2_2007_2020_jul['GRMESZMRUB'][0] +
                  mean_dia2_2007_2020_jul['GRMESZPON'][0] + mean_dia2_2007_2020_jul['GRMESZMICZ'][0]
                  + mean_dia2_2007_2020_aug['GRMESZDIAT'][0] + mean_dia2_2007_2020_aug['GRMESZPHY'][0] 
                    + mean_dia2_2007_2020_aug['GRMESZMRUB'][0] +
                  mean_dia2_2007_2020_aug['GRMESZPON'][0] + mean_dia2_2007_2020_aug['GRMESZMICZ'][0] 
                    )/3.

# %%
t2020_jun = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202006_202006_prod_T.nc')
t2020_jul = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202007_202007_prod_T.nc')
t2020_aug = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202008_202008_prod_T.nc')

# %%
t2020_totalphyto = (t2020_jun['PPDIAT'][0] + t2020_jun['PPPHY'][0] 
                    + t2020_jun['PPMRUB'][0] +
                  t2020_jul['PPDIAT'][0] + t2020_jul['PPPHY'][0] 
                    + t2020_jul['PPMRUB'][0] +
                  t2020_aug['PPDIAT'][0] + t2020_aug['PPPHY'][0] 
                    + t2020_aug['PPMRUB'][0])/3.

# %%
t2020_flag = (t2020_jun['PPPHY'][0] + t2020_jul['PPPHY'][0] 
                    + t2020_aug['PPPHY'][0])/3.

# %%
dia2_t2020_jun = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202006_202006_dia2_T.nc')
dia2_t2020_jul = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202007_202007_dia2_T.nc')
dia2_t2020_aug = xr.open_dataset('/data/sallen/results/MEOPAR/averages/hindcast.201905/SalishSea_1m_202008_202008_dia2_T.nc')

# %%
t2020_totalgraz = (dia2_t2020_jun['GRMESZDIAT'][0] + dia2_t2020_jun['GRMESZPHY'][0] 
                    + dia2_t2020_jun['GRMESZMRUB'][0] +
                  dia2_t2020_jun['GRMESZPON'][0] + dia2_t2020_jun['GRMESZMICZ'][0] 
                  + dia2_t2020_jul['GRMESZDIAT'][0] + dia2_t2020_jul['GRMESZPHY'][0] 
                    + dia2_t2020_jul['GRMESZMRUB'][0] +
                  dia2_t2020_jul['GRMESZPON'][0] + dia2_t2020_jul['GRMESZMICZ'][0]
                  + dia2_t2020_aug['GRMESZDIAT'][0] + dia2_t2020_aug['GRMESZPHY'][0] 
                    + dia2_t2020_aug['GRMESZMRUB'][0] +
                  dia2_t2020_aug['GRMESZPON'][0] + dia2_t2020_aug['GRMESZMICZ'][0] 
                    )/3.

# %%
print (mymesh.gdept_1d[0, 20:23])
lz = 21
thickness = e3t[:lz+1].sum()
# Out:
# <xarray.DataArray 'gdept_1d' (z: 3)>
# array([24.100257, 28.229915, 34.685758])
# Dimensions without coordinates: z
# Attributes:
#     standard_name:  gdept_1d
#     long_name:      nominal depth of T-grid points
#     units:          m
#     positive:       down

# %%
for i in range(lz):
    mean_totalphyto[i] = mean_totalphyto[i] * e3t[i] 
    mean_flag[i] = mean_flag[i] * e3t[i] 
    mean_totalgraz[i] = mean_totalgraz[i] * e3t[i]     
mean_totalphyto = mean_totalphyto[:lz].sum(axis=0)
mean_phyto_ratio = mean_flag[:lz].sum(axis=0)/mean_totalphyto
mean_totalgraz = mean_totalgraz[:lz].sum(axis=0)
print (mean_totalphyto.shape)
# Out:
# (898, 398)

# %%
for i in range(lz):
    t2020_totalphyto[i] = t2020_totalphyto[i] * e3t[i] 
    t2020_flag[i] = t2020_flag[i] * e3t[i] 
    t2020_totalgraz[i] = t2020_totalgraz[i] * e3t[i] 
t2020_totalphyto = t2020_totalphyto[:lz].sum(axis=0)
t2020_phyto_ratio = t2020_flag[:lz].sum(axis=0)/t2020_totalphyto
t2020_totalgraz = t2020_totalgraz[:lz].sum(axis=0)
print (t2020_totalphyto.shape)
# Out:
# (898, 398)

# %%
imin, imax = 350, 750
jmin, jmax = 100, 350
physcale = 86400 # per day

cmap = cmocean.cm.algae
cmap.set_bad('burlywood')
cmap2 = cmocean.cm.balance
cmap2.set_bad('burlywood')

fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### Primary Production ####
labelstring ='Primary Productivity ($\mu$mol N m$^{-2}$ day$^{-1}$)'
vmax = 30
vmin = 5
s = axs[0].pcolormesh(physcale*np.ma.masked_array(mean_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('Summer Mean 2007-2020');

s = axs[1].pcolormesh(physcale*np.ma.masked_array(t2020_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('Summer 2020')

vmax = 25
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array(t2020_totalphyto[imin:imax, jmin:jmax] 
                                           / mean_totalphyto[imin:imax, jmin:jmax] - np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2020')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);
    
fig.savefig('SummerProductivity2020.png')

# %%
fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### RATIO DIATOM PRODUCTIVITY ####
labelstring ='Ratio of Diatom Primary Productivity to Total Productivity'
scale = 1
vmax = 1
vmin = 0
cmap = cmocean.cm.tempo
cmap.set_bad('burlywood')

s = axs[0].pcolormesh(scale*np.ma.masked_array(1-mean_phyto_ratio[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('Summer Mean 2007-2020')

s = axs[1].pcolormesh(scale*np.ma.masked_array(1-t2020_phyto_ratio[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,22,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('Summer 2020')

vmax = 100
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array((1- t2020_phyto_ratio[imin:imax, jmin:jmax]) /
                                            (1 -mean_phyto_ratio[imin:imax, jmin:jmax]) -np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,22,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2020')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);

fig.savefig('SummerDiatoms2020.png')

# %%
fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### GRAZING ####
scale = 86400
vmax = 25
vmin = 0
cmap = cmocean.cm.speed
cmap.set_bad('burlywood')
labelstring ='Mesozooplankton Feeding ($\mu$mol N m$^{-2}$ day$^{-1}$)'

s = axs[0].pcolormesh(scale*np.ma.masked_array(mean_totalgraz[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('Summer Mean 2007-2019')

s = axs[1].pcolormesh(scale*np.ma.masked_array(t2020_totalgraz[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('Summer 2020')

vmax = 15
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array(t2020_totalgraz[imin:imax, jmin:jmax] /
                                           mean_totalgraz[imin:imax, jmin:jmax] -np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,22,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2019')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
    ax.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    right=False,      # ticks along the bottom edge are off
    left=False,         # ticks along the top edge are off
    labelleft=False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 9))
s = ax.pcolormesh(86400*np.ma.masked_array(mean_totalgraz[imin:imax, jmin:jmax] -mean_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), cmap=cmap2,
                 vmax=10, vmin=-10)
viz_tools.set_aspect(ax)
fig.colorbar(s);

# %% [markdown]
# ## July Only

# %%
mean_Jul_totalphyto = (
                  mean_2007_2020_jul['PPDIAT'][0] + mean_2007_2020_jul['PPPHY'][0] 
                    + mean_2007_2020_jul['PPMRUB'][0])

mean_Jul_flag = (mean_2007_2020_jul['PPPHY'][0] 
                    )

tyear_Jul_totalphyto = (
                  t2020_jul['PPDIAT'][0] + t2020_jul['PPPHY'][0] 
                    + t2020_jul['PPMRUB'][0] 
                  )

tyear_Jul_flag = (t2020_jul['PPPHY'][0] 
                    )

# %%
lz = 21
for i in range(lz):
    mean_Jul_totalphyto[i] = mean_Jul_totalphyto[i] * e3t[i] 
    mean_Jul_flag[i] = mean_Jul_flag[i] * e3t[i]   
mean_Jul_totalphyto = mean_Jul_totalphyto[:lz].sum(axis=0)
mean_Jul_phyto_ratio = mean_Jul_flag[:lz].sum(axis=0)/mean_Jul_totalphyto
print (mean_Jul_totalphyto.shape)
# Out:
# (398,)

# %%
for i in range(lz):
    tyear_Jul_totalphyto[i] = tyear_Jul_totalphyto[i] * e3t[i] 
    tyear_Jul_flag[i] = tyear_Jul_flag[i] * e3t[i] 
tyear_Jul_totalphyto = tyear_Jul_totalphyto[:lz].sum(axis=0)
tyear_Jul_phyto_ratio = tyear_Jul_flag[:lz].sum(axis=0)/tyear_Jul_totalphyto

print (tyear_Jul_totalphyto.shape)
# Out:
# (898, 398)

# %%
imin, imax = 350, 750
jmin, jmax = 100, 350
physcale = 86400 # per day

cmap = cmocean.cm.algae
cmap.set_bad('burlywood')
cmap2 = cmocean.cm.balance
cmap2.set_bad('burlywood')

fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### Primary Production ####
labelstring ='Primary Productivity ($\mu$mol N m$^{-2}$ day$^{-1}$)'
vmax = 30
vmin = 5
s = axs[0].pcolormesh(physcale*np.ma.masked_array(mean_Jul_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('July Mean 2007-2020');

s = axs[1].pcolormesh(physcale*np.ma.masked_array(tyear_Jul_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('July 2020')

vmax = 25
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array(tyear_Jul_totalphyto[imin:imax, jmin:jmax] 
                                           / mean_Jul_totalphyto[imin:imax, jmin:jmax] - np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2020')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);
    
fig.savefig('JulyProductivity2020.png')

# %% [markdown]
# ## June Only

# %%
mean_Jun_totalphyto = (
                  mean_2007_2020_jun['PPDIAT'][0] + mean_2007_2020_jun['PPPHY'][0] 
                    + mean_2007_2020_jun['PPMRUB'][0])

mean_Jun_flag = (mean_2007_2020_jun['PPPHY'][0] 
                    )

tyear_Jun_totalphyto = (
                  t2020_jun['PPDIAT'][0] + t2020_jun['PPPHY'][0] 
                    + t2020_jun['PPMRUB'][0] 
                  )

tyear_Jun_flag = (t2020_jun['PPPHY'][0] 
                    )

# %%
lz = 21
for i in range(lz):
    mean_Jun_totalphyto[i] = mean_Jun_totalphyto[i] * e3t[i] 
    mean_Jun_flag[i] = mean_Jun_flag[i] * e3t[i]   
mean_Jun_totalphyto = mean_Jun_totalphyto[:lz].sum(axis=0)
mean_Jun_phyto_ratio = mean_Jun_flag[:lz].sum(axis=0)/mean_Jun_totalphyto
print (mean_Jun_totalphyto.shape)
# Out:
# (898, 398)

# %%
for i in range(lz):
    tyear_Jun_totalphyto[i] = tyear_Jun_totalphyto[i] * e3t[i] 
    tyear_Jun_flag[i] = tyear_Jun_flag[i] * e3t[i] 
tyear_Jun_totalphyto = tyear_Jun_totalphyto[:lz].sum(axis=0)
tyear_Jun_phyto_ratio = tyear_Jun_flag[:lz].sum(axis=0)/tyear_Jun_totalphyto

print (tyear_Jun_totalphyto.shape)
# Out:
# (898, 398)

# %%
imin, imax = 350, 750
jmin, jmax = 100, 350
physcale = 86400 # per day

cmap = cmocean.cm.algae
cmap.set_bad('burlywood')
cmap2 = cmocean.cm.balance
cmap2.set_bad('burlywood')

fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### Primary Production ####
labelstring ='Primary Productivity ($\mu$mol N m$^{-2}$ day$^{-1}$)'
vmax = 30
vmin = 5
s = axs[0].pcolormesh(physcale*np.ma.masked_array(mean_Jun_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('June Mean 2007-2020');

s = axs[1].pcolormesh(physcale*np.ma.masked_array(tyear_Jun_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('June 2020')

vmax = 25
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array(tyear_Jun_totalphyto[imin:imax, jmin:jmax] 
                                           / mean_Jun_totalphyto[imin:imax, jmin:jmax] - np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2020')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);
    
fig.savefig('JuneProductivity2020.png')

# %% [markdown]
# ## August Only

# %%
mean_Aug_totalphyto = (
                  mean_2007_2020_aug['PPDIAT'][0] + mean_2007_2020_aug['PPPHY'][0] 
                    + mean_2007_2020_aug['PPMRUB'][0])

mean_Aug_flag = (mean_2007_2020_aug['PPPHY'][0] 
                    )

tyear_Aug_totalphyto = (
                  t2020_aug['PPDIAT'][0] + t2020_aug['PPPHY'][0] 
                    + t2020_aug['PPMRUB'][0] 
                  )

tyear_Aug_flag = (t2020_aug['PPPHY'][0] 
                    )

# %%
lz = 21
for i in range(lz):
    mean_Aug_totalphyto[i] = mean_Aug_totalphyto[i] * e3t[i] 
    mean_Aug_flag[i] = mean_Aug_flag[i] * e3t[i]   
mean_Aug_totalphyto = mean_Aug_totalphyto[:lz].sum(axis=0)
mean_Aug_phyto_ratio = mean_Aug_flag[:lz].sum(axis=0)/mean_Aug_totalphyto
print (mean_Aug_totalphyto.shape)
# Out:
# (898, 398)

# %%
for i in range(lz):
    tyear_Aug_totalphyto[i] = tyear_Aug_totalphyto[i] * e3t[i] 
    tyear_Aug_flag[i] = tyear_Aug_flag[i] * e3t[i] 
tyear_Aug_totalphyto = tyear_Aug_totalphyto[:lz].sum(axis=0)
tyear_Aug_phyto_ratio = tyear_Aug_flag[:lz].sum(axis=0)/tyear_Aug_totalphyto

print (tyear_Aug_totalphyto.shape)
# Out:
# (898, 398)

# %%
imin, imax = 350, 750
jmin, jmax = 100, 350
physcale = 86400 # per day

cmap = cmocean.cm.algae
cmap.set_bad('burlywood')
cmap2 = cmocean.cm.balance
cmap2.set_bad('burlywood')

fig, axs = plt.subplots(1, 3,figsize = (7.5*3, 9.5*1))

#### Primary Production ####
labelstring ='Primary Productivity ($\mu$mol N m$^{-2}$ day$^{-1}$)'
vmax = 30
vmin = 5
s = axs[0].pcolormesh(physcale*np.ma.masked_array(mean_Aug_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[0])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[0])
axs[0].set_title('August Mean 2007-2020');

s = axs[1].pcolormesh(physcale*np.ma.masked_array(tyear_Aug_totalphyto[imin:imax, jmin:jmax],
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[1])
colorbar.set_label(labelstring)
viz_tools.set_aspect(axs[1])
axs[1].set_title('August 2020')

vmax = 25
vmin = -vmax
s = axs[2].pcolormesh(100*np.ma.masked_array(tyear_Aug_totalphyto[imin:imax, jmin:jmax] 
                                           / mean_Aug_totalphyto[imin:imax, jmin:jmax] - np.ones([imax-imin, jmax-jmin]), 
                                           mask = 1 - mymesh.variables['tmask'][0,lz,imin:imax, jmin:jmax]), 
                        cmap = cmap2, vmin=vmin, vmax=vmax)
colorbar = fig.colorbar(s, ax=axs[2])
colorbar.set_label('Percent of Mean')
viz_tools.set_aspect(axs[2])
axs[2].set_title('Anomaly 2020')

for ax in [axs[0], axs[1], axs[2]
           ]:
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.text(5, 105, 'Vancouver Island', fontsize=13)
    ax.text(150, 205, 'Sunshine Coast', fontsize=12);
    
fig.savefig('AugustProductivity2020.png')
